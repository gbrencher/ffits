# %%
import xarray as xr
import rasterio as rio
import rioxarray
import matplotlib.pyplot as plt
import numpy as np

# %%
ds = xr.open_dataset('autoRIFT_intermediate.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:         (x: 1428, y: 240, y1: 240, x1: 1428)
# Coordinates:
#   * x               (x) int32 0 1 2 3 4 5 6 ... 1422 1423 1424 1425 1426 1427
#   * y               (y) int32 0 1 2 3 4 5 6 7 ... 233 234 235 236 237 238 239
# Dimensions without coordinates: y1, x1
# Data variables:
#     Dx              (y, x) float32 ...
#     Dy              (y, x) float32 ...
#     InterpMask      (y, x) float32 ...
#     ChipSizeX       (y, x) float32 ...
#     SearchLimitX    (y, x) float32 ...
#     SearchLimitY    (y, x) float32 ...
#     noDataMask      (y1, x1) float32 ...
#     GridSpacingX    uint16 ...
#     ScaleChipSizeY  float32 ...
#     origSizeX       uint16 ...
#     origSizeY       uint16 ...
# Attributes:
#     date_created:  12-Oct-2023 23:27:40
#     title:         autoRIFT intermediate results
#     author:        Alex S. Gardner, JPL/NASA; Yang Lei, GPS/Caltech
#     institution:   NASA Jet Propulsion Laboratory (JPL), California Institute...

# %%
f, ax = plt.subplots(figsize=(15, 15))
ax.imshow(np.flip(ds.Dx.values, (0)), cmap='RdBu_r', vmin=-3, vmax=3)
ax.set_aspect('equal')

# %% [markdown]
# # Unwrap interferograms with snaphu using scaled speckle tracking offsets for coarse phase estimate

# %%
import xarray as xr
import rasterio as rio
import rioxarray
import numpy as np
import matplotlib.pyplot as plt
from osgeo import gdal, gdal_array
from skimage import data, filters
from scipy.interpolate import interpn
import os
from glob import glob
from datetime import datetime

# %%
def prep_inputs(igram_dir, speckle_dir, tbaseline):
    '''
    - open interferogram, coherence, and speckle tracking product
    - resample and pad speckle tracking offsets to match interferogram
    - filter speckle tracking product, convert to phase, and scale to temporal baseline
    
    '''
    veloc_fn = f'{speckle_dir}/velocityRg.h5'
    igram_fn = f'{igram_dir}/filt_fine.int'
    cor_fn = f'{igram_dir}/filt_fine.cor'

    igram_ds = gdal.Open(igram_fn, gdal.GA_ReadOnly)
    igram = igram_ds.GetRasterBand(1).ReadAsArray()
    cor_ds = gdal.Open(cor_fn, gdal.GA_ReadOnly)
    cor = cor_ds.GetRasterBand(1).ReadAsArray()

    ds = xr.open_dataset(veloc_fn)

    non_zero_rows = np.any(igram != 0, axis=1)
    non_zero_cols = np.any(igram != 0, axis=0)
    igram_crop = igram[non_zero_rows][:, non_zero_cols]
    cor_crop = cor[non_zero_rows][:, non_zero_cols]

    veloc = ds.velocity.values
    non_zero_rows = np.any(veloc != 0, axis=1)
    non_zero_cols = np.any(veloc != 0, axis=0)

    veloc_crop = veloc[non_zero_rows][:, non_zero_cols]

    # Find rows and columns with all zeros and remove them in each direction
    row_sum = np.sum(igram, axis=1)
    col_sum = np.sum(igram, axis=0)
    top_padding = 0
    bottom_padding = 0
    left_padding = 0
    right_padding = 0
    
    # Determine top padding
    while row_sum[top_padding] == 0:
        top_padding += 1
    
    # Determine bottom padding
    while row_sum[-1 - bottom_padding] == 0:
        bottom_padding += 1
    
    # Determine left padding
    while col_sum[left_padding] == 0:
        left_padding += 1
    
    # Determine right padding
    while col_sum[-1 - right_padding] == 0:
        right_padding += 1

    # interpolate to match interferogram dimensions
    x_coords = np.linspace(0, veloc_crop.shape[1]-1, veloc_crop.shape[1])
    y_coords = np.linspace(0, veloc_crop.shape[0]-1, veloc_crop.shape[0])
    
    # Create a mesh grid for the interferogram dimensions
    x_coords_new, y_coords_new = np.meshgrid(
        np.linspace(x_coords.min(), x_coords.max(), igram_crop.shape[1]),
        np.linspace(y_coords.min(), y_coords.max(), igram_crop.shape[0])
    )
    
    # Perform bilinear interpolation using scipy.interpolate.interpn
    veloc = interpn((y_coords, x_coords), veloc_crop, (y_coords_new, x_coords_new), method="linear")

    # filter to remove some noise
    veloc_filtered = filters.butterworth(veloc,
                                         cutoff_frequency_ratio=0.35, #between 0 and 0.5
                                         order=2,
                                         high_pass=False)
    
    # convert to phase for simulated 12 day period
    veloc_unwrapped = (veloc_filtered-0.6)*(tbaseline/365)*(12.5663706/0.05546576) # 0.6 to set ref point
    # pad to original interferogram dimensions
    veloc_unwrapped_full = np.pad(veloc_unwrapped, ((top_padding, bottom_padding), (left_padding, right_padding)), mode='constant')

    # crop to aoi
    veloc_unwrapped_aoi = veloc_unwrapped_full[6400:7400, 2400:3400]
    igram_aoi = igram[6400:7400, 2400:3400]
    cor_aoi = cor[6400:7400, 2400:3400]

    # save cropped speckle tracking displacement
    veloc_unwrapped_aoi = np.nan_to_num(veloc_unwrapped_aoi, nan=0)
    veloc_unwrapped_aoi = veloc_unwrapped_aoi.astype(np.float32)
    output_file = f'{igram_dir}/veloc_unwrapped_aoi' 
    driver_format = "ISCE"    # Specify the GDAL format for the output (GeoTIFF in this example)
    rows, cols = veloc_unwrapped_aoi.shape    # Get the number of rows and columns from the NumPy array
    data_type = gdal_array.NumericTypeCodeToGDALTypeCode(veloc_unwrapped_aoi.dtype)  # Convert NumPy data type to GDAL data type
    driver = gdal.GetDriverByName(driver_format)
    output_ds = driver.Create(output_file, cols, rows, 1, data_type)
    band = output_ds.GetRasterBand(1)  
    band.WriteArray(veloc_unwrapped_aoi)
    output_ds = None

    # save cropped interferogram
    igram_aoi = np.nan_to_num(igram_aoi, nan=0)
    igram_aoi = igram_aoi.astype(np.complex64)
    output_file = f'{igram_dir}/filt_fine_aoi.int' 
    driver_format = "ISCE"    # Specify the GDAL format for the output (GeoTIFF in this example)
    rows, cols = igram_aoi.shape    # Get the number of rows and columns from the NumPy array
    data_type = gdal_array.NumericTypeCodeToGDALTypeCode(igram_aoi.dtype)  # Convert NumPy data type to GDAL data type
    driver = gdal.GetDriverByName(driver_format)
    output_ds = driver.Create(output_file, cols, rows, 1, data_type)
    band = output_ds.GetRasterBand(1)  
    band.WriteArray(igram_aoi)
    output_ds = None

    # save cropped coherence
    cor_aoi = np.nan_to_num(cor_aoi, nan=0)
    cor_aoi = cor_aoi.astype(np.float32)
    output_file = f'{igram_dir}/filt_fine_aoi.cor' 
    driver_format = "ISCE"    # Specify the GDAL format for the output (GeoTIFF in this example)
    rows, cols = cor_aoi.shape    # Get the number of rows and columns from the NumPy array
    data_type = gdal_array.NumericTypeCodeToGDALTypeCode(cor_aoi.dtype)  # Convert NumPy data type to GDAL data type
    driver = gdal.GetDriverByName(driver_format)
    output_ds = driver.Create(output_file, cols, rows, 1, data_type)
    band = output_ds.GetRasterBand(1) 
    band.WriteArray(cor_aoi)
    output_ds = None

    # # save coherence mask 
    # byte_mask = (np.abs(veloc_unwrapped_aoi)<50).astype(np.uint8)
    # output_file = f'{igram_dir}/50rad_mask' 
    # driver_format = "ISCE"    # Specify the GDAL format for the output (GeoTIFF in this example)
    # rows, cols = byte_mask.shape    # Get the number of rows and columns from the NumPy array
    # data_type = gdal_array.NumericTypeCodeToGDALTypeCode(byte_mask.dtype)  # Convert NumPy data type to GDAL data type
    # driver = gdal.GetDriverByName(driver_format)
    # output_ds = driver.Create(output_file, cols, rows, 1, data_type)
    # band = output_ds.GetRasterBand(1)  # Get the single band
    # band.WriteArray(byte_mask)
    # output_ds = None

# %%
# Function to write to MintPy config file
def write_config_file(out_file, CONFIG_TXT, mode='a'): 
    """Write configuration files for snaphu to process products"""
    if not os.path.isfile(out_file) or mode == 'w':
        with open(out_file, "w") as fid:
            fid.write(CONFIG_TXT)
        print('write configuration to file: {}'.format(out_file))
    else:
        with open(out_file, "a") as fid:
            fid.write("\n" + CONFIG_TXT)
        print('add the following to file: \n{}'.format(CONFIG_TXT))

# %%
CONFIG_TXT = f'''# snaphu configuration file
#############################################
# File input and output and runtime options #
#############################################

# Input file name
INFILE	filt_fine_aoi.int

# Input file line length 
LINELENGTH	1000

# Output file name
OUTFILE	filt_fine_aoi_noest.unw

# Correlation file name
CORRFILE	filt_fine_aoi.cor

# Coarse unwrapped-phase estimate file name (see possible file formats
# below).  The array should have the same dimensions as the input
# wrapped phase array.
#ESTIMATEFILE	veloc_unwrapped_aoi

# Input file of signed binary byte (signed char) values.  
#BYTEMASKFILE  50rad_mask

# Text file to which runtime parameters will be logged.  
LOGFILE       snaphu.logfile

# Statistical-cost mode (TOPO, DEFO, SMOOTH, or NOSTATCOSTS)
STATCOSTMODE	SMOOTH

# Algorithm used for initialization of wrapped phase values.  Possible
# values are MST and MCF.  
INITMETHOD	MCF

################
# File formats #
################

# Input file format
INFILEFORMAT		COMPLEX_DATA

# Output file format
OUTFILEFORMAT		FLOAT_DATA

# Correlation file format
CORRFILEFORMAT		FLOAT_DATA

# Unwrapped estimate file format
ESTFILEFORMAT		FLOAT_DATA

# End of snaphu configuration file'''
config_file = 'snaphu.conf.brief'

# %%
xml_txt = '''
<imageFile>
  <property name="WIDTH">
    <value>1000</value>
  </property>
  <property name="LENGTH">
    <value>1000</value>
  </property>
  <property name="NUMBER_BANDS">
    <value>1</value>
  </property>
  <property name="DATA_TYPE">
    <value>FLOAT</value>
  </property>
  <property name="SCHEME">
    <value>BIP</value>
  </property>
  <property name="BYTE_ORDER">
    <value>l</value>
  </property>
  <property name="ACCESS_MODE">
    <value>read</value>
  </property>
  <property name="FILE_NAME">
    <value>filt_fine_aoi_noest.unw</value>
  </property>
  <component name="Coordinate1">
    <factorymodule>isceobj.Image</factorymodule>
    <factoryname>createCoordinate</factoryname>
    <doc>First coordinate of a 2D image (width).</doc>
    <property name="name">
      <value>ImageCoordinate_name</value>
    </property>
    <property name="family">
      <value>ImageCoordinate</value>
    </property>
    <property name="size">
      <value>1000</value>
    </property>
  </component>
  <component name="Coordinate2">
    <factorymodule>isceobj.Image</factorymodule>
    <factoryname>createCoordinate</factoryname>
    <property name="name">
      <value>ImageCoordinate_name</value>
    </property>
    <property name="family">
      <value>ImageCoordinate</value>
    </property>
    <property name="size">
      <value>1000</value>
    </property>
  </component>
</imageFile>
'''
xml_file = 'filt_fine_aoi_noest.unw.xml'

# %%
igram_list = glob('/mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/work/merged/interferograms/*')
veloc_dir = '/mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_offsets'

# %%
for i, igram_dir in enumerate(igram_list):
    date = os.path.basename(igram_dir)
    print(f'working on {date}, {i+1}/{len(igram_list)}')

    tbaseline =  datetime.strptime(date[9:17], '%Y%m%d')-datetime.strptime(date[0:8], '%Y%m%d')
    print(f'temporal baseline: {tbaseline.days} days')
    
    os.chdir(igram_dir)
    #if not os.path.exists(f'{igram_dir}/filt_fine_aoi_withest.unw.xml'):
    #print('prepping inputs')
    #prep_inputs(igram_dir, veloc_dir, tbaseline.days)
    write_config_file(config_file, CONFIG_TXT, mode='w')
    print('************unwrapping************')
    # !snaphu -f snaphu.conf.brief
    write_config_file(xml_file, xml_txt, mode='w')
    #else:
       # print('unwrapped igram exists, skipping')
    print('--------------------------------------------------')
# Out:
# working on 20191004_20191016, 1/68
# temporal baseline: 12 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 98908689
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:42.11
# Elapsed wall clock time:  0:00:42
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191004_20191028, 2/68
# temporal baseline: 24 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 116055861
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:43.59
# Elapsed wall clock time:  0:00:44
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191004_20191109, 3/68
# temporal baseline: 36 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 105869182
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:46.40
# Elapsed wall clock time:  0:00:46
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191004_20191121, 4/68
# temporal baseline: 48 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 108736716
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:41.09
# Elapsed wall clock time:  0:00:41
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191004_20191203, 5/68
# temporal baseline: 60 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 115165079
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:44.11
# Elapsed wall clock time:  0:00:44
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191016_20191028, 6/68
# temporal baseline: 12 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 86151757
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:40.91
# Elapsed wall clock time:  0:00:41
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191016_20191109, 7/68
# temporal baseline: 24 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 88793738
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:37.25
# Elapsed wall clock time:  0:00:37
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191016_20191121, 8/68
# temporal baseline: 36 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 95780780
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:34.50
# Elapsed wall clock time:  0:00:35
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191016_20191203, 9/68
# temporal baseline: 48 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 97261671
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:38.60
# Elapsed wall clock time:  0:00:39
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191016_20191215, 10/68
# temporal baseline: 60 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# can't open file filt_fine_aoi.int
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191028_20191109, 11/68
# temporal baseline: 12 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 85958004
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:38.66
# Elapsed wall clock time:  0:00:39
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191028_20191121, 12/68
# temporal baseline: 24 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 101492997
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:42.77
# Elapsed wall clock time:  0:00:43
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191028_20191203, 13/68
# temporal baseline: 36 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 105747548
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:43.98
# Elapsed wall clock time:  0:00:44
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191028_20191215, 14/68
# temporal baseline: 48 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 151131948
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:45.60
# Elapsed wall clock time:  0:00:46
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191028_20191227, 15/68
# temporal baseline: 60 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 118198450
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:39.05
# Elapsed wall clock time:  0:00:39
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191109_20191121, 16/68
# temporal baseline: 12 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 70236308
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:34.31
# Elapsed wall clock time:  0:00:35
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191109_20191215, 17/68
# temporal baseline: 36 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 131021366
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:42.61
# Elapsed wall clock time:  0:00:43
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191109_20191227, 18/68
# temporal baseline: 48 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 106745064
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:36.59
# Elapsed wall clock time:  0:00:37
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191109_20200108, 19/68
# temporal baseline: 60 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 133445727
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:42.87
# Elapsed wall clock time:  0:00:43
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191121_20191203, 20/68
# temporal baseline: 12 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 4
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 68624460
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:27.91
# Elapsed wall clock time:  0:00:28
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191121_20191215, 21/68
# temporal baseline: 24 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 133036571
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:46.38
# Elapsed wall clock time:  0:00:46
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191121_20191227, 22/68
# temporal baseline: 36 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 101666203
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:38.05
# Elapsed wall clock time:  0:00:39
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191121_20200108, 23/68
# temporal baseline: 48 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 132502810
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:40.16
# Elapsed wall clock time:  0:00:40
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191121_20200120, 24/68
# temporal baseline: 60 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Flow increment: 2  (Total improvements: 3777)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 2
# Total solution cost: 120251342
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:39.79
# Elapsed wall clock time:  0:00:40
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191203_20191215, 25/68
# temporal baseline: 12 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 115886290
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:38.04
# Elapsed wall clock time:  0:00:38
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191203_20191227, 26/68
# temporal baseline: 24 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 91774110
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:40.61
# Elapsed wall clock time:  0:00:40
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191203_20200108, 27/68
# temporal baseline: 36 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 126188292
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:44.46
# Elapsed wall clock time:  0:00:45
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191203_20200120, 28/68
# temporal baseline: 48 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 111800400
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:45.73
# Elapsed wall clock time:  0:00:46
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191203_20200201, 29/68
# temporal baseline: 60 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 91209474
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:35.99
# Elapsed wall clock time:  0:00:36
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191215_20191227, 30/68
# temporal baseline: 12 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 118942321
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:42.46
# Elapsed wall clock time:  0:00:43
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191215_20200108, 31/68
# temporal baseline: 24 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 119570279
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:42.21
# Elapsed wall clock time:  0:00:42
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191215_20200120, 32/68
# temporal baseline: 36 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 130610536
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:42.55
# Elapsed wall clock time:  0:00:43
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191215_20200213, 33/68
# temporal baseline: 60 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 135071670
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:37.55
# Elapsed wall clock time:  0:00:38
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191227_20200108, 34/68
# temporal baseline: 12 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 94915603
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:36.44
# Elapsed wall clock time:  0:00:37
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191227_20200120, 35/68
# temporal baseline: 24 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 94696522
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:37.54
# Elapsed wall clock time:  0:00:37
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191227_20200201, 36/68
# temporal baseline: 36 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 90419008
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:34.74
# Elapsed wall clock time:  0:00:35
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191227_20200213, 37/68
# temporal baseline: 48 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 98077339
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:46.14
# Elapsed wall clock time:  0:00:47
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191227_20200225, 38/68
# temporal baseline: 60 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 95895768
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:36.70
# Elapsed wall clock time:  0:00:37
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200108_20200120, 39/68
# temporal baseline: 12 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 103269561
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:39.57
# Elapsed wall clock time:  0:00:39
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200108_20200201, 40/68
# temporal baseline: 24 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 115295901
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:42.76
# Elapsed wall clock time:  0:00:43
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200108_20200213, 41/68
# temporal baseline: 36 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 126833291
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:51.20
# Elapsed wall clock time:  0:00:52
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200108_20200225, 42/68
# temporal baseline: 48 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 112856751
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:41.22
# Elapsed wall clock time:  0:00:41
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200108_20200308, 43/68
# temporal baseline: 60 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 132037509
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:43.28
# Elapsed wall clock time:  0:00:44
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200120_20200201, 44/68
# temporal baseline: 12 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 4
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 82314581
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:31.15
# Elapsed wall clock time:  0:00:31
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200120_20200213, 45/68
# temporal baseline: 24 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 106821711
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:36.86
# Elapsed wall clock time:  0:00:37
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200120_20200225, 46/68
# temporal baseline: 36 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 99115887
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:36.31
# Elapsed wall clock time:  0:00:37
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200120_20200308, 47/68
# temporal baseline: 48 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 118639505
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:48.93
# Elapsed wall clock time:  0:00:49
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200120_20200320, 48/68
# temporal baseline: 60 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 126857133
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:46.04
# Elapsed wall clock time:  0:00:46
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200201_20200225, 49/68
# temporal baseline: 24 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 91544651
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:37.89
# Elapsed wall clock time:  0:00:38
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200201_20200308, 50/68
# temporal baseline: 36 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# ...
# Elapsed wall clock time:  0:00:35
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200213_20200225, 53/68
# temporal baseline: 12 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 5
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 84113110
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:42.80
# Elapsed wall clock time:  0:00:43
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200213_20200308, 54/68
# temporal baseline: 24 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 86440840
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:33.89
# Elapsed wall clock time:  0:00:34
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200213_20200320, 55/68
# temporal baseline: 36 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 103658308
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:35.30
# Elapsed wall clock time:  0:00:35
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200213_20200401, 56/68
# temporal baseline: 48 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 91777727
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:42.75
# Elapsed wall clock time:  0:00:42
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200213_20200413, 57/68
# temporal baseline: 60 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 94900802
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:35.26
# Elapsed wall clock time:  0:00:36
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200225_20200308, 58/68
# temporal baseline: 12 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 90853418
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:47.83
# Elapsed wall clock time:  0:00:48
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200225_20200320, 59/68
# temporal baseline: 24 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 102663083
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:41.43
# Elapsed wall clock time:  0:00:41
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200225_20200401, 60/68
# temporal baseline: 36 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 4
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Flow increment: 2  (Total improvements: 3586)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 2
# Total solution cost: 102695948
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:42.35
# Elapsed wall clock time:  0:00:43
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200225_20200413, 61/68
# temporal baseline: 48 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 108412878
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:41.15
# Elapsed wall clock time:  0:00:41
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200308_20200320, 62/68
# temporal baseline: 12 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 83754548
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:36.33
# Elapsed wall clock time:  0:00:37
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200308_20200401, 63/68
# temporal baseline: 24 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 88984642
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:32.49
# Elapsed wall clock time:  0:00:33
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200308_20200413, 64/68
# temporal baseline: 36 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 99181457
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:40.17
# Elapsed wall clock time:  0:00:40
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200320_20200401, 65/68
# temporal baseline: 12 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 69652819
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:31.28
# Elapsed wall clock time:  0:00:32
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191109_20191203, 66/68
# temporal baseline: 24 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 79456056
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:34.14
# Elapsed wall clock time:  0:00:34
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20191215_20200201, 67/68
# temporal baseline: 48 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 2
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 133378136
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:40.69
# Elapsed wall clock time:  0:00:41
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------
# working on 20200201_20200213, 68/68
# temporal baseline: 12 days
# write configuration to file: snaphu.conf.brief
# ************unwrapping************
#
# snaphu v2.0.6
# 11 parameters input from file snaphu.conf.brief (52 lines total)
# Logging run-time parameters to file snaphu.logfile
# Reading wrapped phase from file filt_fine_aoi.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file filt_fine_aoi.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Running nonlinear network flow optimizer
# Maximum flow on network: 3
# Flow increment: 1  (Total improvements: 0)
# Found 1 valid set(s) of connected nodes
# Maximum flow on network: 1
# Total solution cost: 70791921
# Integrating phase
# Writing output to file filt_fine_aoi_noest.unw
# Program snaphu done
# Elapsed processor time:   0:00:39.26
# Elapsed wall clock time:  0:00:39
# write configuration to file: filt_fine_aoi_noest.unw.xml
# --------------------------------------------------

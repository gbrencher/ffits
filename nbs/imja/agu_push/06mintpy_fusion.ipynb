# %%
# Import required packages
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from osgeo import gdal, gdal_array
from datetime import datetime, timedelta
import xarray as xr
import rasterio as rio
import rioxarray
import geopandas as gpd
import time
from glob import glob
import scipy.signal
from mintpy.utils import readfile, writefile, utils as ut, plot
from mintpy.cli import view, tsview, plot_network, plot_transection
from mintpy.view import prep_slice, plot_slice
from pathlib import Path

# %%
mintpy_path = '/mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion'

# %%
# Function to write to MintPy config file
def write_config_file(out_file, CONFIG_TXT, mode='a'): 
    """Write configuration files for MintPy to process products"""
    if not os.path.isfile(out_file) or mode == 'w':
        with open(out_file, "w") as fid:
            fid.write(CONFIG_TXT)
        print('write configuration to file: {}'.format(out_file))
    else:
        with open(out_file, "a") as fid:
            fid.write("\n" + CONFIG_TXT)
        print('add the following to file: \n{}'.format(CONFIG_TXT))

# %%
CONFIG_TXT = f'''
# vim: set filetype=cfg:
##------------------------ smallbaselineApp.cfg ------------------------##
########## computing resource configuration
mintpy.compute.maxMemory = 40 #auto for 4, max memory to allocate in GB
## parallel processing with dask
## currently apply to steps: invert_network, correct_topography
## cluster   = none to turn off the parallel computing
## numWorker = all  to use all of locally available cores (for cluster = local only)
## numWorker = 80%  to use 80% of locally available cores (for cluster = local only)
## config    = none to rollback to the default name (same as the cluster type; for cluster != local)
mintpy.compute.cluster   = local #[local / slurm / pbs / lsf / none], auto for none, cluster type
mintpy.compute.numWorker = 4 #[int > 1 / all / num%], auto for 4 (local) or 40 (slurm / pbs / lsf), num of workers
mintpy.compute.config    = auto #[none / slurm / pbs / lsf ], auto for none (same as cluster), config name


########## 1. load_data
##---------add attributes manually
## MintPy requires attributes listed at: https://mintpy.readthedocs.io/en/latest/api/attributes/
## Missing attributes can be added below manually (uncomment #), e.g.
# ORBIT_DIRECTION = ascending
# PLATFORM = Sen
# ...
## a. autoPath - automatic path pattern defined in mintpy.defaults.auto_path.AUTO_PATH_*
## b. load_data.py -H to check more details and example inputs.
## c. compression to save disk usage for ifgramStack.h5 file:
## no   - save   0% disk usage, fast [default]
## lzf  - save ~57% disk usage, relative slow
## gzip - save ~62% disk usage, very slow [not recommend]
mintpy.load.processor       = isce  #[isce, aria, hyp3, gmtsar, snap, gamma, roipac, nisar], auto for isce
mintpy.load.autoPath        = auto  #[yes / no], auto for no, use pre-defined auto path
mintpy.load.updateMode      = auto  #[yes / no], auto for yes, skip re-loading if HDF5 files are complete
mintpy.load.compression     = auto  #[gzip / lzf / no], auto for no.
##---------for ISCE only:
mintpy.load.metaFile        = ../work/reference/IW1.xml  #[path of common metadata file for the stack], i.e.: ./reference/IW1.xml, ./referenceShelve/data.dat
mintpy.load.baselineDir     = ../work/baselines  #[path of the baseline dir], i.e.: ./baselines
##---------interferogram stack:
mintpy.load.unwFile         = ../fusion_pairs/*/*filt_fine_aoi_noest.unw  #[path pattern of unwrapped interferogram files]
mintpy.load.corFile         = ../fusion_pairs/*/*filt_fine_aoi.cor  #[path pattern of spatial coherence       files]
mintpy.load.connCompFile    = ../fusion_pairs/*/*conn_comp  #[path pattern of connected components    files], optional but recommended
mintpy.load.intFile         = auto  #[path pattern of wrapped interferogram   files], optional
mintpy.load.magFile         = auto  #[path pattern of interferogram magnitude files], optional
##---------geometry:
mintpy.load.demFile         = ../work/merged/geom_reference/hgt_aoi.rdr  #[path of DEM file]
mintpy.load.lookupYFile     = ../work/merged/geom_reference/lat_aoi.rdr  #[path of latitude /row   /y coordinate file], not required for geocoded data
mintpy.load.lookupXFile     = ../work/merged/geom_reference/lon_aoi.rdr  #[path of longitude/column/x coordinate file], not required for geocoded data
mintpy.load.incAngleFile    = ../work/merged/geom_reference/incLocal_aoi.rdr  #[path of incidence angle file], optional but recommended
mintpy.load.azAngleFile     = ../work/merged/geom_reference/los_aoi.rdr  #[path of azimuth   angle file], optional
mintpy.load.shadowMaskFile  = ../work/merged/geom_reference/shadowMask_aoi.rdr  #[path of shadow mask file], optional but recommended

########## 2. modify_network
## 1) Network modification based on temporal/perpendicular baselines, date, num of connections etc.
mintpy.network.tempBaseMax     = auto  #[1-inf, no], auto for no, max temporal baseline in days
mintpy.network.perpBaseMax     = 150  #[1-inf, no], auto for no, max perpendicular spatial baseline in meter
mintpy.network.connNumMax      = auto  #[1-inf, no], auto for no, max number of neighbors for each acquisition
mintpy.network.startDate       = auto  #[20090101 / no], auto for no
mintpy.network.endDate         = auto  #[20110101 / no], auto for no
mintpy.network.excludeDate     = auto  #[20080520,20090817 / no], auto for no
mintpy.network.excludeIfgIndex = auto  #[1:5,25 / no], auto for no, list of ifg index (start from 0)
mintpy.network.referenceFile   = auto  #[date12_list.txt / ifgramStack.h5 / no], auto for no

## 2) Data-driven network modification
## a - Coherence-based network modification = (threshold + MST) by default
## reference: Yunjun et al. (2019, section 4.2 and 5.3.1); Chaussard et al. (2015, GRL)
## It calculates a average coherence for each interferogram using spatial coherence based on input mask (with AOI)
## Then it finds a minimum spanning tree (MST) network with inverse of average coherence as weight (keepMinSpanTree)
## Next it excludes interferograms if a) the average coherence < minCoherence AND b) not in the MST network.
mintpy.network.coherenceBased  = auto  #[yes / no], auto for no, exclude interferograms with coherence < minCoherence
mintpy.network.minCoherence    = auto  #[0.0-1.0], auto for 0.7

## b - Effective Coherence Ratio network modification = (threshold + MST) by default
## reference: Kang et al. (2021, RSE)
## It calculates the area ratio of each interferogram that is above a spatial coherence threshold.
## This threshold is defined as the spatial coherence of the interferograms within the input mask.
## It then finds a minimum spanning tree (MST) network with inverse of the area ratio as weight (keepMinSpanTree)
## Next it excludes interferograms if a) the area ratio < minAreaRatio AND b) not in the MST network.
mintpy.network.areaRatioBased  = auto  #[yes / no], auto for no, exclude interferograms with area ratio < minAreaRatio
mintpy.network.minAreaRatio    = auto  #[0.0-1.0], auto for 0.75

## Additional common parameters for the 2) data-driven network modification
mintpy.network.keepMinSpanTree = auto  #[yes / no], auto for yes, keep interferograms in Min Span Tree network
mintpy.network.maskFile        = auto  #[file name, no], auto for waterMask.h5 or no [if no waterMask.h5 found]
mintpy.network.aoiYX           = auto  #[y0:y1,x0:x1 / no], auto for no, area of interest for coherence calculation
mintpy.network.aoiLALO         = auto  #[S:N,W:E / no], auto for no - use the whole area


########## 3. reference_point
## Reference all interferograms to one common point in space
## auto - randomly select a pixel with coherence > minCoherence
## however, manually specify using prior knowledge of the study area is highly recommended
##   with the following guideline (section 4.3 in Yunjun et al., 2019):
## 1) located in a coherence area, to minimize the decorrelation effect.
## 2) not affected by strong atmospheric turbulence, i.e. ionospheric streaks
## 3) close to and with similar elevation as the AOI, to minimize the impact of spatially correlated atmospheric delay
mintpy.reference.yx            = auto   #[257,151 / auto]
mintpy.reference.lalo          = 27.904352, 86.870901   #[31.8,130.8 / auto]
mintpy.reference.maskFile      = auto   #[filename / no], auto for maskConnComp.h5
mintpy.reference.coherenceFile = auto   #[filename], auto for avgSpatialCoh.h5
mintpy.reference.minCoherence  = auto   #[0.0-1.0], auto for 0.85, minimum coherence for auto method


########## quick_overview
## A quick assessment of:
## 1) possible groud deformation
##    using the velocity from the traditional interferogram stacking
##    reference: Zebker et al. (1997, JGR)
## 2) distribution of phase unwrapping error
##    from the number of interferogram triplets with non-zero integer ambiguity of closue phase
##    reference: T_int in Yunjun et al. (2019, CAGEO). Related to section 3.2, equation (8-9) and Fig. 3d-e.


########## 4. correct_unwrap_error (optional)
## connected components (mintpy.load.connCompFile) are required for this step.
## SNAPHU (Chem & Zebker,2001) is currently the only unwrapper that provides connected components as far as we know.
## reference: Yunjun et al. (2019, section 3)
## supported methods:
## a. phase_closure          - suitable for highly redundant network
## b. bridging               - suitable for regions separated by narrow decorrelated features, e.g. rivers, narrow water bodies
## c. bridging+phase_closure - recommended when there is a small percentage of errors left after bridging
mintpy.unwrapError.method          = no  #[bridging / phase_closure / bridging+phase_closure / no], auto for no
mintpy.unwrapError.waterMaskFile   = auto  #[waterMask.h5 / no], auto for waterMask.h5 or no [if not found]
mintpy.unwrapError.connCompMinArea = 500  #[1-inf], auto for 2.5e3, discard regions smaller than the min size in pixels

## phase_closure options:
## numSample - a region-based strategy is implemented to speedup L1-norm regularized least squares inversion.
##     Instead of inverting every pixel for the integer ambiguity, a common connected component mask is generated,
##     for each common conn. comp., numSample pixels are radomly selected for inversion, and the median value of the results
##     are used for all pixels within this common conn. comp.
mintpy.unwrapError.numSample       = 100  #[int>1], auto for 100, number of samples to invert for common conn. comp.

## bridging options:
## ramp - a phase ramp could be estimated based on the largest reliable region, removed from the entire interferogram
##     before estimating the phase difference between reliable regions and added back after the correction.
## bridgePtsRadius - half size of the window used to calculate the median value of phase difference
mintpy.unwrapError.ramp            = auto  #[linear / quadratic], auto for no; recommend linear for L-band data
mintpy.unwrapError.bridgePtsRadius = auto  #[1-inf], auto for 50, half size of the window around end points


########## 5. invert_network
## Invert network of interferograms into time-series using weighted least square (WLS) estimator.
## weighting options for least square inversion [fast option available but not best]:
## a. var - use inverse of covariance as weight (Tough et al., 1995; Guarnieri & Tebaldini, 2008) [recommended]
## b. fim - use Fisher Information Matrix as weight (Seymour & Cumming, 1994; Samiei-Esfahany et al., 2016).
## c. coh - use coherence as weight (Perissin & Wang, 2012)
## d. no  - uniform weight (Berardino et al., 2002) [fast]
## SBAS (Berardino et al., 2002) = minNormVelocity (yes) + weightFunc (no)
mintpy.networkInversion.weightFunc      = auto #[var / fim / coh / no], auto for var
mintpy.networkInversion.waterMaskFile   = auto #[filename / no], auto for waterMask.h5 or no [if not found]
mintpy.networkInversion.minNormVelocity = auto #[yes / no], auto for yes, min-norm deformation velocity / phase

## mask options for unwrapPhase of each interferogram before inversion (recommend if weightFunct=no):
## a. coherence              - mask out pixels with spatial coherence < maskThreshold
## b. connectComponent       - mask out pixels with False/0 value
## c. no                     - no masking [recommended].
## d. range/azimuthOffsetStd - mask out pixels with offset std. dev. > maskThreshold [for offset]
mintpy.networkInversion.maskDataset   = auto #[coherence / connectComponent / rangeOffsetStd / azimuthOffsetStd / no], auto for no
mintpy.networkInversion.maskThreshold = auto #[0-inf], auto for 0.4
mintpy.networkInversion.minRedundancy = auto #[1-inf], auto for 1.0, min num_ifgram for every SAR acquisition

## Temporal coherence is calculated and used to generate the mask as the reliability measure
## reference: Pepe & Lanari (2006, IEEE-TGRS)
mintpy.networkInversion.minTempCoh  = 0.0 #[0.0-1.0], auto for 0.7, min temporal coherence for mask
mintpy.networkInversion.minNumPixel = auto #[int > 1], auto for 100, min number of pixels in mask above
mintpy.networkInversion.shadowMask  = yes #[yes / no], auto for yes [if shadowMask is in geometry file] or no.

########## 6. correct_troposphere (optional but recommended)
## correct tropospheric delay using the following methods:
## a. height_correlation - correct stratified tropospheric delay (Doin et al., 2009, J Applied Geop)
## b. pyaps - use Global Atmospheric Models (GAMs) data (Jolivet et al., 2011; 2014)
##      ERA5  - ERA5    from ECMWF [need to install PyAPS from GitHub; recommended and turn ON by default]
##      MERRA - MERRA-2 from NASA  [need to install PyAPS from Caltech/EarthDef]
##      NARR  - NARR    from NOAA  [need to install PyAPS from Caltech/EarthDef; recommended for N America]
## c. gacos - use GACOS with the iterative tropospheric decomposition model (Yu et al., 2018, JGR)
##      need to manually download GACOS products at http://www.gacos.net for all acquisitions before running this step
mintpy.troposphericDelay.method = no  #[pyaps / height_correlation / gacos / no], auto for pyaps

## Notes for pyaps:
## a. GAM data latency: with the most recent SAR data, there will be GAM data missing, the correction
##    will be applied to dates with GAM data available and skipped for the others.
## b. WEATHER_DIR: if you define an environment variable named WEATHER_DIR to contain the path to a
##    directory, then MintPy applications will download the GAM files into the indicated directory.
##    MintPy application will look for the GAM files in the directory before downloading a new one to
##    prevent downloading multiple copies if you work with different dataset that cover the same date/time.
mintpy.troposphericDelay.weatherModel = auto  #[ERA5 / MERRA / NARR], auto for ERA5
mintpy.troposphericDelay.weatherDir   = auto  #[path2directory], auto for WEATHER_DIR or "./"

## Notes for height_correlation:
## Extra multilooking is applied to estimate the empirical phase/elevation ratio ONLY.
## For an dataset with 5 by 15 looks, looks=8 will generate phase with (5*8) by (15*8) looks
## to estimate the empirical parameter; then apply the correction to original phase (with 5 by 15 looks),
## if the phase/elevation correlation is larger than minCorrelation.
mintpy.troposphericDelay.polyOrder      = auto  #[1 / 2 / 3], auto for 1
mintpy.troposphericDelay.looks          = auto  #[1-inf], auto for 8, extra multilooking num
mintpy.troposphericDelay.minCorrelation = auto  #[0.0-1.0], auto for 0

## Notes for gacos:
## Set the path below to directory that contains the downloaded *.ztd* files
mintpy.troposphericDelay.gacosDir = auto # [path2directory], auto for "./GACOS"


########## 7. deramp (optional)
## Estimate and remove a phase ramp for each acquisition based on the reliable pixels.
## Recommended for localized deformation signals, i.e. volcanic deformation, landslide and land subsidence, etc.
## NOT recommended for long spatial wavelength deformation signals, i.e. co-, post- and inter-seimic deformation.
mintpy.deramp          = linear  #[no / linear / quadratic], auto for no - no ramp will be removed
mintpy.deramp.maskFile = auto  #[filename / no], auto for maskTempCoh.h5, mask file for ramp estimation


########## 8. correct_topography (optional but recommended)
## Topographic residual (DEM error) correction
## reference: Fattahi and Amelung (2013, IEEE-TGRS)
## stepFuncDate      - specify stepFuncDate option if you know there are sudden displacement jump in your area,
##                     e.g. volcanic eruption, or earthquake
## excludeDate       - dates excluded for the error estimation
## pixelwiseGeometry - use pixel-wise geometry (incidence angle & slant range distance)
##                     yes - use pixel-wise geometry if they are available [slow; used by default]
##                     no  - use the mean   geometry [fast]
mintpy.topographicResidual                   = auto  #[yes / no], auto for yes
mintpy.topographicResidual.polyOrder         = auto  #[1-inf], auto for 2, poly order of temporal deformation model
mintpy.topographicResidual.phaseVelocity     = auto  #[yes / no], auto for no - use phase velocity for minimization
mintpy.topographicResidual.stepFuncDate      = auto  #[20080529,20190704T1733 / no], auto for no, date of step jump
mintpy.topographicResidual.excludeDate       = auto  #[20070321 / txtFile / no], auto for exclude_date.txt
mintpy.topographicResidual.pixelwiseGeometry = auto  #[yes / no], auto for yes, use pixel-wise geometry info


########## 9.1 residual_RMS (root mean squares for noise evaluation)
## Calculate the Root Mean Square (RMS) of residual phase time-series for each acquisition
## reference: Yunjun et al. (2019, section 4.9 and 5.4)
## To get rid of long spatial wavelength component, a ramp is removed for each acquisition
## Set optimal reference date to date with min RMS
## Set exclude dates (outliers) to dates with RMS > cutoff * median RMS (Median Absolute Deviation)
mintpy.residualRMS.maskFile = auto  #[file name / no], auto for maskTempCoh.h5, mask for ramp estimation
mintpy.residualRMS.deramp   = auto  #[quadratic / linear / no], auto for quadratic
mintpy.residualRMS.cutoff   = auto  #[0.0-inf], auto for 3

########## 9.2 reference_date
## Reference all time-series to one date in time
## reference: Yunjun et al. (2019, section 4.9)
## no     - do not change the default reference date (1st date)
mintpy.reference.date = no   #[reference_date.txt / 20090214 / no], auto for reference_date.txt


########## 10. velocity
## Estimate a suite of time functions [linear velocity by default]
## from final displacement file (and from tropospheric delay file if exists)
mintpy.timeFunc.startDate   = auto   #[20070101 / no], auto for no
mintpy.timeFunc.endDate     = auto   #[20101230 / no], auto for no
mintpy.timeFunc.excludeDate = auto   #[exclude_date.txt / 20080520,20090817 / no], auto for exclude_date.txt

## Fit a suite of time functions
## reference: Hetland et al. (2012, JGR) equation (2-9)
## polynomial function    is  defined by its degree in integer. 1 for linear, 2 for quadratic, etc.
## periodic   function(s) are defined by a list of periods in decimal years. 1 for annual, 0.5 for semi-annual, etc.
## step       function(s) are defined by a list of onset times in str in YYYYMMDD(THHMM) format
## exp & log  function(s) are defined by an onset time followed by an charateristic time in integer days.
##   Multiple exp and log functions can be overlaied on top of each other, achieved via e.g.:
##   20110311,60,120          - two functions sharing the same onset time OR
##   20110311,60;20170908,120 - separated by ";"
mintpy.timeFunc.polynomial = auto   #[int >= 0], auto for 1, degree of the polynomial function
mintpy.timeFunc.periodic   = auto   #[1,0.5 / list_of_float / no], auto for no, periods in decimal years
mintpy.timeFunc.stepDate   = auto   #[20110311,20170908 / 20120928T1733 / no], auto for no, step function(s)
mintpy.timeFunc.exp        = auto   #[20110311,60 / 20110311,60,120 / 20110311,60;20170908,120 / no], auto for no
mintpy.timeFunc.log        = auto   #[20110311,60 / 20110311,60,120 / 20110311,60;20170908,120 / no], auto for no

## Uncertainty quantification methods:
## a. residue    - propagate from fitting residue assuming normal dist. in time (Fattahi & Amelung, 2015, JGR)
## b. covariance - propagate from time series (co)variance matrix
## c. bootstrap  - bootstrapping (independently resampling with replacement; Efron & Tibshirani, 1986, Stat. Sci.)
mintpy.timeFunc.uncertaintyQuantification = auto   #[residue, covariance, bootstrap], auto for residue
mintpy.timeFunc.timeSeriesCovFile         = auto   #[filename / no], auto for no, time series covariance file
mintpy.timeFunc.bootstrapCount            = auto   #[int>1], auto for 400, number of iterations for bootstrapping


########## 11.1 geocode (post-processing)
# for input dataset in radar coordinates only
# commonly used resolution in meters and in degrees (on equator)
# 100,         90,          60,          50,          40,          30,          20,          10
# 0.000925926, 0.000833334, 0.000555556, 0.000462963, 0.000370370, 0.000277778, 0.000185185, 0.000092593
mintpy.geocode              = auto  #[yes / no], auto for yes
mintpy.geocode.SNWE         = auto  #[-1.2,0.5,-92,-91 / none ], auto for none, output extent in degree
mintpy.geocode.laloStep     = 0.000092593, 0.000092593  #[-0.000555556,0.000555556 / None], auto for None, output resolution in degree
mintpy.geocode.interpMethod = auto  #[linear], auto for nearest, interpolation method
mintpy.geocode.fillValue    = auto  #[np.nan, 0, ...], auto for np.nan, fill value for outliers.

########## 11.2 google_earth (post-processing)
mintpy.save.kmz             = auto   #[yes / no], auto for yes, save geocoded velocity to Google Earth KMZ file

########## 11.3 hdfeos5 (post-processing)
mintpy.save.hdfEos5         = auto   #[yes / no], auto for no, save time-series to HDF-EOS5 format
mintpy.save.hdfEos5.update  = auto   #[yes / no], auto for no, put XXXXXXXX as endDate in output filename
mintpy.save.hdfEos5.subset  = auto   #[yes / no], auto for no, put subset range info   in output filename

########## 11.4 plot
# for high-resolution plotting, increase mintpy.plot.maxMemory
# for fast plotting with more parallelization, decrease mintpy.plot.maxMemory
mintpy.plot           = auto  #[yes / no], auto for yes, plot files generated by default processing to pic folder
mintpy.plot.dpi       = auto  #[int], auto for 150, number of dots per inch (DPI)
mintpy.plot.maxMemory = auto  #[float], auto for 4, max memory used by one call of view.py for plotting.
'''

# %%
os.chdir(mintpy_path)
config_file = f'{mintpy_path}/SenAT12.txt'
write_config_file(config_file, CONFIG_TXT, mode='w')
# Out:
# write configuration to file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/SenAT12.txt

# %%
# !smallbaselineApp.py SenAT12.txt --dostep load_data
# Out:
# MintPy version 1.5.2.post24, date 2023-10-10
# --RUN-at-2023-11-27 07:21:19.472803--
# Current directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# Run routine processing with smallbaselineApp.py on steps: ['load_data']
# Remaining steps: ['modify_network', 'reference_point', 'quick_overview', 'correct_unwrap_error', 'invert_network', 'correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# copy default template file /mnt/Backups/gbrench/sw/insar_tools/MintPy/src/mintpy/defaults/smallbaselineApp.cfg to work directory
# read custom template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/SenAT12.txt
# update default template based on input custom template
#     mintpy.compute.maxMemory: auto --> 40
#     mintpy.compute.cluster: auto --> local
#     mintpy.compute.numWorker: auto --> 4
#     mintpy.load.processor: auto --> isce
#     mintpy.load.metaFile: auto --> ../work/reference/IW1.xml
#     mintpy.load.baselineDir: auto --> ../work/baselines
#     mintpy.load.unwFile: auto --> ../fusion_pairs/*/*filt_fine_aoi_noest.unw
#     mintpy.load.corFile: auto --> ../fusion_pairs/*/*filt_fine_aoi.cor
#     mintpy.load.connCompFile: auto --> ../fusion_pairs/*/*conn_comp
#     mintpy.load.demFile: auto --> ../work/merged/geom_reference/hgt_aoi.rdr
#     mintpy.load.lookupYFile: auto --> ../work/merged/geom_reference/lat_aoi.rdr
#     mintpy.load.lookupXFile: auto --> ../work/merged/geom_reference/lon_aoi.rdr
#     mintpy.load.incAngleFile: auto --> ../work/merged/geom_reference/incLocal_aoi.rdr
#     mintpy.load.azAngleFile: auto --> ../work/merged/geom_reference/los_aoi.rdr
#     mintpy.load.shadowMaskFile: auto --> ../work/merged/geom_reference/shadowMask_aoi.rdr
#     mintpy.network.perpBaseMax: auto --> 150
#     mintpy.reference.lalo: auto --> 27.904352, 86.870901
#     mintpy.unwrapError.method: auto --> no
#     mintpy.unwrapError.connCompMinArea: auto --> 500
#     mintpy.unwrapError.numSample: auto --> 100
#     mintpy.networkInversion.minTempCoh: auto --> 0.0
#     mintpy.networkInversion.shadowMask: auto --> yes
#     mintpy.troposphericDelay.method: auto --> no
#     mintpy.deramp: auto --> linear
#     mintpy.reference.date: auto --> no
#     mintpy.geocode.laloStep: auto --> None
# copy SenAT12.txt          to inputs   directory for backup.
# copy smallbaselineApp.cfg to inputs   directory for backup.
# copy SenAT12.txt          to pic      directory for backup.
# copy smallbaselineApp.cfg to pic      directory for backup.
# read default template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
#
#
# ******************** step - load_data ********************
#
# load_data.py --template /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/SenAT12.txt --project SenAT12
# processor : isce
# SAR platform/sensor : Sen
# --------------------------------------------------
# prepare metadata files for isce products
# prep_isce.py -m ../work/reference/IW1.xml -g ../work/merged/geom_reference -b ../work/baselines -f "../fusion_pairs/*/*filt_fine_aoi_noest.unw" --geom-files hgt_aoi.rdr lat_aoi.rdr lon_aoi.rdr incLocal_aoi.rdr los_aoi.rdr shadowMask_aoi.rdr
# ['../work/reference/data.rsc'] exists and is newer than ['../work/reference/IW1.xml'] --> skip.
# preparing RSC file for geometry files
# write file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/work/merged/geom_reference/hgt_aoi.rdr.rsc
# write file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/work/merged/geom_reference/lat_aoi.rdr.rsc
# write file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/work/merged/geom_reference/lon_aoi.rdr.rsc
# write file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/work/merged/geom_reference/incLocal_aoi.rdr.rsc
# write file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/work/merged/geom_reference/los_aoi.rdr.rsc
# write file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/work/merged/geom_reference/shadowMask_aoi.rdr.rsc
# read perp baseline time-series from ../work/baselines
# preparing RSC file for: ../fusion_pairs/*/*filt_fine_aoi_noest.unw
# output data in size: 1500, 1500
# update LENGTH, WIDTH, Y/XMIN/MAX, A/RLOOKS
# update AZIMUTH_PIXEL_SIZE
# update RANGE_PIXEL_SIZE
# update NCORRLOOKS
# [==================================================] 20200401_20200413 100/100   0s /     0s
# Done.
# --------------------------------------------------
# updateMode : True
# compression: None
# multilook x/ystep: 1/1
# multilook method : nearest
# --------------------------------------------------
# searching geometry files info
# input data files:
# height          : ../work/merged/geom_reference/hgt_aoi.rdr
# latitude        : ../work/merged/geom_reference/lat_aoi.rdr
# longitude       : ../work/merged/geom_reference/lon_aoi.rdr
# incidenceAngle  : ../work/merged/geom_reference/incLocal_aoi.rdr
# azimuthAngle    : ../work/merged/geom_reference/los_aoi.rdr
# shadowMask      : ../work/merged/geom_reference/shadowMask_aoi.rdr
# --------------------------------------------------
# create HDF5 file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/geometryRadar.h5 with w mode
# create dataset /height             of <class 'numpy.float32'>   in size of (1500, 1500) with compression = lzf
# create dataset /latitude           of <class 'numpy.float32'>   in size of (1500, 1500) with compression = lzf
# create dataset /longitude          of <class 'numpy.float32'>   in size of (1500, 1500) with compression = lzf
# create dataset /incidenceAngle     of <class 'numpy.float32'>   in size of (1500, 1500) with compression = lzf
# create dataset /azimuthAngle       of <class 'numpy.float32'>   in size of (1500, 1500) with compression = lzf
# create dataset /shadowMask         of <class 'numpy.bool_'>     in size of (1500, 1500) with compression = lzf
# prepare slantRangeDistance ...
# create dataset /slantRangeDistance of <class 'numpy.float32'>   in size of (1500, 1500) with compression = lzf
# add extra metadata: {'PROJECT_NAME': 'SenAT12', 'PLATFORM': 'Sen'}
# Finished writing to /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/geometryRadar.h5
# --------------------------------------------------
# searching interferogram pairs info
# input data files:
# unwrapPhase     : ../fusion_pairs/*/*filt_fine_aoi_noest.unw
# coherence       : ../fusion_pairs/*/*filt_fine_aoi.cor
# connectComponent: ../fusion_pairs/*/*conn_comp
# number of unwrapPhase     : 100
# number of coherence       : 100
# number of connectComponent: 100
# --------------------------------------------------
# create HDF5 file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/ifgramStack.h5 with w mode
# create dataset /unwrapPhase      of <class 'numpy.float32'>   in size of (100, 1500, 1500) with compression = None
# [==================================================] 20200401_20200413   28s /     0s
# create dataset /coherence        of <class 'numpy.float32'>   in size of (100, 1500, 1500) with compression = None
# [==================================================] 20200401_20200413   34s /     0s
# create dataset /connectComponent of <class 'numpy.int16'>     in size of (100, 1500, 1500) with compression = lzf
# [==================================================] 20200401_20200413   11s /     0s
# create dataset /date             of <class 'numpy.bytes_'>    in size of (100, 2)
# create dataset /bperp            of <class 'numpy.float32'>   in size of (100,)
# create dataset /dropIfgram       of <class 'numpy.bool_'>     in size of (100,)
# add extra metadata: {'PROJECT_NAME': 'SenAT12', 'PLATFORM': 'Sen'}
# Finished writing to /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/ifgramStack.h5
# --------------------------------------------------
# searching ionosphere pairs info
# input data files:
# WARNING: No data files found for the required dataset: ['unwrapPhase']! Skip loading for ionosphere stack.
# --------------------------------------------------
# searching offset pairs info
# input data files:
# WARNING: No data files found for the required dataset: ['rangeOffset', 'azimuthOffset']! Skip loading for offset stack.
# time used: 01 mins 20.7 secs.
#
# Loaded dataset are processed by InSAR software: isce
# Loaded dataset are in RADAR coordinates
# Interferogram Stack: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/ifgramStack.h5
# Geometry      File : /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/geometryRadar.h5
# Lookup Table  File : /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/geometryRadar.h5
# --------------------------------------------------
# updating metadata based on custom template file SenAT12.txt for file: ifgramStack.h5
# Go back to directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 01 mins 21.0 secs

# %%
view.main('inputs/ifgramStack.h5 unwrapPhase-* -v -10 10 --zero-mask --noaxis --noverbose'.split())
# Out:
# view.py inputs/ifgramStack.h5 unwrapPhase-* -v -10 10 --zero-mask --noaxis --noverbose

# %%
# !smallbaselineApp.py SenAT12.txt --dostep modify_network
# Out:
# MintPy version 1.5.2.post24, date 2023-10-10
# --RUN-at-2023-11-27 07:23:02.752043--
# Current directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# Run routine processing with smallbaselineApp.py on steps: ['modify_network']
# Remaining steps: ['reference_point', 'quick_overview', 'correct_unwrap_error', 'invert_network', 'correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# read custom template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/SenAT12.txt
# update default template based on input custom template
# No new option value found, skip updating /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
# read default template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
#
#
# ******************** step - modify_network ********************
#
# modify_network.py /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/ifgramStack.h5 -t /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
# read options from template file: smallbaselineApp.cfg
# open ifgramStack file: ifgramStack.h5
# number of interferograms: 100
# --------------------------------------------------
# Drop ifgrams with perp baseline > 150.0 meters: (7)
# ['20191004_20191016', '20191004_20191028', '20191004_20191227', '20191004_20200108', '20191004_20200120', '20191004_20200225', '20191028_20200413']
# --------------------------------------------------
# number of interferograms to remove: 7
# number of interferograms to keep  : 93
# open file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/ifgramStack.h5 with r+ mode
# update HDF5 dataset "/dropIfgram".
# update MODIFICATION_TIME in HDF5 dataset "/unwrapPhase"
# update MODIFICATION_TIME in HDF5 dataset "/coherence"
# update MODIFICATION_TIME in HDF5 dataset "/connectComponent"
# Done.
#
# plot_network.py /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/ifgramStack.h5 -t /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg --nodisplay -d coherence -v 0.2 1.0
# read options from template file: smallbaselineApp.cfg
# read temporal/spatial baseline info from file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/ifgramStack.h5
# open ifgramStack file: ifgramStack.h5
# calculating spatial mean of coherence in file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/ifgramStack.h5 ...
# [==================================================] 100/100   1s /     0s
# write average value in space into text file: coherenceSpatialAvg.txt
# number of acquisitions: 17
# number of interferograms: 100
# shift all perp baseline by -133.13316345214844 to zero mean for plotting
# --------------------------------------------------
# number of interferograms marked as drop: 7
# number of interferograms marked as keep: 93
# number of acquisitions marked as drop: 0
# save figure to pbaseHistory.pdf
# save figure to coherenceMatrix.pdf
# save figure to coherenceHistory.pdf
# max perpendicular baseline: 239.08 m
# max temporal      baseline: 192.0 days
# showing coherence
# data range: [0.3797, 1.0]
# display range: [0.2, 1.0]
# save figure to network.pdf
# Go back to directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 15.5 secs

# %%
plot_network.main('inputs/ifgramStack.h5 -t smallbaselineApp.cfg --figsize 12 4'.split())
# Out:
# read options from template file: smallbaselineApp.cfg
# read temporal/spatial baseline info from file: inputs/ifgramStack.h5
# open ifgramStack file: ifgramStack.h5
# coherenceSpatialAvg.txt already exists, read it directly
# number of acquisitions: 17
# number of interferograms: 100
# shift all perp baseline by -133.13316345214844 to zero mean for plotting
# --------------------------------------------------
# number of interferograms marked as drop: 7
# number of interferograms marked as keep: 93
# number of acquisitions marked as drop: 0
# max perpendicular baseline: 239.08 m
# max temporal      baseline: 192.0 days
# showing coherence
# data range: [0.3797, 1.0]
# display range: (0.2, 1.0)
# showing ...

# %%
# !smallbaselineApp.py SenAT12.txt --dostep reference_point
# Out:
# MintPy version 1.5.2.post24, date 2023-10-10
# --RUN-at-2023-11-27 07:23:21.693096--
# Current directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# Run routine processing with smallbaselineApp.py on steps: ['reference_point']
# Remaining steps: ['quick_overview', 'correct_unwrap_error', 'invert_network', 'correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# read custom template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/SenAT12.txt
# update default template based on input custom template
# No new option value found, skip updating /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
# read default template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
#
#
# ******************** step - reference_point ********************
#
# generate_mask.py /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/ifgramStack.h5 --nonzero -o /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/maskConnComp.h5 --update
# input ifgramStack file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/ifgramStack.h5
# --------------------------------------------------
# update mode: ON
# 1) output file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/maskConnComp.h5 NOT exist.
# run or skip: run.
# calculate the common mask of pixels with non-zero connectComponent value
# [==================================================] 93/93    1s /     0s
# create HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/maskConnComp.h5 with w mode
# create dataset /mask of bool       in size of (1500, 1500)         with compression=None
# finished writing to /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/maskConnComp.h5
# time used: 00 mins 1.7 secs.
#
# temporal_average.py /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/ifgramStack.h5 --dataset coherence -o /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/avgSpatialCoh.h5 --update
# --------------------------------------------------
# update mode: ON
# 1) output file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/avgSpatialCoh.h5 NOT exist.
# run or skip: run.
# calculate the temporal average of coherence in file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/ifgramStack.h5 ...
# [==================================================] lines 1500/1500
# create HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/avgSpatialCoh.h5 with w mode
# create dataset /coherence of float32    in size of (1500, 1500)         with compression=None
# finished writing to /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/avgSpatialCoh.h5
# time used: 00 mins 1.5 secs
#
#
# reference_point.py /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/ifgramStack.h5 -t /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg -c /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/avgSpatialCoh.h5 --lookup /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/geometryRadar.h5
# --------------------------------------------------
# reading reference info from template: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
# input reference point in lat/lon: (27.904352, 86.870901)
# input reference point in y/x: (758, 316)
# mask: maskConnComp.h5
# --------------------------------------------------
# calculate the temporal average of unwrapPhase in file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/ifgramStack.h5 ...
# [==================================================] lines 1500/1500
# Add/update ref_x/y attribute to file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/ifgramStack.h5
# {'REF_Y': '758', 'REF_X': '316'}
# touch avgSpatialCoh.h5
# touch maskConnComp.h5
# Go back to directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 5.4 secs

# %%
view.main('maskConnComp.h5 -c gray --noverbose'.split())
# Out:
# view.py maskConnComp.h5 -c gray --noverbose

# %%
# !smallbaselineApp.py SenAT12.txt --dostep quick_overview
# Out:
# MintPy version 1.5.2.post24, date 2023-10-10
# --RUN-at-2023-11-27 07:23:30.182084--
# Current directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# Run routine processing with smallbaselineApp.py on steps: ['quick_overview']
# Remaining steps: ['correct_unwrap_error', 'invert_network', 'correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# read custom template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/SenAT12.txt
# update default template based on input custom template
# No new option value found, skip updating /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
# read default template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
#
#
# ******************** step - quick_overview ********************
#
# temporal_average.py /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/ifgramStack.h5 --dataset unwrapPhase -o /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/avgPhaseVelocity.h5 --update
# --------------------------------------------------
# update mode: ON
# 1) output file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/avgPhaseVelocity.h5 NOT exist.
# run or skip: run.
# calculate the temporal average of unwrapPhase in file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/ifgramStack.h5 ...
# [==================================================] lines 1500/1500
# create HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/avgPhaseVelocity.h5 with w mode
# create dataset /velocity of float32    in size of (1500, 1500)         with compression=None
# finished writing to /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/avgPhaseVelocity.h5
# time used: 00 mins 1.9 secs
#
#
# unwrap_error_phase_closure.py /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/ifgramStack.h5 --water-mask /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/waterMask.h5 --action calculate --update
# open ifgramStack file: ifgramStack.h5
# number of interferograms: 93
# number of triplets: 222
# calculating the number of triplets with non-zero integer ambiguity of closure phase ...
#     block by block with size up to (500, 1500), 3 blocks in total
# reference pixel in y/x: (758, 316) from dataset: unwrapPhase
# [==================================================] line 1000 / 1500  14s /     7s
# mask out pixels with zero in file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/avgSpatialCoh.h5
# write to file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/numTriNonzeroIntAmbiguity.h5
# create HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/numTriNonzeroIntAmbiguity.h5 with w mode
# create dataset /mask of float32    in size of (1500, 1500)         with compression=None
# finished writing to /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/numTriNonzeroIntAmbiguity.h5
# plot and save figure to file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/numTriNonzeroIntAmbiguity.png
# time used: 00 mins 23.5 secs
# Done.
# Go back to directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 26.5 secs

# %%
plot.plot_num_triplet_with_nonzero_integer_ambiguity('numTriNonzeroIntAmbiguity.h5', disp_fig=True, fig_size=[14, 4])
# Out:
# plot and save figure to file numTriNonzeroIntAmbiguity.png

# %%
# !smallbaselineApp.py SenAT12.txt --dostep correct_unwrap_error

# %%
# !smallbaselineApp.py SenAT12.txt --dostep invert_network
# Out:
# MintPy version 1.5.2.post24, date 2023-10-10
# --RUN-at-2023-11-27 07:24:00.849515--
# Current directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# Run routine processing with smallbaselineApp.py on steps: ['invert_network']
# Remaining steps: ['correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# read custom template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/SenAT12.txt
# update default template based on input custom template
# No new option value found, skip updating /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
# read default template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
#
#
# ******************** step - invert_network ********************
#
# ifgram_inversion.py /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/ifgramStack.h5 -t /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg --update
# read input option from template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
# use dataset "unwrapPhase" by default
# --------------------------------------------------
# update mode: ON
# 1) NOT ALL output files found: ['timeseries.h5', 'temporalCoherence.h5', 'numInvIfgram.h5'].
# run or skip: run.
# save the original settings of ['OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS', 'MKL_NUM_THREADS', 'NUMEXPR_NUM_THREADS', 'VECLIB_MAXIMUM_THREADS']
# set OMP_NUM_THREADS = 1
# set OPENBLAS_NUM_THREADS = 1
# set MKL_NUM_THREADS = 1
# set NUMEXPR_NUM_THREADS = 1
# set VECLIB_MAXIMUM_THREADS = 1
# reference pixel in y/x: (758, 316) from dataset: unwrapPhase
# -------------------------------------------------------------------------------
# least-squares solution with L2 min-norm on: deformation velocity
# minimum redundancy: 1.0
# weight function: var
# calculate covariance: False
# mask: no
# -------------------------------------------------------------------------------
# number of interferograms: 93
# number of acquisitions  : 17
# number of lines   : 1500
# number of columns : 1500
# --------------------------------------------------
# create HDF5 file: timeseries.h5 with w mode
# create dataset  : date       of |S8                       in size of (17,)                with compression = None
# create dataset  : bperp      of <class 'numpy.float32'>   in size of (17,)                with compression = None
# create dataset  : timeseries of <class 'numpy.float32'>   in size of (17, 1500, 1500)     with compression = None
# close  HDF5 file: timeseries.h5
# --------------------------------------------------
# create HDF5 file: temporalCoherence.h5 with w mode
# create dataset  : temporalCoherence of <class 'numpy.float32'>   in size of (1500, 1500)         with compression = None
# close  HDF5 file: temporalCoherence.h5
# --------------------------------------------------
# create HDF5 file: numInvIfgram.h5 with w mode
# create dataset  : mask of <class 'numpy.float32'>   in size of (1500, 1500)         with compression = None
# close  HDF5 file: numInvIfgram.h5
#
#
# ------- start parallel processing using Dask -------
# input Dask cluster type: local
# initiate Dask cluster
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#        usage information.
#
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# split patch into 4 sub boxes in x direction for workers to process
# scale Dask cluster to 4 workers
# initiate Dask client
# submit a job to the worker for sub box 0: [0, 0, 375, 1500]
# submit a job to the worker for sub box 1: [375, 0, 750, 1500]
# submit a job to the worker for sub box 2: [750, 0, 1125, 1500]
# submit a job to the worker for sub box 3: [1125, 0, 1500, 1500]
# calculating weight from spatial coherence ...
# reading coherence in [375, 0, 750, 1500] * 93 ...
# calculating weight from spatial coherence ...
# reading coherence in [0, 0, 375, 1500] * 93 ...
# calculating weight from spatial coherence ...
# reading coherence in [750, 0, 1125, 1500] * 93 ...
# calculating weight from spatial coherence ...
# reading coherence in [1125, 0, 1500, 1500] * 93 ...
# convert coherence to weight in chunks of 100000 pixels: 6 chunks in total ...
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=62
# chunk 1 / 6
# convert coherence to weight in chunks of 100000 pixels: 6 chunks in total ...
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=62
# convert coherence to weight in chunks of 100000 pixels: 6 chunks in total ...
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=62
# convert coherence to weight in chunks of 100000 pixels: 6 chunks in total ...
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=62
# chunk 2 / 6
# chunk 1 / 6
# chunk 1 / 6
# chunk 1 / 6
# chunk 3 / 6
# chunk 2 / 6
# chunk 2 / 6
# chunk 2 / 6
# chunk 3 / 6
# chunk 4 / 6
# chunk 3 / 6
# chunk 3 / 6
# chunk 4 / 6
# chunk 4 / 6
# chunk 5 / 6
# chunk 4 / 6
# chunk 6 / 6
# reading unwrapPhase in [375, 0, 750, 1500] * 93 ...
# chunk 5 / 6
# chunk 5 / 6
# chunk 5 / 6
# chunk 6 / 6
# chunk 6 / 6
# reading unwrapPhase in [750, 0, 1125, 1500] * 93 ...
# reading unwrapPhase in [1125, 0, 1500, 1500] * 93 ...
# chunk 6 / 6
# reading unwrapPhase in [0, 0, 375, 1500] * 93 ...
# use input reference value
# convert zero value in unwrapPhase to NaN (no-data value)
# skip pixels with unwrapPhase = NaN in all interferograms
# use input reference value
# use input reference value
# use input reference value
# skip pixels with zero value in file: avgSpatialCoh.h5
# number of pixels to invert: 562500 out of 562500 (100.0%)
# estimating time-series via WLS pixel-by-pixel ...
# convert zero value in unwrapPhase to NaN (no-data value)
# skip pixels with unwrapPhase = NaN in all interferograms
# convert zero value in unwrapPhase to NaN (no-data value)
# skip pixels with unwrapPhase = NaN in all interferograms
# convert zero value in unwrapPhase to NaN (no-data value)
# skip pixels with unwrapPhase = NaN in all interferograms
# [>                                                 ]skip pixels with zero value in file: avgSpatialCoh.h5
# skip pixels with zero value in file: avgSpatialCoh.h5
# skip pixels with zero value in file: avgSpatialCoh.h5
# number of pixels to invert: 562500 out of 562500 (100.0%)
# estimating time-series via WLS pixel-by-pixel ...
# number of pixels to invert: 562499 out of 562500 (100.0%)
# estimating time-series via WLS pixel-by-pixel ...
# [>                                                 ]number of pixels to invert: 562500 out of 562500 (100.0%)
# estimating time-series via WLS pixel-by-pixel ...
# [==================================================] 562500/562500 pixels  154s /     3s
# [======================= 98% ====================> ] 553400/562499 pixels  154s /     3sconverting LOS phase unit from radian to meter
# [==================================================] 555000/562500 pixels  154s /     3s
# FUTURE #1 complete. Time used: 159 seconds
# [==================================================] 562500/562500 pixels  155s /     3s
# converting LOS phase unit from radian to meter
# [==================================================] 561000/562499 pixels
# FUTURE #2 complete. Time used: 162 seconds
# [==================================================] 562499/562499 pixels
# converting LOS phase unit from radian to meter
# [==================================================] 560000/562500 pixels
# FUTURE #3 complete. Time used: 162 seconds
# [==================================================] 562500/562500 pixels
# converting LOS phase unit from radian to meter
#
# FUTURE #4 complete. Time used: 163 seconds
# close dask client
# close dask cluster
# ------- finished parallel processing -------
#
#
# --------------------------------------------------
# open  HDF5 file timeseries.h5 in a mode
# writing dataset /timeseries                block: [0, 17, 0, 1500, 0, 1500]
# close HDF5 file timeseries.h5.
# --------------------------------------------------
# open  HDF5 file temporalCoherence.h5 in a mode
# writing dataset /temporalCoherence         block: [0, 1500, 0, 1500]
# close HDF5 file temporalCoherence.h5.
# --------------------------------------------------
# open  HDF5 file numInvIfgram.h5 in a mode
# writing dataset /mask                      block: [0, 1500, 0, 1500]
# close HDF5 file numInvIfgram.h5.
# --------------------------------------------------
# update values on the reference pixel: (758, 316)
# set temporalCoherence on the reference pixel to 1.
# set  # of observations on the reference pixel as 93
# roll back to the original settings of ['OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS', 'MKL_NUM_THREADS', 'NUMEXPR_NUM_THREADS', 'VECLIB_MAXIMUM_THREADS']
# set OMP_NUM_THREADS = 16
# remove env variable OPENBLAS_NUM_THREADS
# remove env variable MKL_NUM_THREADS
# remove env variable NUMEXPR_NUM_THREADS
# remove env variable VECLIB_MAXIMUM_THREADS
# time used: 02 mins 49.2 secs.
#
#
# generate_mask.py /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/temporalCoherence.h5 -m 0.0 -o /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/maskTempCoh.h5 --base /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/geometryRadar.h5 --base-dataset shadowMask --base-value 1
# update mode: ON
# run or skip: run
# input temporalCoherence file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/temporalCoherence.h5
# read /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/temporalCoherence.h5
# create initial mask with the same size as the input file and all = 1
# all pixels with nan value = 0
# exclude pixels with value < 0.0
# exclude pixels in base file geometryRadar.h5 dataset shadowMask with value == 1.0
# create HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/maskTempCoh.h5 with w mode
# create dataset /mask of bool       in size of (1500, 1500)         with compression=None
# finished writing to /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/maskTempCoh.h5
# time used: 00 mins 0.2 secs.
# number of reliable pixels: 1363842
# Go back to directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 02 mins 50.5 secs

# %%
view.main('avgSpatialCoh.h5 --noverbose'.split())
view.main('temporalCoherence.h5 --noverbose'.split())
# Out:
# view.py avgSpatialCoh.h5 --noverbose
# view.py temporalCoherence.h5 --noverbose

# %%
view.main('timeseries.h5 -v -5 5 --noaxis'.split())
# equivalent command in terminal: view.py timeseries.h5 -v -5 5 --noaxis
# Out:
# run view.py in MintPy version 1.5.2.post24, date 2023-10-10
# input file is timeseries file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries.h5 in float32 format
# file size in y/x: (1500, 1500)
# num of datasets in file timeseries.h5: 17
# datasets to exclude (0):
# []
# datasets to display (17):
# ['timeseries-20191004', 'timeseries-20191016', 'timeseries-20191028', 'timeseries-20191109', 'timeseries-20191121', 'timeseries-20191203', 'timeseries-20191215', 'timeseries-20191227', 'timeseries-20200108', 'timeseries-20200120', 'timeseries-20200201', 'timeseries-20200213', 'timeseries-20200225', 'timeseries-20200308', 'timeseries-20200320', 'timeseries-20200401', 'timeseries-20200413']
# data   coverage in y/x: (0, 0, 1500, 1500)
# subset coverage in y/x: (0, 0, 1500, 1500)
# data   coverage in lat/lon: None
# subset coverage in lat/lon: None
# ------------------------------------------------------------------------
# colormap: jet
# ASCENDING orbit -> flip up-down
# figure title: timeseries
# figure size : [15.00, 8.00]
# dataset number: 17
# row     number: 3
# column  number: 6
# figure  number: 1
# read mask from file: maskTempCoh.h5
# ----------------------------------------
# Figure 1 - timeseries.png
# reading data as a 3D matrix ...
# data    range: [-4876.076, 2690.363] cm
# display range: [-5.0, 5.0] cm
# masking data
# plotting ...
# [==================================================] timeseries-20200413    0s /     0s
# data    range: [-3494.0315, 2367.821] cm
# display range: [-5.0, 5.0] cm
# show colorbar
# showing ...

# %%
# !smallbaselineApp.py SenAT12.txt --dostep deramp
# Out:
# MintPy version 1.5.2.post24, date 2023-10-10
# --RUN-at-2023-11-27 07:26:58.708600--
# Current directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# Run routine processing with smallbaselineApp.py on steps: ['deramp']
# Remaining steps: ['correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# read custom template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/SenAT12.txt
# update default template based on input custom template
# No new option value found, skip updating /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
# read default template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
#
#
# ******************** step - deramp ********************
# Remove for each acquisition a phase ramp: linear
#
# remove_ramp.py /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries.h5 -s linear -m maskTempCoh.h5 -o /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries_ramp.h5 --update
# --------------------------------------------------
# update mode: ON
# 1) output file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries_ramp.h5 NOT found.
# run or skip: run.
# remove linear ramp from file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries.h5
# read mask file: maskTempCoh.h5
# --------------------------------------------------
# grab metadata from ref_file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries.h5
# grab dataset structure from ref_file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries.h5
# create HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries_ramp.h5 with w mode
# create dataset  : bperp      of float32                   in size of (17,)                with compression = None
# create dataset  : date       of |S8                       in size of (17,)                with compression = None
# create dataset  : timeseries of float32                   in size of (17, 1500, 1500)     with compression = None
# close  HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries_ramp.h5
# estimating phase ramp one date at a time ...
# [==================================================] 17/17    6s /     0s
# finished writing to file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries_ramp.h5
# add/update the following metadata to file:
# add/update mintpy.deramp = linear
# add/update mintpy.deramp.maskFile = maskTempCoh.h5
# time used: 00 mins 7.4 secs.
# Go back to directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 7.5 secs

# %%
# !smallbaselineApp.py SenAT12.txt --dostep correct_topography
# Out:
# MintPy version 1.5.2.post24, date 2023-10-10
# --RUN-at-2023-11-27 07:27:08.391764--
# Current directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# Run routine processing with smallbaselineApp.py on steps: ['correct_topography']
# Remaining steps: ['residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# read custom template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/SenAT12.txt
# update default template based on input custom template
# No new option value found, skip updating /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
# read default template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
#
#
# ******************** step - correct_topography ********************
#
# dem_error.py /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries_ramp.h5 -t /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg -o /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries_ramp_demErr.h5 --update -g /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/geometryRadar.h5
# read options from template file: smallbaselineApp.cfg
# --------------------------------------------------
# update mode: ON
# 1) output file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries_ramp_demErr.h5 NOT found.
# run or skip: run.
# save the original settings of ['OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS', 'MKL_NUM_THREADS', 'NUMEXPR_NUM_THREADS', 'VECLIB_MAXIMUM_THREADS']
# set OMP_NUM_THREADS = 1
# set OPENBLAS_NUM_THREADS = 1
# set MKL_NUM_THREADS = 1
# set NUMEXPR_NUM_THREADS = 1
# set VECLIB_MAXIMUM_THREADS = 1
# open timeseries file: timeseries_ramp.h5
# --------------------------------------------------------------------------------
# correct topographic phase residual (DEM error) (Fattahi & Amelung, 2013, IEEE-TGRS)
# ordinal least squares (OLS) inversion with L2-norm minimization on: phase
# temporal deformation model: polynomial order = 2
# --------------------------------------------------------------------------------
# add/update the following configuration metadata to file:
# ['polyOrder', 'phaseVelocity', 'stepFuncDate', 'excludeDate']
# --------------------------------------------------
# create HDF5 file: demErr.h5 with w mode
# create dataset  : dem of <class 'numpy.float32'>   in size of (1500, 1500)         with compression = None
# close  HDF5 file: demErr.h5
# --------------------------------------------------
# grab dataset structure from ref_file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries_ramp.h5
# create HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries_ramp_demErr.h5 with w mode
# create dataset  : bperp      of float32                   in size of (17,)                with compression = None
# create dataset  : date       of |S8                       in size of (17,)                with compression = None
# create dataset  : timeseries of float32                   in size of (17, 1500, 1500)     with compression = None
# close  HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries_ramp_demErr.h5
# --------------------------------------------------
# grab dataset structure from ref_file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries_ramp.h5
# create HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseriesResidual.h5 with w mode
# create dataset  : bperp      of float32                   in size of (17,)                with compression = None
# create dataset  : date       of |S8                       in size of (17,)                with compression = None
# create dataset  : timeseries of float32                   in size of (17, 1500, 1500)     with compression = None
# close  HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseriesResidual.h5
#
#
# ------- start parallel processing using Dask -------
# input Dask cluster type: local
# initiate Dask cluster
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help` for
#        usage information.
#
# split patch into 4 sub boxes in x direction for workers to process
# scale Dask cluster to 4 workers
# initiate Dask client
# submit a job to the worker for sub box 0: [0, 0, 375, 1500]
# submit a job to the worker for sub box 1: [375, 0, 750, 1500]
# submit a job to the worker for sub box 2: [750, 0, 1125, 1500]
# submit a job to the worker for sub box 3: [1125, 0, 1500, 1500]
# open geometry file: geometryRadar.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryRadar.h5
# open geometry file: geometryRadar.h5
# open geometry file: geometryRadar.h5
# open geometry file: geometryRadar.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryRadar.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryRadar.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryRadar.h5
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# read mean bperp from timeseries file
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with ZERO in ALL acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# skip pixels with NaN  in ANY acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 562500 out of 562500 (100.0%)
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 562500 out of 562500 (100.0%)
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 562499 out of 562500 (100.0%)
# estimating DEM error pixel-wisely ...
# number of pixels to invert: 562500 out of 562500 (100.0%)
# estimating DEM error pixel-wisely ...
# [==================================================] 562500/562500   55s /     1s
#
# FUTURE #1 complete. Time used: 57 seconds
# [==================================================] 562500/562500   56s /     1s
#
# FUTURE #2 complete. Time used: 57 seconds
# [==================================================] 562500/562500
#
# FUTURE #3 complete. Time used: 58 seconds
# [==================================================] 562499/562499
#
# FUTURE #4 complete. Time used: 58 seconds
# close dask client
# close dask cluster
# ------- finished parallel processing -------
#
#
# --------------------------------------------------
# open  HDF5 file demErr.h5 in a mode
# writing dataset /dem                       block: [0, 1500, 0, 1500]
# close HDF5 file demErr.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries_ramp_demErr.h5 in a mode
# writing dataset /timeseries                block: [0, 17, 0, 1500, 0, 1500]
# close HDF5 file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries_ramp_demErr.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseriesResidual.h5 in a mode
# writing dataset /timeseries                block: [0, 17, 0, 1500, 0, 1500]
# close HDF5 file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseriesResidual.h5.
# roll back to the original settings of ['OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS', 'MKL_NUM_THREADS', 'NUMEXPR_NUM_THREADS', 'VECLIB_MAXIMUM_THREADS']
# set OMP_NUM_THREADS = 16
# remove env variable OPENBLAS_NUM_THREADS
# remove env variable MKL_NUM_THREADS
# remove env variable NUMEXPR_NUM_THREADS
# remove env variable VECLIB_MAXIMUM_THREADS
# time used: 01 mins 4.7 secs.
# Go back to directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 01 mins 4.9 secs

# %%
# !smallbaselineApp.py SenAT12.txt --dostep residual_RMS
# Out:
# MintPy version 1.5.2.post24, date 2023-10-10
# --RUN-at-2023-11-27 07:28:15.735447--
# Current directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# Run routine processing with smallbaselineApp.py on steps: ['residual_RMS']
# Remaining steps: ['reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# read custom template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/SenAT12.txt
# update default template based on input custom template
# No new option value found, skip updating /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
# read default template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
#
#
# ******************** step - residual_RMS ********************
#
# timeseries_rms.py timeseriesResidual.h5 -t /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
# read options from template file: smallbaselineApp.cfg
# remove quadratic ramp from file: timeseriesResidual.h5
# read mask file: maskTempCoh.h5
# --------------------------------------------------
# grab metadata from ref_file: timeseriesResidual.h5
# grab dataset structure from ref_file: timeseriesResidual.h5
# create HDF5 file: timeseriesResidual_ramp.h5 with w mode
# create dataset  : bperp      of float32                   in size of (17,)                with compression = None
# create dataset  : date       of |S8                       in size of (17,)                with compression = None
# create dataset  : timeseries of float32                   in size of (17, 1500, 1500)     with compression = None
# close  HDF5 file: timeseriesResidual_ramp.h5
# estimating phase ramp one date at a time ...
# [==================================================] 17/17    9s /     0s
# finished writing to file: timeseriesResidual_ramp.h5
# time used: 00 mins 10.4 secs.
#
# calculating residual RMS for each epoch from file: timeseriesResidual_ramp.h5
# read mask from file: maskTempCoh.h5
# reading timeseries data from file: timeseriesResidual_ramp.h5 ...
# [==================================================] 17/17    2s /     0s
# save timeseries RMS to text file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/rms_timeseriesResidual_ramp.txt
# read timeseries residual RMS from file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/rms_timeseriesResidual_ramp.txt
# --------------------------------------------------
# date with min RMS: 20191004 - 0.5627
# save date to file: reference_date.txt
# --------------------------------------------------
# date(s) with RMS > 3.0 * median RMS (3.7402)
# None.
# save figure to file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/rms_timeseriesResidual_ramp.pdf
# Go back to directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 13.8 secs

# %%
# !smallbaselineApp.py SenAT12.txt --dostep reference_date
# Out:
# MintPy version 1.5.2.post24, date 2023-10-10
# --RUN-at-2023-11-27 07:28:31.753431--
# Current directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# Run routine processing with smallbaselineApp.py on steps: ['reference_date']
# Remaining steps: ['velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# read custom template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/SenAT12.txt
# update default template based on input custom template
# No new option value found, skip updating /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
# read default template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
#
#
# ******************** step - reference_date ********************
# No reference date change.
# Go back to directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 0.0 secs

# %%
# !smallbaselineApp.py SenAT12.txt --dostep velocity
# Out:
# MintPy version 1.5.2.post24, date 2023-10-10
# --RUN-at-2023-11-27 07:28:33.886775--
# Current directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# Run routine processing with smallbaselineApp.py on steps: ['velocity']
# Remaining steps: ['geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# read custom template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/SenAT12.txt
# update default template based on input custom template
# No new option value found, skip updating /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
# read default template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
#
#
# ******************** step - velocity ********************
#
# timeseries2velocity.py /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries_ramp_demErr.h5 -t /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg -o /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/velocity.h5 --update
# read options from template file: smallbaselineApp.cfg
# update mode: ON
# 1) output file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/velocity.h5 NOT found.
# run or skip: run.
# open timeseries file: timeseries_ramp_demErr.h5
# exclude date: []
# --------------------------------------------------
# dates from input file: 17
# ['20191004', '20191016', '20191028', '20191109', '20191121', '20191203', '20191215', '20191227', '20200108', '20200120', '20200201', '20200213', '20200225', '20200308', '20200320', '20200401', '20200413']
# --------------------------------------------------
# using all dates to calculate the time function
# --------------------------------------------------
# estimate deformation model with the following assumed time functions:
#     polynomial : 1
#     periodic   : []
#     stepDate   : []
#     polyline   : []
#     exp        : {}
#     log        : {}
# add/update the following configuration metadata:
# ['startDate', 'endDate', 'excludeDate', 'polynomial', 'periodic', 'stepDate', 'exp', 'log', 'uncertaintyQuantification', 'timeSeriesCovFile', 'bootstrapCount']
# --------------------------------------------------
# create HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/velocity.h5 with w mode
# create dataset  : intercept    of <class 'numpy.float32'>   in size of (1500, 1500)         with compression = None
# create dataset  : interceptStd of <class 'numpy.float32'>   in size of (1500, 1500)         with compression = None
# create dataset  : velocity     of <class 'numpy.float32'>   in size of (1500, 1500)         with compression = None
# create dataset  : velocityStd  of <class 'numpy.float32'>   in size of (1500, 1500)         with compression = None
# create dataset  : residue      of <class 'numpy.float32'>   in size of (1500, 1500)         with compression = None
# add /intercept    attribute: UNIT = m
# add /interceptStd attribute: UNIT = m
# add /velocity     attribute: UNIT = m/year
# add /velocityStd  attribute: UNIT = m/year
# add /residue      attribute: UNIT = m
# close  HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/velocity.h5
# reading data from file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries_ramp_demErr.h5 ...
# skip pixels with zero/nan value in all acquisitions
# number of pixels to invert: 2250000 out of 2250000 (100.0%)
# estimating time functions via linalg.lstsq ...
# estimating time functions STD from time-series fitting residual ...
# --------------------------------------------------
# open  HDF5 file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/velocity.h5 in a mode
# writing dataset /intercept                 block: [0, 1500, 0, 1500]
# close HDF5 file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/velocity.h5 in a mode
# writing dataset /interceptStd              block: [0, 1500, 0, 1500]
# close HDF5 file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/velocity.h5 in a mode
# writing dataset /velocity                  block: [0, 1500, 0, 1500]
# close HDF5 file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/velocity.h5 in a mode
# writing dataset /velocityStd               block: [0, 1500, 0, 1500]
# close HDF5 file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/velocity.h5 in a mode
# writing dataset /residue                   block: [0, 1500, 0, 1500]
# close HDF5 file /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/velocity.h5.
# time used: 00 mins 2.3 secs.
# Go back to directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 2.3 secs

# %%
view.main('velocity.h5 --noverbose --vlim -10 10 -c RdBu'.split())
# Out:
# view.py velocity.h5 --noverbose --vlim -10 10 -c RdBu

# %%
# !smallbaselineApp.py SenAT12.txt --dostep geocode
# Out:
# MintPy version 1.5.2.post24, date 2023-10-10
# --RUN-at-2023-11-27 07:36:52.892362--
# Current directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# Run routine processing with smallbaselineApp.py on steps: ['geocode']
# Remaining steps: ['google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
# read custom template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/SenAT12.txt
# update default template based on input custom template
#     mintpy.geocode.interpMethod: linear --> auto
# copy SenAT12.txt          to inputs   directory for backup.
# copy smallbaselineApp.cfg to inputs   directory for backup.
# copy SenAT12.txt          to pic      directory for backup.
# copy smallbaselineApp.cfg to pic      directory for backup.
# read default template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
#
#
# ******************** step - geocode ********************
#
# geocode.py /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/geometryRadar.h5 temporalCoherence.h5 avgSpatialCoh.h5 /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries_ramp_demErr.h5 velocity.h5 -l /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/geometryRadar.h5 -t /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg --outdir /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo --update
# read input option from template file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/smallbaselineApp.cfg
# number of processor to be used: 1
# resampling software: pyresample
# read latitude / longitude from lookup table file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/geometryRadar.h5
# output pixel size in (lat, lon) in degree: (-9.2593e-05, 9.2593e-05)
# output area extent in (S, N, W, E) in degree: (27.801466605361327, 28.036930604361327, 86.71933694324609, 87.1446165922461)
# output file row / column number: (2543, 4593)
# [1/1] preparing geometry for dest_box: (0, 0, 4593, 2543) --> full src_box: (0, 0, 1500, 1500)
# --------------------------------------------------
# resampling file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/geometryRadar.h5
# update mode: ON
# --------------------------------------------------
# grab dataset structure from ref_file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/inputs/geometryRadar.h5
# create HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_geometryRadar.h5 with w mode
# create dataset  : azimuthAngle       of float32                   in size of (2543, 4593)         with compression = lzf
# create dataset  : height             of float32                   in size of (2543, 4593)         with compression = lzf
# create dataset  : incidenceAngle     of float32                   in size of (2543, 4593)         with compression = lzf
# create dataset  : latitude           of float32                   in size of (2543, 4593)         with compression = lzf
# create dataset  : longitude          of float32                   in size of (2543, 4593)         with compression = lzf
# create dataset  : shadowMask         of bool                      in size of (2543, 4593)         with compression = lzf
# create dataset  : slantRangeDistance of float32                   in size of (2543, 4593)         with compression = lzf
# close  HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_geometryRadar.h5
# --------------------------------------------------1/1
# reading azimuthAngle       in block (0, 0, 1500, 1500) from geometryRadar.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 13 segments ...
# write data in block [0, 2543, 0, 4593] to file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_geometryRadar.h5
# --------------------------------------------------1/1
# reading height             in block (0, 0, 1500, 1500) from geometryRadar.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 13 segments ...
# write data in block [0, 2543, 0, 4593] to file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_geometryRadar.h5
# --------------------------------------------------1/1
# reading incidenceAngle     in block (0, 0, 1500, 1500) from geometryRadar.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 13 segments ...
# write data in block [0, 2543, 0, 4593] to file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_geometryRadar.h5
# --------------------------------------------------1/1
# reading latitude           in block (0, 0, 1500, 1500) from geometryRadar.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 13 segments ...
# write data in block [0, 2543, 0, 4593] to file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_geometryRadar.h5
# --------------------------------------------------1/1
# reading longitude          in block (0, 0, 1500, 1500) from geometryRadar.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 13 segments ...
# write data in block [0, 2543, 0, 4593] to file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_geometryRadar.h5
# --------------------------------------------------1/1
# reading shadowMask         in block (0, 0, 1500, 1500) from geometryRadar.h5 ...
# input source data is bool type, restrict fill_value to False.
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 13 segments ...
# write data in block [0, 2543, 0, 4593] to file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_geometryRadar.h5
# --------------------------------------------------1/1
# reading slantRangeDistance in block (0, 0, 1500, 1500) from geometryRadar.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 13 segments ...
# write data in block [0, 2543, 0, 4593] to file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_geometryRadar.h5
# --------------------------------------------------
# resampling file: temporalCoherence.h5
# update mode: ON
# update REF_LAT/LON/Y/X
# --------------------------------------------------
# grab dataset structure from ref_file: temporalCoherence.h5
# create HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_temporalCoherence.h5 with w mode
# create dataset  : temporalCoherence of float32                   in size of (2543, 4593)         with compression = None
# close  HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_temporalCoherence.h5
# --------------------------------------------------1/1
# reading temporalCoherence in block (0, 0, 1500, 1500) from temporalCoherence.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 13 segments ...
# write data in block [0, 2543, 0, 4593] to file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_temporalCoherence.h5
# --------------------------------------------------
# resampling file: avgSpatialCoh.h5
# update mode: ON
# --------------------------------------------------
# grab dataset structure from ref_file: avgSpatialCoh.h5
# create HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_avgSpatialCoh.h5 with w mode
# create dataset  : coherence of float32                   in size of (2543, 4593)         with compression = None
# close  HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_avgSpatialCoh.h5
# --------------------------------------------------1/1
# reading coherence in block (0, 0, 1500, 1500) from avgSpatialCoh.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 13 segments ...
# write data in block [0, 2543, 0, 4593] to file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_avgSpatialCoh.h5
# --------------------------------------------------
# resampling file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries_ramp_demErr.h5
# update mode: ON
# update REF_LAT/LON/Y/X
# --------------------------------------------------
# grab dataset structure from ref_file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/timeseries_ramp_demErr.h5
# create HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_timeseries_ramp_demErr.h5 with w mode
# create dataset  : bperp      of float32                   in size of (17,)                with compression = None
# create dataset  : date       of |S8                       in size of (17,)                with compression = None
# create dataset  : timeseries of float32                   in size of (17, 2543, 4593)     with compression = None
# close  HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_timeseries_ramp_demErr.h5
# --------------------------------------------------1/1
# reading timeseries in block (0, 0, 1500, 1500) from timeseries_ramp_demErr.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 13 segments ...
# write data in block [0, 17, 0, 2543, 0, 4593] to file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_timeseries_ramp_demErr.h5
# --------------------------------------------------
# resampling file: velocity.h5
# update mode: ON
# update REF_LAT/LON/Y/X
# --------------------------------------------------
# grab dataset structure from ref_file: velocity.h5
# create HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_velocity.h5 with w mode
# create dataset  : intercept    of float32                   in size of (2543, 4593)         with compression = None
# create dataset  : interceptStd of float32                   in size of (2543, 4593)         with compression = None
# create dataset  : residue      of float32                   in size of (2543, 4593)         with compression = None
# create dataset  : velocity     of float32                   in size of (2543, 4593)         with compression = None
# create dataset  : velocityStd  of float32                   in size of (2543, 4593)         with compression = None
# add /intercept    attribute: UNIT = m
# add /interceptStd attribute: UNIT = m
# add /residue      attribute: UNIT = m
# add /velocity     attribute: UNIT = m/year
# add /velocityStd  attribute: UNIT = m/year
# close  HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_velocity.h5
# --------------------------------------------------1/1
# reading velocity     in block (0, 0, 1500, 1500) from velocity.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 13 segments ...
# write data in block [0, 2543, 0, 4593] to file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_velocity.h5
# --------------------------------------------------1/1
# reading velocityStd  in block (0, 0, 1500, 1500) from velocity.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 13 segments ...
# write data in block [0, 2543, 0, 4593] to file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_velocity.h5
# --------------------------------------------------1/1
# reading intercept    in block (0, 0, 1500, 1500) from velocity.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 13 segments ...
# write data in block [0, 2543, 0, 4593] to file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_velocity.h5
# --------------------------------------------------1/1
# reading interceptStd in block (0, 0, 1500, 1500) from velocity.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 13 segments ...
# write data in block [0, 2543, 0, 4593] to file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_velocity.h5
# --------------------------------------------------1/1
# reading residue      in block (0, 0, 1500, 1500) from velocity.h5 ...
# nearest resampling with pyresample.kd_tree using 1 CPU cores in 13 segments ...
# write data in block [0, 2543, 0, 4593] to file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_velocity.h5
# time used: 01 mins 1.9 secs.
#
#
# generate_mask.py /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_temporalCoherence.h5 -m 0.0 -o /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_maskTempCoh.h5 --base /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_geometryRadar.h5 --base-dataset shadowMask --base-value 1
# input temporalCoherence file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_temporalCoherence.h5
# read /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_temporalCoherence.h5
# create initial mask with the same size as the input file and all = 1
# all pixels with nan value = 0
# exclude pixels with value < 0.0
# exclude pixels in base file geo_geometryRadar.h5 dataset shadowMask with value == 1.0
# create HDF5 file: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_maskTempCoh.h5 with w mode
# create dataset /mask of bool       in size of (2543, 4593)         with compression=None
# finished writing to /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion/geo/geo_maskTempCoh.h5
# time used: 00 mins 0.8 secs.
# Go back to directory: /mnt/Backups/gbrench/repos/fusits/nbs/imja/agu_push/AT12/mintpy_fusion
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 01 mins 3.0 secs

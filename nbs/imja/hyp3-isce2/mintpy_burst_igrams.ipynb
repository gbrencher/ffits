# %%
# Import required packages
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from osgeo import gdal, gdal_array
from datetime import datetime, timedelta
import xarray as xr
import rasterio as rio
import rioxarray
import geopandas as gpd
import time
from glob import glob
import scipy.signal
from mintpy.utils import readfile, writefile, utils as ut, plot
from mintpy.cli import view, tsview, plot_network, plot_transection
from mintpy.view import prep_slice, plot_slice
from pathlib import Path
from typing import List, Union

# %%
def get_common_overlap(file_list: List[Union[str, Path]]) -> List[float]:
    """Get the common overlap of  a list of GeoTIFF files
    
    Arg:
        file_list: a list of GeoTIFF files
    
    Returns:
         [ulx, uly, lrx, lry], the upper-left x, upper-left y, lower-right x, and lower-right y
         corner coordinates of the common overlap
    """
    
    corners = [gdal.Info(str(dem), format='json')['cornerCoordinates'] for dem in file_list]

    ulx = max(corner['upperLeft'][0] for corner in corners)
    uly = min(corner['upperLeft'][1] for corner in corners)
    lrx = min(corner['lowerRight'][0] for corner in corners)
    lry = max(corner['lowerRight'][1] for corner in corners)
    return [ulx, uly, lrx, lry]

# %%
def clip_hyp3_products_to_common_overlap(data_path: Union[str, Path], overlap: List[float]) -> None:
    """Clip all GeoTIFF files to their common overlap
    
    Args:
        data_dir:
            directory containing the GeoTIFF files to clip
        overlap:
            a list of the upper-left x, upper-left y, lower-right-x, and lower-tight y
            corner coordinates of the common overlap
    Returns: None
    """
    
    files_for_mintpy = ['_conncomp.tif', '_corr.tif', '_unw_phase.tif', '_dem.tif', '_lv_theta.tif', '_lv_phi.tif']

    for extension in files_for_mintpy:
        print(f'working on {extension}') 
        for file in data_path.rglob(f'*{extension}'):

            dst_file = file.parent / f'{file.stem}_clipped{file.suffix}'

            gdal.Translate(destName=str(dst_file), srcDS=str(file), projWin=overlap)

# %%
mintpy_path = '/mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams'

# %%
data_path = '/mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/data'
phase_files = Path(data_path).glob('*/*/*_unw_phase.tif')
overlap = get_common_overlap(phase_files)
clip_hyp3_products_to_common_overlap(Path(data_path), overlap)
# Out:
# /home/gbrench/sw/miniconda3/envs/mintpy/lib/python3.11/site-packages/osgeo/gdal.py:287: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# working on _conncomp.tif
# working on _corr.tif
# working on _unw_phase.tif
# working on _dem.tif
# working on _lv_theta.tif
# working on _lv_phi.tif

# %%
# Function to write to MintPy config file
def write_config_file(out_file, CONFIG_TXT, mode='a'): 
    """Write configuration files for MintPy to process products"""
    if not os.path.isfile(out_file) or mode == 'w':
        with open(out_file, "w") as fid:
            fid.write(CONFIG_TXT)
        print('write configuration to file: {}'.format(out_file))
    else:
        with open(out_file, "a") as fid:
            fid.write("\n" + CONFIG_TXT)
        print('add the following to file: \n{}'.format(CONFIG_TXT))

# %%
CONFIG_TXT = f'''
# vim: set filetype=cfg:
##------------------------ smallbaselineApp.cfg ------------------------##
########## computing resource configuration
mintpy.compute.maxMemory = 10 #auto for 4, max memory to allocate in GB
## parallel processing with dask
## currently apply to steps: invert_network, correct_topography
## cluster   = none to turn off the parallel computing
## numWorker = all  to use all of locally available cores (for cluster = local only)
## numWorker = 80%  to use 80% of locally available cores (for cluster = local only)
## config    = none to rollback to the default name (same as the cluster type; for cluster != local)
mintpy.compute.cluster   = local #[local / slurm / pbs / lsf / none], auto for none, cluster type
mintpy.compute.numWorker = 4 #[int > 1 / all / num%], auto for 4 (local) or 40 (slurm / pbs / lsf), num of workers
mintpy.compute.config    = auto #[none / slurm / pbs / lsf ], auto for none (same as cluster), config name


########## 1. load_data
##---------add attributes manually
## MintPy requires attributes listed at: https://mintpy.readthedocs.io/en/latest/api/attributes/
## Missing attributes can be added below manually (uncomment #), e.g.
# ORBIT_DIRECTION = ascending
# PLATFORM = Sen
# ...
## a. autoPath - automatic path pattern defined in mintpy.defaults.auto_path.AUTO_PATH_*
## b. load_data.py -H to check more details and example inputs.
## c. compression to save disk usage for ifgramStack.h5 file:
## no   - save   0% disk usage, fast [default]
## lzf  - save ~57% disk usage, relative slow
## gzip - save ~62% disk usage, very slow [not recommend]
mintpy.load.processor       = hyp3 #[isce, aria, hyp3, gmtsar, snap, gamma, roipac, nisar], auto for isce
mintpy.load.autoPath        = auto  #[yes / no], auto for no, use pre-defined auto path
mintpy.load.updateMode      = auto  #[yes / no], auto for yes, skip re-loading if HDF5 files are complete
mintpy.load.compression     = auto  #[gzip / lzf / no], auto for no.
##---------interferogram stack:
mintpy.load.unwFile         = ../data/*/*/S1*unw_phase_clipped.tif  #[path pattern of unwrapped interferogram files]
mintpy.load.corFile         = ../data/*/*/S1*corr_clipped.tif  #[path pattern of spatial coherence       files]
mintpy.load.connCompFile    = ../data/*/*/S1*conncomp_clipped.tif  #[path pattern of connected components    files], optional but recommended
##---------geometry:
mintpy.load.demFile         = ../data/*/*/S1*dem_clipped.tif   #[path of DEM file]
mintpy.load.incAngleFile    = ../data/*/*/S1*lv_theta_clipped.tif   #[path of incidence angle file], optional but recommended
mintpy.load.azAngleFile     = ../data/*/*/S1*lv_phi_clipped.tif   #[path of azimuth   angle file], optional
########## 2. modify_network
## 1) Network modification based on temporal/perpendicular baselines, date, num of connections etc.
mintpy.network.tempBaseMax     = 24  #[1-inf, no], auto for no, max temporal baseline in days
mintpy.network.perpBaseMax     = 150  #[1-inf, no], auto for no, max perpendicular spatial baseline in meter
mintpy.network.connNumMax      = auto  #[1-inf, no], auto for no, max number of neighbors for each acquisition
mintpy.network.startDate       = auto  #[20090101 / no], auto for no
mintpy.network.endDate         = auto  #[20110101 / no], auto for no
mintpy.network.excludeDate     = auto  #[20080520,20090817 / no], auto for no
mintpy.network.excludeIfgIndex = auto  #[1:5,25 / no], auto for no, list of ifg index (start from 0)
mintpy.network.referenceFile   = auto  #[date12_list.txt / ifgramStack.h5 / no], auto for no

## 2) Data-driven network modification
## a - Coherence-based network modification = (threshold + MST) by default
## reference: Yunjun et al. (2019, section 4.2 and 5.3.1); Chaussard et al. (2015, GRL)
## It calculates a average coherence for each interferogram using spatial coherence based on input mask (with AOI)
## Then it finds a minimum spanning tree (MST) network with inverse of average coherence as weight (keepMinSpanTree)
## Next it excludes interferograms if a) the average coherence < minCoherence AND b) not in the MST network.
mintpy.network.coherenceBased  = auto  #[yes / no], auto for no, exclude interferograms with coherence < minCoherence
mintpy.network.minCoherence    = auto  #[0.0-1.0], auto for 0.7

## b - Effective Coherence Ratio network modification = (threshold + MST) by default
## reference: Kang et al. (2021, RSE)
## It calculates the area ratio of each interferogram that is above a spatial coherence threshold.
## This threshold is defined as the spatial coherence of the interferograms within the input mask.
## It then finds a minimum spanning tree (MST) network with inverse of the area ratio as weight (keepMinSpanTree)
## Next it excludes interferograms if a) the area ratio < minAreaRatio AND b) not in the MST network.
mintpy.network.areaRatioBased  = auto  #[yes / no], auto for no, exclude interferograms with area ratio < minAreaRatio
mintpy.network.minAreaRatio    = auto  #[0.0-1.0], auto for 0.75

## Additional common parameters for the 2) data-driven network modification
mintpy.network.keepMinSpanTree = auto  #[yes / no], auto for yes, keep interferograms in Min Span Tree network
mintpy.network.maskFile        = auto  #[file name, no], auto for waterMask.h5 or no [if no waterMask.h5 found]
mintpy.network.aoiYX           = auto  #[y0:y1,x0:x1 / no], auto for no, area of interest for coherence calculation
mintpy.network.aoiLALO         = auto  #[S:N,W:E / no], auto for no - use the whole area


########## 3. reference_point
## Reference all interferograms to one common point in space
## auto - randomly select a pixel with coherence > minCoherence
## however, manually specify using prior knowledge of the study area is highly recommended
##   with the following guideline (section 4.3 in Yunjun et al., 2019):
## 1) located in a coherence area, to minimize the decorrelation effect.
## 2) not affected by strong atmospheric turbulence, i.e. ionospheric streaks
## 3) close to and with similar elevation as the AOI, to minimize the impact of spatially correlated atmospheric delay
mintpy.reference.yx            = auto   #[257,151 / auto]
mintpy.reference.lalo          = 3087261.5,489428.3 # 28.003585, 88.480191  #[31.8,130.8 / auto]
mintpy.reference.maskFile      = auto   #[filename / no], auto for maskConnComp.h5
mintpy.reference.coherenceFile = auto   #[filename], auto for avgSpatialCoh.h5
mintpy.reference.minCoherence  = auto   #[0.0-1.0], auto for 0.85, minimum coherence for auto method


########## quick_overview
## A quick assessment of:
## 1) possible groud deformation
##    using the velocity from the traditional interferogram stacking
##    reference: Zebker et al. (1997, JGR)
## 2) distribution of phase unwrapping error
##    from the number of interferogram triplets with non-zero integer ambiguity of closue phase
##    reference: T_int in Yunjun et al. (2019, CAGEO). Related to section 3.2, equation (8-9) and Fig. 3d-e.


########## 4. correct_unwrap_error (optional)
## connected components (mintpy.load.connCompFile) are required for this step.
## SNAPHU (Chem & Zebker,2001) is currently the only unwrapper that provides connected components as far as we know.
## reference: Yunjun et al. (2019, section 3)
## supported methods:
## a. phase_closure          - suitable for highly redundant network
## b. bridging               - suitable for regions separated by narrow decorrelated features, e.g. rivers, narrow water bodies
## c. bridging+phase_closure - recommended when there is a small percentage of errors left after bridging
mintpy.unwrapError.method          = bridging  #[bridging / phase_closure / bridging+phase_closure / no], auto for no
mintpy.unwrapError.waterMaskFile   = auto  #[waterMask.h5 / no], auto for waterMask.h5 or no [if not found]
mintpy.unwrapError.connCompMinArea = auto  #[1-inf], auto for 2.5e3, discard regions smaller than the min size in pixels

## phase_closure options:
## numSample - a region-based strategy is implemented to speedup L1-norm regularized least squares inversion.
##     Instead of inverting every pixel for the integer ambiguity, a common connected component mask is generated,
##     for each common conn. comp., numSample pixels are radomly selected for inversion, and the median value of the results
##     are used for all pixels within this common conn. comp.
mintpy.unwrapError.numSample       = auto  #[int>1], auto for 100, number of samples to invert for common conn. comp.

## bridging options:
## ramp - a phase ramp could be estimated based on the largest reliable region, removed from the entire interferogram
##     before estimating the phase difference between reliable regions and added back after the correction.
## bridgePtsRadius - half size of the window used to calculate the median value of phase difference
mintpy.unwrapError.ramp            = auto  #[linear / quadratic], auto for no; recommend linear for L-band data
mintpy.unwrapError.bridgePtsRadius = auto  #[1-inf], auto for 50, half size of the window around end points


########## 5. invert_network
## Invert network of interferograms into time-series using weighted least square (WLS) estimator.
## weighting options for least square inversion [fast option available but not best]:
## a. var - use inverse of covariance as weight (Tough et al., 1995; Guarnieri & Tebaldini, 2008) [recommended]
## b. fim - use Fisher Information Matrix as weight (Seymour & Cumming, 1994; Samiei-Esfahany et al., 2016).
## c. coh - use coherence as weight (Perissin & Wang, 2012)
## d. no  - uniform weight (Berardino et al., 2002) [fast]
## SBAS (Berardino et al., 2002) = minNormVelocity (yes) + weightFunc (no)
mintpy.networkInversion.weightFunc      = auto #[var / fim / coh / no], auto for var
mintpy.networkInversion.waterMaskFile   = auto #[filename / no], auto for waterMask.h5 or no [if not found]
mintpy.networkInversion.minNormVelocity = auto #[yes / no], auto for yes, min-norm deformation velocity / phase

## mask options for unwrapPhase of each interferogram before inversion (recommend if weightFunct=no):
## a. coherence              - mask out pixels with spatial coherence < maskThreshold
## b. connectComponent       - mask out pixels with False/0 value
## c. no                     - no masking [recommended].
## d. range/azimuthOffsetStd - mask out pixels with offset std. dev. > maskThreshold [for offset]
mintpy.networkInversion.maskDataset   = auto #[coherence / connectComponent / rangeOffsetStd / azimuthOffsetStd / no], auto for no
mintpy.networkInversion.maskThreshold = auto #[0-inf], auto for 0.4
mintpy.networkInversion.minRedundancy = auto #[1-inf], auto for 1.0, min num_ifgram for every SAR acquisition

## Temporal coherence is calculated and used to generate the mask as the reliability measure
## reference: Pepe & Lanari (2006, IEEE-TGRS)
mintpy.networkInversion.minTempCoh  = 0.0 #[0.0-1.0], auto for 0.7, min temporal coherence for mask
mintpy.networkInversion.minNumPixel = auto #[int > 1], auto for 100, min number of pixels in mask above
mintpy.networkInversion.shadowMask  = yes #[yes / no], auto for yes [if shadowMask is in geometry file] or no.

########## 6. correct_troposphere (optional but recommended)
## correct tropospheric delay using the following methods:
## a. height_correlation - correct stratified tropospheric delay (Doin et al., 2009, J Applied Geop)
## b. pyaps - use Global Atmospheric Models (GAMs) data (Jolivet et al., 2011; 2014)
##      ERA5  - ERA5    from ECMWF [need to install PyAPS from GitHub; recommended and turn ON by default]
##      MERRA - MERRA-2 from NASA  [need to install PyAPS from Caltech/EarthDef]
##      NARR  - NARR    from NOAA  [need to install PyAPS from Caltech/EarthDef; recommended for N America]
## c. gacos - use GACOS with the iterative tropospheric decomposition model (Yu et al., 2018, JGR)
##      need to manually download GACOS products at http://www.gacos.net for all acquisitions before running this step
mintpy.troposphericDelay.method = no  #[pyaps / height_correlation / gacos / no], auto for pyaps

## Notes for pyaps:
## a. GAM data latency: with the most recent SAR data, there will be GAM data missing, the correction
##    will be applied to dates with GAM data available and skipped for the others.
## b. WEATHER_DIR: if you define an environment variable named WEATHER_DIR to contain the path to a
##    directory, then MintPy applications will download the GAM files into the indicated directory.
##    MintPy application will look for the GAM files in the directory before downloading a new one to
##    prevent downloading multiple copies if you work with different dataset that cover the same date/time.
mintpy.troposphericDelay.weatherModel = auto  #[ERA5 / MERRA / NARR], auto for ERA5
mintpy.troposphericDelay.weatherDir   = auto  #[path2directory], auto for WEATHER_DIR or "./"

## Notes for height_correlation:
## Extra multilooking is applied to estimate the empirical phase/elevation ratio ONLY.
## For an dataset with 5 by 15 looks, looks=8 will generate phase with (5*8) by (15*8) looks
## to estimate the empirical parameter; then apply the correction to original phase (with 5 by 15 looks),
## if the phase/elevation correlation is larger than minCorrelation.
mintpy.troposphericDelay.polyOrder      = auto  #[1 / 2 / 3], auto for 1
mintpy.troposphericDelay.looks          = auto  #[1-inf], auto for 8, extra multilooking num
mintpy.troposphericDelay.minCorrelation = auto  #[0.0-1.0], auto for 0

## Notes for gacos:
## Set the path below to directory that contains the downloaded *.ztd* files
mintpy.troposphericDelay.gacosDir = auto # [path2directory], auto for "./GACOS"


########## 7. deramp (optional)
## Estimate and remove a phase ramp for each acquisition based on the reliable pixels.
## Recommended for localized deformation signals, i.e. volcanic deformation, landslide and land subsidence, etc.
## NOT recommended for long spatial wavelength deformation signals, i.e. co-, post- and inter-seimic deformation.
mintpy.deramp          = linear  #[no / linear / quadratic], auto for no - no ramp will be removed
mintpy.deramp.maskFile = auto  #[filename / no], auto for maskTempCoh.h5, mask file for ramp estimation


########## 8. correct_topography (optional but recommended)
## Topographic residual (DEM error) correction
## reference: Fattahi and Amelung (2013, IEEE-TGRS)
## stepFuncDate      - specify stepFuncDate option if you know there are sudden displacement jump in your area,
##                     e.g. volcanic eruption, or earthquake
## excludeDate       - dates excluded for the error estimation
## pixelwiseGeometry - use pixel-wise geometry (incidence angle & slant range distance)
##                     yes - use pixel-wise geometry if they are available [slow; used by default]
##                     no  - use the mean   geometry [fast]
mintpy.topographicResidual                   = auto  #[yes / no], auto for yes
mintpy.topographicResidual.polyOrder         = auto  #[1-inf], auto for 2, poly order of temporal deformation model
mintpy.topographicResidual.phaseVelocity     = auto  #[yes / no], auto for no - use phase velocity for minimization
mintpy.topographicResidual.stepFuncDate      = auto  #[20080529,20190704T1733 / no], auto for no, date of step jump
mintpy.topographicResidual.excludeDate       = auto  #[20070321 / txtFile / no], auto for exclude_date.txt
mintpy.topographicResidual.pixelwiseGeometry = auto  #[yes / no], auto for yes, use pixel-wise geometry info


########## 9.1 residual_RMS (root mean squares for noise evaluation)
## Calculate the Root Mean Square (RMS) of residual phase time-series for each acquisition
## reference: Yunjun et al. (2019, section 4.9 and 5.4)
## To get rid of long spatial wavelength component, a ramp is removed for each acquisition
## Set optimal reference date to date with min RMS
## Set exclude dates (outliers) to dates with RMS > cutoff * median RMS (Median Absolute Deviation)
mintpy.residualRMS.maskFile = auto  #[file name / no], auto for maskTempCoh.h5, mask for ramp estimation
mintpy.residualRMS.deramp   = auto  #[quadratic / linear / no], auto for quadratic
mintpy.residualRMS.cutoff   = auto  #[0.0-inf], auto for 3

########## 9.2 reference_date
## Reference all time-series to one date in time
## reference: Yunjun et al. (2019, section 4.9)
## no     - do not change the default reference date (1st date)
mintpy.reference.date = no   #[reference_date.txt / 20090214 / no], auto for reference_date.txt


########## 10. velocity
## Estimate a suite of time functions [linear velocity by default]
## from final displacement file (and from tropospheric delay file if exists)
mintpy.timeFunc.startDate   = auto   #[20070101 / no], auto for no
mintpy.timeFunc.endDate     = auto   #[20101230 / no], auto for no
mintpy.timeFunc.excludeDate = auto   #[exclude_date.txt / 20080520,20090817 / no], auto for exclude_date.txt

## Fit a suite of time functions
## reference: Hetland et al. (2012, JGR) equation (2-9)
## polynomial function    is  defined by its degree in integer. 1 for linear, 2 for quadratic, etc.
## periodic   function(s) are defined by a list of periods in decimal years. 1 for annual, 0.5 for semi-annual, etc.
## step       function(s) are defined by a list of onset times in str in YYYYMMDD(THHMM) format
## exp & log  function(s) are defined by an onset time followed by an charateristic time in integer days.
##   Multiple exp and log functions can be overlaied on top of each other, achieved via e.g.:
##   20110311,60,120          - two functions sharing the same onset time OR
##   20110311,60;20170908,120 - separated by ";"
mintpy.timeFunc.polynomial = auto   #[int >= 0], auto for 1, degree of the polynomial function
mintpy.timeFunc.periodic   = auto   #[1,0.5 / list_of_float / no], auto for no, periods in decimal years
mintpy.timeFunc.stepDate   = auto   #[20110311,20170908 / 20120928T1733 / no], auto for no, step function(s)
mintpy.timeFunc.exp        = auto   #[20110311,60 / 20110311,60,120 / 20110311,60;20170908,120 / no], auto for no
mintpy.timeFunc.log        = auto   #[20110311,60 / 20110311,60,120 / 20110311,60;20170908,120 / no], auto for no

## Uncertainty quantification methods:
## a. residue    - propagate from fitting residue assuming normal dist. in time (Fattahi & Amelung, 2015, JGR)
## b. covariance - propagate from time series (co)variance matrix
## c. bootstrap  - bootstrapping (independently resampling with replacement; Efron & Tibshirani, 1986, Stat. Sci.)
mintpy.timeFunc.uncertaintyQuantification = auto   #[residue, covariance, bootstrap], auto for residue
mintpy.timeFunc.timeSeriesCovFile         = auto   #[filename / no], auto for no, time series covariance file
mintpy.timeFunc.bootstrapCount            = auto   #[int>1], auto for 400, number of iterations for bootstrapping


########## 11.1 geocode (post-processing)
# for input dataset in radar coordinates only
# commonly used resolution in meters and in degrees (on equator)
# 100,         90,          60,          50,          40,          30,          20,          10
# 0.000925926, 0.000833334, 0.000555556, 0.000462963, 0.000370370, 0.000277778, 0.000185185, 0.000092593
mintpy.geocode              = auto  #[yes / no], auto for yes
mintpy.geocode.SNWE         = auto  #[-1.2,0.5,-92,-91 / none ], auto for none, output extent in degree
mintpy.geocode.laloStep     = None  #[-0.000555556,0.000555556 / None], auto for None, output resolution in degree
mintpy.geocode.interpMethod = auto  #[linear], auto for nearest, interpolation method
mintpy.geocode.fillValue    = auto  #[np.nan, 0, ...], auto for np.nan, fill value for outliers.

########## 11.2 google_earth (post-processing)
mintpy.save.kmz             = auto   #[yes / no], auto for yes, save geocoded velocity to Google Earth KMZ file

########## 11.3 hdfeos5 (post-processing)
mintpy.save.hdfEos5         = auto   #[yes / no], auto for no, save time-series to HDF-EOS5 format
mintpy.save.hdfEos5.update  = auto   #[yes / no], auto for no, put XXXXXXXX as endDate in output filename
mintpy.save.hdfEos5.subset  = auto   #[yes / no], auto for no, put subset range info   in output filename

########## 11.4 plot
# for high-resolution plotting, increase mintpy.plot.maxMemory
# for fast plotting with more parallelization, decrease mintpy.plot.maxMemory
mintpy.plot           = auto  #[yes / no], auto for yes, plot files generated by default processing to pic folder
mintpy.plot.dpi       = auto  #[int], auto for 150, number of dots per inch (DPI)
mintpy.plot.maxMemory = auto  #[float], auto for 4, max memory used by one call of view.py for plotting.
'''

# %%
os.chdir(mintpy_path)
config_file = f'{mintpy_path}/SenAT12.txt'
write_config_file(config_file, CONFIG_TXT, mode='w')
# Out:
# write configuration to file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/SenAT12.txt

# %%
# !smallbaselineApp.py SenAT12.txt --dostep load_data
# Out:
# MintPy version 1.5.3, date 2023-11-23
# --RUN-at-2024-01-29 16:37:58.657875--
# Current directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# Run routine processing with smallbaselineApp.py on steps: ['load_data']
# Remaining steps: ['modify_network', 'reference_point', 'quick_overview', 'correct_unwrap_error', 'invert_network', 'correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# copy default template file /home/gbrench/sw/miniconda3/envs/mintpy/lib/python3.11/site-packages/mintpy/defaults/smallbaselineApp.cfg to work directory
# read custom template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/SenAT12.txt
# update default template based on input custom template
#     mintpy.compute.maxMemory: auto --> 10
#     mintpy.compute.cluster: auto --> local
#     mintpy.compute.numWorker: auto --> 4
#     mintpy.load.processor: auto --> hyp3
#     mintpy.load.unwFile: auto --> ../data/*/*/S1*unw_phase_clipped.tif
#     mintpy.load.corFile: auto --> ../data/*/*/S1*corr_clipped.tif
#     mintpy.load.connCompFile: auto --> ../data/*/*/S1*conncomp_clipped.tif
#     mintpy.load.demFile: auto --> ../data/*/*/S1*dem_clipped.tif
#     mintpy.load.incAngleFile: auto --> ../data/*/*/S1*lv_theta_clipped.tif
#     mintpy.load.azAngleFile: auto --> ../data/*/*/S1*lv_phi_clipped.tif
#     mintpy.network.tempBaseMax: auto --> 24
#     mintpy.network.perpBaseMax: auto --> 150
#     mintpy.unwrapError.method: auto --> bridging
#     mintpy.networkInversion.minTempCoh: auto --> 0.0
#     mintpy.networkInversion.shadowMask: auto --> yes
#     mintpy.troposphericDelay.method: auto --> no
#     mintpy.deramp: auto --> linear
#     mintpy.reference.date: auto --> no
#     mintpy.geocode.laloStep: auto --> None
# copy SenAT12.txt          to inputs   directory for backup.
# copy smallbaselineApp.cfg to inputs   directory for backup.
# copy SenAT12.txt          to pic      directory for backup.
# copy smallbaselineApp.cfg to pic      directory for backup.
# read default template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
#
#
# ******************** step - load_data ********************
#
# load_data.py --template /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/SenAT12.txt --project SenAT12
# processor : hyp3
# SAR platform/sensor : Sen
# --------------------------------------------------
# prepare metadata files for hyp3 products
# prep_hyp3.py "../data/*/*/S1*unw_phase_clipped.tif"
# /home/gbrench/sw/miniconda3/envs/mintpy/lib/python3.11/site-packages/osgeo/gdal.py:287: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# prep_hyp3.py "../data/*/*/S1*corr_clipped.tif"
# prep_hyp3.py "../data/*/*/S1*conncomp_clipped.tif"
# prep_hyp3.py "../data/*/*/S1*dem_clipped.tif"
# prep_hyp3.py "../data/*/*/S1*lv_theta_clipped.tif"
# prep_hyp3.py "../data/*/*/S1*lv_phi_clipped.tif"
# --------------------------------------------------
# updateMode : True
# compression: None
# multilook x/ystep: 1/1
# multilook method : nearest
# --------------------------------------------------
# searching geometry files info
# input data files:
# height          : ../data/20170123_20170204/S1_023790_IW1_20170123_20170204_VV_INT20_4537/S1_023790_IW1_20170123_20170204_VV_INT20_4537_dem_clipped.tif
# incidenceAngle  : ../data/20170123_20170204/S1_023790_IW1_20170123_20170204_VV_INT20_4537/S1_023790_IW1_20170123_20170204_VV_INT20_4537_lv_theta_clipped.tif
# azimuthAngle    : ../data/20170123_20170204/S1_023790_IW1_20170123_20170204_VV_INT20_4537/S1_023790_IW1_20170123_20170204_VV_INT20_4537_lv_phi_clipped.tif
# --------------------------------------------------
# create HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/geometryGeo.h5 with w mode
# create dataset /height             of <class 'numpy.float32'>   in size of (1972, 5142) with compression = lzf
# create dataset /incidenceAngle     of <class 'numpy.float32'>   in size of (1972, 5142) with compression = lzf
#     convert incidenceAngle  from Gamma (from horizontal in radian)  to MintPy (from vertical in degree) convention.
# create dataset /azimuthAngle       of <class 'numpy.float32'>   in size of (1972, 5142) with compression = lzf
#     convert azimuthAngle    from Gamma (from east in radian)  to MintPy (from north in degree) convention.
# prepare slantRangeDistance ...
#     geocoded input, use incidenceAngle from file: S1_023790_IW1_20170123_20170204_VV_INT20_4537_lv_theta_clipped.tif
#     convert incidence angle from Gamma to MintPy convention.
# create dataset /slantRangeDistance of <class 'numpy.float32'>   in size of (1972, 5142) with compression = lzf
# Finished writing to /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/geometryGeo.h5
# --------------------------------------------------
# searching interferogram pairs info
# input data files:
# unwrapPhase     : ../data/*/*/S1*unw_phase_clipped.tif
# coherence       : ../data/*/*/S1*corr_clipped.tif
# connectComponent: ../data/*/*/S1*conncomp_clipped.tif
# number of unwrapPhase     : 418
# number of coherence       : 418
# number of connectComponent: 418
# --------------------------------------------------
# create HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/ifgramStack.h5 with w mode
# create dataset /unwrapPhase      of <class 'numpy.float32'>   in size of (418, 1972, 5142) with compression = None
# [==================================================] 20231230_20240123  562s /    11s
# create dataset /coherence        of <class 'numpy.float32'>   in size of (418, 1972, 5142) with compression = None
# [==================================================] 20231230_20240123  586s /    11s
# create dataset /connectComponent of <class 'numpy.int16'>     in size of (418, 1972, 5142) with compression = lzf
# [==================================================] 20231230_20240123  501s /    10s
# create dataset /date             of <class 'numpy.bytes_'>    in size of (418, 2)
# create dataset /bperp            of <class 'numpy.float32'>   in size of (418,)
# create dataset /dropIfgram       of <class 'numpy.bool_'>     in size of (418,)
# add extra metadata: {'PROJECT_NAME': 'SenAT12', 'PLATFORM': 'Sen'}
# Finished writing to /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/ifgramStack.h5
# --------------------------------------------------
# searching ionosphere pairs info
# input data files:
# WARNING: No data files found for the required dataset: ['unwrapPhase']! Skip loading for ionosphere stack.
# --------------------------------------------------
# searching offset pairs info
# input data files:
# WARNING: No data files found for the required dataset: ['rangeOffset', 'azimuthOffset']! Skip loading for offset stack.
# time used: 30 mins 6.5 secs.
#
# No lookup table (longitude or rangeCoord) found in files.
# Input data seems to be geocoded. Lookup file not needed.
# Loaded dataset are processed by InSAR software: hyp3
# Loaded dataset are in GEO coordinates
# Interferogram Stack: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/ifgramStack.h5
# Geometry      File : /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/geometryGeo.h5
# Lookup Table  File : None
# --------------------------------------------------
# updating metadata based on custom template file SenAT12.txt for file: ifgramStack.h5
# Go back to directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 30 mins 8.0 secs

# %%
view.main('inputs/ifgramStack.h5 unwrapPhase-* -v -10 10 --zero-mask --noaxis --noverbose'.split())
# Out:
# view.py inputs/ifgramStack.h5 unwrapPhase-* -v -10 10 --zero-mask --noaxis --noverbose

# %%
# !smallbaselineApp.py SenAT12.txt --dostep modify_network
# Out:
# MintPy version 1.5.3, date 2023-11-23
# --RUN-at-2024-01-29 17:11:25.474122--
# Current directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# Run routine processing with smallbaselineApp.py on steps: ['modify_network']
# Remaining steps: ['reference_point', 'quick_overview', 'correct_unwrap_error', 'invert_network', 'correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# read custom template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/SenAT12.txt
# update default template based on input custom template
# No new option value found, skip updating /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
# copy SenAT12.txt          to inputs   directory for backup.
# copy smallbaselineApp.cfg to inputs   directory for backup.
# copy SenAT12.txt          to pic      directory for backup.
# copy smallbaselineApp.cfg to pic      directory for backup.
# read default template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
#
#
# ******************** step - modify_network ********************
# Input data seems to be geocoded. Lookup file not needed.
#
# modify_network.py /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/ifgramStack.h5 -t /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
# read options from template file: smallbaselineApp.cfg
# No lookup table (longitude or rangeCoord) found in files.
# open ifgramStack file: ifgramStack.h5
# number of interferograms: 418
# --------------------------------------------------
# Drop ifgrams with temporal baseline > 24.0 days: (6)
# ['20170523_20170628', '20170604_20170710', '20190501_20190606', '20190513_20190618', '20230305_20230410', '20230317_20230422']
# --------------------------------------------------
# Drop ifgrams with perp baseline > 150.0 meters: (37)
# ['20180810_20180903', '20190206_20190302', '20190829_20190922', '20191004_20191016', '20191004_20191028', '20200706_20200730', '20200916_20201010', '20201010_20201103', '20201127_20201221', '20220109_20220202', '20220813_20220906', '20220825_20220906', '20220906_20220918', '20220930_20221012', '20221105_20221129', '20221129_20221223', '20230104_20230128', '20230116_20230128', '20230128_20230209', '20230128_20230221', '20230209_20230305', '20230221_20230305', '20230305_20230317', '20230317_20230410', '20230422_20230516', '20230516_20230609', '20230528_20230609', '20230528_20230621', '20230621_20230715', '20230715_20230808', '20230727_20230808', '20230901_20230925', '20230913_20230925', '20231007_20231031', '20231124_20231206', '20231124_20231218', '20231218_20240111']
# --------------------------------------------------
# number of interferograms to remove: 43
# number of interferograms to keep  : 375
# number of acquisitions to remove: 2
# ['20230128', '20230305']
# open file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/ifgramStack.h5 with r+ mode
# update HDF5 dataset "/dropIfgram".
# update MODIFICATION_TIME in HDF5 dataset "/unwrapPhase"
# update MODIFICATION_TIME in HDF5 dataset "/coherence"
# update MODIFICATION_TIME in HDF5 dataset "/connectComponent"
# Done.
#
# plot_network.py /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/ifgramStack.h5 -t /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg --nodisplay -d coherence -v 0.2 1.0
# read options from template file: smallbaselineApp.cfg
# read temporal/spatial baseline info from file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/ifgramStack.h5
# open ifgramStack file: ifgramStack.h5
# calculating spatial mean of coherence in file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/ifgramStack.h5 ...
# [==================================================] 418/418  177s /     3s
# write average value in space into text file: coherenceSpatialAvg.txt
# number of acquisitions: 211
# number of interferograms: 418
# shift all perp baseline by 24.761306762695312 to zero mean for plotting
# --------------------------------------------------
# number of interferograms marked as drop: 43
# number of interferograms marked as keep: 375
# number of acquisitions marked as drop: 2
# ['20230128', '20230305']
# save figure to pbaseHistory.pdf
# save figure to coherenceMatrix.pdf
# save figure to coherenceHistory.pdf
# max perpendicular baseline: 268.69 m
# max temporal      baseline: 36.0 days
# showing coherence
# data range: [0.3375, 0.7559]
# display range: [0.2, 1.0]
# save figure to network.pdf
# Go back to directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 03 mins 17.6 secs

# %%
plot_network.main('inputs/ifgramStack.h5 -t smallbaselineApp.cfg --figsize 12 4'.split())
# Out:
# read options from template file: smallbaselineApp.cfg
# read temporal/spatial baseline info from file: inputs/ifgramStack.h5
# open ifgramStack file: ifgramStack.h5
# coherenceSpatialAvg.txt already exists, read it directly
# number of acquisitions: 211
# number of interferograms: 418
# shift all perp baseline by 24.761306762695312 to zero mean for plotting
# --------------------------------------------------
# number of interferograms marked as drop: 43
# number of interferograms marked as keep: 375
# number of acquisitions marked as drop: 2
# ['20230128', '20230305']
# max perpendicular baseline: 268.69 m
# max temporal      baseline: 36.0 days
# showing coherence
# data range: [0.3375, 0.7559]
# display range: (0.2, 1.0)
# showing ...

# %%
# !smallbaselineApp.py SenAT12.txt --dostep reference_point
# Out:
# MintPy version 1.5.3, date 2023-11-23
# --RUN-at-2024-01-29 20:57:14.162451--
# Current directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# Run routine processing with smallbaselineApp.py on steps: ['reference_point']
# Remaining steps: ['quick_overview', 'correct_unwrap_error', 'invert_network', 'correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# read custom template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/SenAT12.txt
# update default template based on input custom template
#     mintpy.reference.lalo: 3086742.0, 491159.9 --> 3087261.5,489428.3
# copy SenAT12.txt          to inputs   directory for backup.
# copy smallbaselineApp.cfg to inputs   directory for backup.
# copy SenAT12.txt          to pic      directory for backup.
# copy smallbaselineApp.cfg to pic      directory for backup.
# read default template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
#
#
# ******************** step - reference_point ********************
# Input data seems to be geocoded. Lookup file not needed.
#
# generate_mask.py /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/ifgramStack.h5 --nonzero -o /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/maskConnComp.h5 --update
# input ifgramStack file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/ifgramStack.h5
# --------------------------------------------------
# update mode: ON
# 1) output file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/maskConnComp.h5 already exists.
# 2) output file is newer than input dataset: connectComponent.
# run or skip: skip.
#
# temporal_average.py /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/ifgramStack.h5 --dataset coherence -o /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/avgSpatialCoh.h5 --update
# --------------------------------------------------
# update mode: ON
# 1) output file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/avgSpatialCoh.h5 already exists.
# 2) output file is newer than input dataset: coherence.
# run or skip: skip.
# Input data seems to be geocoded. Lookup file not needed.
#
# reference_point.py /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/ifgramStack.h5 -t /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg -c /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/avgSpatialCoh.h5
# --------------------------------------------------
# reading reference info from template: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
# input reference point in lat/lon: (3087261.5, 489428.3)
# input reference point in y/x: (992, 3640)
# mask: maskConnComp.h5
# --------------------------------------------------
# calculate the temporal average of unwrapPhase in file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/ifgramStack.h5 ...
# [==================================================] lines 1972/1972   75s /     7s
# Add/update ref_x/y attribute to file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/ifgramStack.h5
# {'REF_Y': '992', 'REF_X': '3640', 'REF_LAT': '3087270.0', 'REF_LON': '489430.0'}
# touch avgSpatialCoh.h5
# touch maskConnComp.h5
# Go back to directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 01 mins 45.3 secs

# %%
view.main('maskConnComp.h5 -c gray --noverbose'.split())
# Out:
# view.py maskConnComp.h5 -c gray --noverbose

# %%
# !smallbaselineApp.py SenAT12.txt --dostep quick_overview
# Out:
# MintPy version 1.5.3, date 2023-11-23
# --RUN-at-2024-01-29 21:00:12.587560--
# Current directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# Run routine processing with smallbaselineApp.py on steps: ['quick_overview']
# Remaining steps: ['correct_unwrap_error', 'invert_network', 'correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# read custom template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/SenAT12.txt
# update default template based on input custom template
# No new option value found, skip updating /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
# copy SenAT12.txt          to inputs   directory for backup.
# copy smallbaselineApp.cfg to inputs   directory for backup.
# copy SenAT12.txt          to pic      directory for backup.
# copy smallbaselineApp.cfg to pic      directory for backup.
# read default template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
#
#
# ******************** step - quick_overview ********************
# Input data seems to be geocoded. Lookup file not needed.
#
# temporal_average.py /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/ifgramStack.h5 --dataset unwrapPhase -o /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/avgPhaseVelocity.h5 --update
# --------------------------------------------------
# update mode: ON
# 1) output file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/avgPhaseVelocity.h5 already exists.
# 2) output file is newer than input dataset: unwrapPhase.
# run or skip: skip.
#
# unwrap_error_phase_closure.py /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/ifgramStack.h5 --water-mask /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/waterMask.h5 --action calculate --update
# update mode: ON
# 1) output file "/mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/numTriNonzeroIntAmbiguity.h5" already exists
# 2) output file is newer than input dataset
# 3) NOT all key configurations are the same: ['REF_Y', 'REF_X']
# run or skip: run.
# open ifgramStack file: ifgramStack.h5
# number of interferograms: 375
# number of triplets: 168
# calculating the number of triplets with non-zero integer ambiguity of closure phase ...
#     block by block with size up to (150, 5142), 14 blocks in total
# reference pixel in y/x: (992, 3640) from dataset: unwrapPhase
# [==================================================] line 1950 / 1972  128s /     9s
# mask out pixels with zero in file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/avgSpatialCoh.h5
# write to file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/numTriNonzeroIntAmbiguity.h5
# delete exsited file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/numTriNonzeroIntAmbiguity.h5
# create HDF5 file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/numTriNonzeroIntAmbiguity.h5 with w mode
# create dataset /mask of float32    in size of (1972, 5142)         with compression=None
# finished writing to /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/numTriNonzeroIntAmbiguity.h5
# plot and save figure to file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/numTriNonzeroIntAmbiguity.png
# time used: 02 mins 13.0 secs
# Done.
# Go back to directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 02 mins 15.5 secs

# %%
plot.plot_num_triplet_with_nonzero_integer_ambiguity('numTriNonzeroIntAmbiguity.h5', disp_fig=True, fig_size=[14, 4])
# Out:
# plot and save figure to file numTriNonzeroIntAmbiguity.png

# %%
# !smallbaselineApp.py SenAT12.txt --dostep correct_unwrap_error
# Out:
# MintPy version 1.5.3, date 2023-11-23
# --RUN-at-2024-01-29 21:02:31.636443--
# Current directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# Run routine processing with smallbaselineApp.py on steps: ['correct_unwrap_error']
# Remaining steps: ['invert_network', 'correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# read custom template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/SenAT12.txt
# update default template based on input custom template
# No new option value found, skip updating /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
# copy SenAT12.txt          to inputs   directory for backup.
# copy smallbaselineApp.cfg to inputs   directory for backup.
# copy SenAT12.txt          to pic      directory for backup.
# copy smallbaselineApp.cfg to pic      directory for backup.
# read default template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
#
#
# ******************** step - correct_unwrap_error ********************
# Input data seems to be geocoded. Lookup file not needed.
#
# unwrap_error_bridging.py /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/ifgramStack.h5 --template /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg --update
# read options from template file: smallbaselineApp.cfg
# --------------------------------------------------
# update mode: ON
# 1) output dataset: unwrapPhase_bridging exists
# 2) output dataset is newer than input dataset: unwrapPhase
# 3) all key configuration parameters are the same: ['waterMaskFile', 'connCompMinArea', 'ramp', 'bridgePtsRadius'].
# run or skip: skip.
# Go back to directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 3.0 secs

# %%
# !smallbaselineApp.py SenAT12.txt --dostep invert_network
# Out:
# MintPy version 1.5.3, date 2023-11-23
# --RUN-at-2024-01-29 21:02:35.800623--
# Current directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# Run routine processing with smallbaselineApp.py on steps: ['invert_network']
# Remaining steps: ['correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# read custom template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/SenAT12.txt
# update default template based on input custom template
# No new option value found, skip updating /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
# copy SenAT12.txt          to inputs   directory for backup.
# copy smallbaselineApp.cfg to inputs   directory for backup.
# copy SenAT12.txt          to pic      directory for backup.
# copy smallbaselineApp.cfg to pic      directory for backup.
# read default template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
#
#
# ******************** step - invert_network ********************
# Input data seems to be geocoded. Lookup file not needed.
#
# ifgram_inversion.py /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/ifgramStack.h5 -t /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg --update
# read input option from template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
# phase unwrapping error correction "bridging" is turned ON
# use dataset "unwrapPhase_bridging" by default
# --------------------------------------------------
# update mode: ON
# 1) output files already exist: ['timeseries.h5', 'temporalCoherence.h5', 'numInvIfgram.h5'].
# 2) output dataset is newer than input dataset: unwrapPhase_bridging.
# 3) NOT all the metadata are the same: ['REF_Y', 'REF_X']
# run or skip: run.
# save the original settings of ['OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS', 'MKL_NUM_THREADS', 'NUMEXPR_NUM_THREADS', 'VECLIB_MAXIMUM_THREADS']
# set OMP_NUM_THREADS = 1
# set OPENBLAS_NUM_THREADS = 1
# set MKL_NUM_THREADS = 1
# set NUMEXPR_NUM_THREADS = 1
# set VECLIB_MAXIMUM_THREADS = 1
# reference pixel in y/x: (992, 3640) from dataset: unwrapPhase_bridging
# -------------------------------------------------------------------------------
# least-squares solution with L2 min-norm on: deformation velocity
# minimum redundancy: 1.0
# weight function: var
# calculate covariance: False
# mask: no
# ***WARNING: the network is NOT fully connected.
# 	Inversion result can be biased!
# 	Continue to use SVD to resolve the offset between different subsets.
# -------------------------------------------------------------------------------
# number of interferograms: 375
# number of acquisitions  : 209
# number of lines   : 1972
# number of columns : 5142
# --------------------------------------------------
# create HDF5 file: timeseries.h5 with w mode
# create dataset  : date       of |S8                       in size of (209,)               with compression = None
# create dataset  : bperp      of <class 'numpy.float32'>   in size of (209,)               with compression = None
# create dataset  : timeseries of <class 'numpy.float32'>   in size of (209, 1972, 5142)    with compression = None
# close  HDF5 file: timeseries.h5
# --------------------------------------------------
# create HDF5 file: temporalCoherence.h5 with w mode
# create dataset  : temporalCoherence of <class 'numpy.float32'>   in size of (1972, 5142)         with compression = None
# close  HDF5 file: temporalCoherence.h5
# --------------------------------------------------
# create HDF5 file: numInvIfgram.h5 with w mode
# create dataset  : mask of <class 'numpy.float32'>   in size of (1972, 5142)         with compression = None
# close  HDF5 file: numInvIfgram.h5
# maximum memory size: 1.0E+01 GB
# split 1972 lines into 6 patches for processing
#     with each patch up to 330 lines
#
# ------- processing patch 1 out of 6 --------------
# box width:  5142
# box length: 330
#
#
# ------- start parallel processing using Dask -------
# input Dask cluster type: local
# initiate Dask cluster
# split patch into 4 sub boxes in x direction for workers to process
# scale Dask cluster to 4 workers
# initiate Dask client
# submit a job to the worker for sub box 0: [0, 0, 1286, 330]
# submit a job to the worker for sub box 1: [1286, 0, 2572, 330]
# submit a job to the worker for sub box 2: [2572, 0, 3858, 330]
# submit a job to the worker for sub box 3: [3858, 0, 5142, 330]
# calculating weight from spatial coherence ...
# reading coherence in [3858, 0, 5142, 330] * 375 ...
# calculating weight from spatial coherence ...
# reading coherence in [1286, 0, 2572, 330] * 375 ...
# calculating weight from spatial coherence ...
# reading coherence in [2572, 0, 3858, 330] * 375 ...
# calculating weight from spatial coherence ...
# reading coherence in [0, 0, 1286, 330] * 375 ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# chunk 1 / 5
# chunk 1 / 5
# chunk 1 / 5
# chunk 1 / 5
# chunk 2 / 5
# chunk 2 / 5
# chunk 2 / 5
# chunk 2 / 5
# chunk 3 / 5
# chunk 3 / 5
# chunk 3 / 5
# chunk 3 / 5
# chunk 4 / 5
# chunk 4 / 5
# chunk 4 / 5
# chunk 4 / 5
# chunk 5 / 5
# reading unwrapPhase_bridging in [2572, 0, 3858, 330] * 375 ...
# chunk 5 / 5
# reading unwrapPhase_bridging in [0, 0, 1286, 330] * 375 ...
# chunk 5 / 5
# reading unwrapPhase_bridging in [1286, 0, 2572, 330] * 375 ...
# chunk 5 / 5
# reading unwrapPhase_bridging in [3858, 0, 5142, 330] * 375 ...
# 2024-01-29 21:03:03,704 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.90 GiB -- Worker memory limit: 2.68 GiB
# use input reference value
# 2024-01-29 21:03:04,253 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.94 GiB -- Worker memory limit: 2.68 GiB
# 2024-01-29 21:03:04,254 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.99 GiB -- Worker memory limit: 2.68 GiB
# 2024-01-29 21:03:04,290 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.95 GiB -- Worker memory limit: 2.68 GiB
# use input reference value
# use input reference value
# use input reference value
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# skip pixels with zero value in file: avgSpatialCoh.h5
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# skip pixels with zero value in file: avgSpatialCoh.h5
# number of pixels to invert: 0 out of 424380 (0.0%)
# skip pixels with zero value in file: avgSpatialCoh.h5
# skip pixels with zero value in file: avgSpatialCoh.h5
# number of pixels to invert: 0 out of 424380 (0.0%)
# number of pixels to invert: 29047 out of 424380 (6.8%)
# estimating time-series via WLS pixel-by-pixel ...
# [>                                                 ]number of pixels to invert: 145889 out of 423720 (34.4%)
# estimating time-series via WLS pixel-by-pixel ...
# [=>                       3%                       ] 800/29047 pixels    0s /    19s
# FUTURE #1 complete. Time used: 24 seconds
# [>                                                 ]
# FUTURE #2 complete. Time used: 25 seconds
# [==================================================] 29047/29047 pixels    92s /   369s
# converting LOS phase unit from radian to meter
#
# FUTURE #3 complete. Time used: 117 seconds
# [==================================================] 145889/145889 pixels  433s /     8s
# converting LOS phase unit from radian to meter
#
# FUTURE #4 complete. Time used: 466 seconds
# close dask client
# close dask cluster
# ------- finished parallel processing -------
#
#
# --------------------------------------------------
# open  HDF5 file timeseries.h5 in a mode
# writing dataset /timeseries                block: [0, 209, 0, 330, 0, 5142]
# close HDF5 file timeseries.h5.
# --------------------------------------------------
# open  HDF5 file temporalCoherence.h5 in a mode
# writing dataset /temporalCoherence         block: [0, 330, 0, 5142]
# close HDF5 file temporalCoherence.h5.
# --------------------------------------------------
# open  HDF5 file numInvIfgram.h5 in a mode
# writing dataset /mask                      block: [0, 330, 0, 5142]
# close HDF5 file numInvIfgram.h5.
# time used: 07 mins 54.8 secs.
#
#
# ------- processing patch 2 out of 6 --------------
# box width:  5142
# box length: 330
#
#
# ------- start parallel processing using Dask -------
# input Dask cluster type: local
# initiate Dask cluster
# split patch into 4 sub boxes in x direction for workers to process
# scale Dask cluster to 4 workers
# initiate Dask client
# submit a job to the worker for sub box 0: [0, 330, 1286, 660]
# submit a job to the worker for sub box 1: [1286, 330, 2572, 660]
# submit a job to the worker for sub box 2: [2572, 330, 3858, 660]
# submit a job to the worker for sub box 3: [3858, 330, 5142, 660]
# calculating weight from spatial coherence ...
# reading coherence in [3858, 330, 5142, 660] * 375 ...
# calculating weight from spatial coherence ...
# reading coherence in [0, 330, 1286, 660] * 375 ...
# calculating weight from spatial coherence ...
# calculating weight from spatial coherence ...
# reading coherence in [1286, 330, 2572, 660] * 375 ...
# reading coherence in [2572, 330, 3858, 660] * 375 ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# chunk 1 / 5
# chunk 1 / 5
# chunk 1 / 5
# chunk 1 / 5
# chunk 2 / 5
# chunk 2 / 5
# chunk 2 / 5
# chunk 2 / 5
# chunk 3 / 5
# chunk 3 / 5
# chunk 3 / 5
# chunk 3 / 5
# chunk 4 / 5
# chunk 4 / 5
# chunk 4 / 5
# chunk 4 / 5
# chunk 5 / 5
# reading unwrapPhase_bridging in [3858, 330, 5142, 660] * 375 ...
# chunk 5 / 5
# reading unwrapPhase_bridging in [2572, 330, 3858, 660] * 375 ...
# chunk 5 / 5
# chunk 5 / 5
# reading unwrapPhase_bridging in [1286, 330, 2572, 660] * 375 ...
# reading unwrapPhase_bridging in [0, 330, 1286, 660] * 375 ...
# 2024-01-29 21:10:59,470 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.88 GiB -- Worker memory limit: 2.68 GiB
# 2024-01-29 21:10:59,537 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.90 GiB -- Worker memory limit: 2.68 GiB
# 2024-01-29 21:10:59,566 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.88 GiB -- Worker memory limit: 2.68 GiB
# 2024-01-29 21:10:59,577 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.90 GiB -- Worker memory limit: 2.68 GiB
# use input reference value
# use input reference value
# use input reference value
# use input reference value
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# skip pixels with zero value in file: avgSpatialCoh.h5
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# skip pixels with zero value in file: avgSpatialCoh.h5
# number of pixels to invert: 0 out of 424380 (0.0%)
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# skip pixels with zero value in file: avgSpatialCoh.h5
# number of pixels to invert: 102125 out of 424380 (24.1%)
# estimating time-series via WLS pixel-by-pixel ...
# [>                                                 ]skip pixels with zero value in file: avgSpatialCoh.h5
# number of pixels to invert: 275382 out of 423720 (65.0%)
# estimating time-series via WLS pixel-by-pixel ...
# [>                                                 ]
# FUTURE #1 complete. Time used: 29 seconds
# number of pixels to invert: 375242 out of 424380 (88.4%)
# estimating time-series via WLS pixel-by-pixel ...
# [==================================================] 102125/102125 pixels 378s /   768ss
# converting LOS phase unit from radian to meter
# [===============>        33%                       ] 91800/275382 pixels  379s /   769s
# FUTURE #2 complete. Time used: 408 seconds
# [==================================================] 275382/275382 pixels  999s /   333s
# converting LOS phase unit from radian to meter
#
# FUTURE #3 complete. Time used: 1029 seconds
# [==================================================] 375242/375242 pixels 1270s /    25s
# converting LOS phase unit from radian to meter
#
# FUTURE #4 complete. Time used: 1317 seconds
# close dask client
# close dask cluster
# ------- finished parallel processing -------
#
#
# --------------------------------------------------
# open  HDF5 file timeseries.h5 in a mode
# writing dataset /timeseries                block: [0, 209, 330, 660, 0, 5142]
# close HDF5 file timeseries.h5.
# --------------------------------------------------
# open  HDF5 file temporalCoherence.h5 in a mode
# writing dataset /temporalCoherence         block: [330, 660, 0, 5142]
# close HDF5 file temporalCoherence.h5.
# --------------------------------------------------
# open  HDF5 file numInvIfgram.h5 in a mode
# writing dataset /mask                      block: [330, 660, 0, 5142]
# close HDF5 file numInvIfgram.h5.
# time used: 29 mins 57.3 secs.
#
#
# ------- processing patch 3 out of 6 --------------
# box width:  5142
# box length: 330
#
#
# ------- start parallel processing using Dask -------
# input Dask cluster type: local
# initiate Dask cluster
# split patch into 4 sub boxes in x direction for workers to process
# scale Dask cluster to 4 workers
# initiate Dask client
# submit a job to the worker for sub box 0: [0, 660, 1286, 990]
# submit a job to the worker for sub box 1: [1286, 660, 2572, 990]
# submit a job to the worker for sub box 2: [2572, 660, 3858, 990]
# submit a job to the worker for sub box 3: [3858, 660, 5142, 990]
# calculating weight from spatial coherence ...
# calculating weight from spatial coherence ...
# calculating weight from spatial coherence ...
# reading coherence in [2572, 660, 3858, 990] * 375 ...
# reading coherence in [1286, 660, 2572, 990] * 375 ...
# reading coherence in [3858, 660, 5142, 990] * 375 ...
# calculating weight from spatial coherence ...
# reading coherence in [0, 660, 1286, 990] * 375 ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# chunk 1 / 5
# chunk 1 / 5
# chunk 1 / 5
# chunk 1 / 5
# chunk 2 / 5
# chunk 2 / 5
# chunk 2 / 5
# chunk 2 / 5
# chunk 3 / 5
# chunk 3 / 5
# chunk 3 / 5
# chunk 3 / 5
# chunk 4 / 5
# chunk 4 / 5
# chunk 4 / 5
# chunk 5 / 5
# reading unwrapPhase_bridging in [2572, 660, 3858, 990] * 375 ...
# chunk 5 / 5
# reading unwrapPhase_bridging in [1286, 660, 2572, 990] * 375 ...
# chunk 5 / 5
# reading unwrapPhase_bridging in [3858, 660, 5142, 990] * 375 ...
# chunk 4 / 5
# chunk 5 / 5
# reading unwrapPhase_bridging in [0, 660, 1286, 990] * 375 ...
# 2024-01-29 21:32:58,835 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.89 GiB -- Worker memory limit: 2.68 GiB
# 2024-01-29 21:32:58,936 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.94 GiB -- Worker memory limit: 2.68 GiB
# 2024-01-29 21:32:58,936 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.88 GiB -- Worker memory limit: 2.68 GiB
# 2024-01-29 21:32:59,041 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.94 GiB -- Worker memory limit: 2.68 GiB
# use input reference value
# use input reference value
# use input reference value
# use input reference value
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# skip pixels with zero value in file: avgSpatialCoh.h5
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# number of pixels to invert: 196163 out of 424380 (46.2%)
# estimating time-series via WLS pixel-by-pixel ...
# [>                                                 ]skip pixels with zero value in file: avgSpatialCoh.h5
# [>                                                 ]skip pixels with zero value in file: avgSpatialCoh.h5
# skip pixels with zero value in file: avgSpatialCoh.h5
# number of pixels to invert: 419102 out of 424380 (98.8%)
# estimating time-series via WLS pixel-by-pixel ...
# [>                                                 ]number of pixels to invert: 301495 out of 423720 (71.2%)
# estimating time-series via WLS pixel-by-pixel ...
# number of pixels to invert: 424380 out of 424380 (100.0%)
# estimating time-series via WLS pixel-by-pixel ...
# [==================================================] 196163/196163 pixels  825s /  1008s
# converting LOS phase unit from radian to meter
# [=====================>  43%                       ] 184000/424380 pixels  825s /  1094s
# FUTURE #1 complete. Time used: 850 seconds
# [==================================================] 301495/301495 pixels 1269s /   493s
# converting LOS phase unit from radian to meter
# [======================= 70% ======>               ] 298200/424380 pixels 1269s /   544s
# FUTURE #2 complete. Time used: 1294 seconds
# [==================================================] 419102/419102 pixels 1661s /    51s
# converting LOS phase unit from radian to meter
#
# FUTURE #3 complete. Time used: 1685 seconds
# [==================================================] 424380/424380 pixels 1678s /    34s
# converting LOS phase unit from radian to meter
#
# FUTURE #4 complete. Time used: 1721 seconds
# close dask client
# close dask cluster
# ------- finished parallel processing -------
#
#
# --------------------------------------------------
# open  HDF5 file timeseries.h5 in a mode
# writing dataset /timeseries                block: [0, 209, 660, 990, 0, 5142]
# close HDF5 file timeseries.h5.
# --------------------------------------------------
# open  HDF5 file temporalCoherence.h5 in a mode
# writing dataset /temporalCoherence         block: [660, 990, 0, 5142]
# close HDF5 file temporalCoherence.h5.
# --------------------------------------------------
# open  HDF5 file numInvIfgram.h5 in a mode
# writing dataset /mask                      block: [660, 990, 0, 5142]
# close HDF5 file numInvIfgram.h5.
# time used: 58 mins 44.3 secs.
#
#
# ------- processing patch 4 out of 6 --------------
# box width:  5142
# box length: 330
#
#
# ------- start parallel processing using Dask -------
# input Dask cluster type: local
# initiate Dask cluster
# split patch into 4 sub boxes in x direction for workers to process
# scale Dask cluster to 4 workers
# initiate Dask client
# submit a job to the worker for sub box 0: [0, 990, 1286, 1320]
# submit a job to the worker for sub box 1: [1286, 990, 2572, 1320]
# submit a job to the worker for sub box 2: [2572, 990, 3858, 1320]
# submit a job to the worker for sub box 3: [3858, 990, 5142, 1320]
# calculating weight from spatial coherence ...
# reading coherence in [1286, 990, 2572, 1320] * 375 ...
# calculating weight from spatial coherence ...
# calculating weight from spatial coherence ...
# reading coherence in [0, 990, 1286, 1320] * 375 ...
# calculating weight from spatial coherence ...
# reading coherence in [3858, 990, 5142, 1320] * 375 ...
# reading coherence in [2572, 990, 3858, 1320] * 375 ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# chunk 1 / 5
# chunk 1 / 5
# chunk 1 / 5
# chunk 1 / 5
# chunk 2 / 5
# chunk 2 / 5
# chunk 2 / 5
# chunk 2 / 5
# chunk 3 / 5
# chunk 3 / 5
# chunk 3 / 5
# chunk 3 / 5
# chunk 4 / 5
# chunk 4 / 5
# chunk 4 / 5
# chunk 4 / 5
# chunk 5 / 5
# reading unwrapPhase_bridging in [1286, 990, 2572, 1320] * 375 ...
# chunk 5 / 5
# reading unwrapPhase_bridging in [3858, 990, 5142, 1320] * 375 ...
# chunk 5 / 5
# reading unwrapPhase_bridging in [0, 990, 1286, 1320] * 375 ...
# chunk 5 / 5
# reading unwrapPhase_bridging in [2572, 990, 3858, 1320] * 375 ...
# 2024-01-29 22:01:46,919 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.90 GiB -- Worker memory limit: 2.68 GiB
# 2024-01-29 22:01:47,466 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.91 GiB -- Worker memory limit: 2.68 GiB
# 2024-01-29 22:01:47,489 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.92 GiB -- Worker memory limit: 2.68 GiB
# 2024-01-29 22:01:47,521 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.90 GiB -- Worker memory limit: 2.68 GiB
# use input reference value
# use input reference value
# use input reference value
# use input reference value
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# skip pixels with zero value in file: avgSpatialCoh.h5
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# skip pixels with zero value in file: avgSpatialCoh.h5
# number of pixels to invert: 183920 out of 423720 (43.4%)
# estimating time-series via WLS pixel-by-pixel ...
# number of pixels to invert: 335023 out of 424380 (78.9%)
# estimating time-series via WLS pixel-by-pixel ...
# skip pixels with zero value in file: avgSpatialCoh.h5
# skip pixels with zero value in file: avgSpatialCoh.h5
# number of pixels to invert: 417624 out of 424380 (98.4%)
# estimating time-series via WLS pixel-by-pixel ...
# number of pixels to invert: 424380 out of 424380 (100.0%)
# estimating time-series via WLS pixel-by-pixel ...
# [==================================================] 183920/183920 pixels  852s /  1177s
# [======================= 53%                       ] 176600/335023 pixels  853s /   756sconverting LOS phase unit from radian to meter
# [===================>    41%                       ] 175600/424380 pixels  853s /  1227s
# FUTURE #1 complete. Time used: 878 seconds
# [==================================================] 335023/335023 pixels 1458s /   387s
# converting LOS phase unit from radian to meter
#
# FUTURE #2 complete. Time used: 1484 seconds
# [==================================================] 417624/417624 pixels 1735s /    35s
# [======================= 98% ====================> ] 417000/424380 pixels 1735s /    35sconverting LOS phase unit from radian to meter
#
# FUTURE #3 complete. Time used: 1761 seconds
# [==================================================] 424380/424380 pixels 1739s /    35s
# converting LOS phase unit from radian to meter
#
# FUTURE #4 complete. Time used: 1785 seconds
# close dask client
# close dask cluster
# ------- finished parallel processing -------
#
#
# --------------------------------------------------
# open  HDF5 file timeseries.h5 in a mode
# writing dataset /timeseries                block: [0, 209, 990, 1320, 0, 5142]
# close HDF5 file timeseries.h5.
# --------------------------------------------------
# open  HDF5 file temporalCoherence.h5 in a mode
# writing dataset /temporalCoherence         block: [990, 1320, 0, 5142]
# close HDF5 file temporalCoherence.h5.
# --------------------------------------------------
# open  HDF5 file numInvIfgram.h5 in a mode
# writing dataset /mask                      block: [990, 1320, 0, 5142]
# close HDF5 file numInvIfgram.h5.
# time used: 88 mins 36.1 secs.
#
#
# ------- processing patch 5 out of 6 --------------
# box width:  5142
# box length: 330
#
#
# ------- start parallel processing using Dask -------
# input Dask cluster type: local
# initiate Dask cluster
# split patch into 4 sub boxes in x direction for workers to process
# scale Dask cluster to 4 workers
# initiate Dask client
# submit a job to the worker for sub box 0: [0, 1320, 1286, 1650]
# submit a job to the worker for sub box 1: [1286, 1320, 2572, 1650]
# submit a job to the worker for sub box 2: [2572, 1320, 3858, 1650]
# submit a job to the worker for sub box 3: [3858, 1320, 5142, 1650]
# calculating weight from spatial coherence ...
# calculating weight from spatial coherence ...
# calculating weight from spatial coherence ...
# reading coherence in [3858, 1320, 5142, 1650] * 375 ...
# reading coherence in [0, 1320, 1286, 1650] * 375 ...
# reading coherence in [1286, 1320, 2572, 1650] * 375 ...
# calculating weight from spatial coherence ...
# reading coherence in [2572, 1320, 3858, 1650] * 375 ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# chunk 1 / 5
# chunk 1 / 5
# chunk 1 / 5
# chunk 1 / 5
# chunk 2 / 5
# chunk 2 / 5
# chunk 2 / 5
# chunk 2 / 5
# chunk 3 / 5
# chunk 3 / 5
# chunk 3 / 5
# chunk 3 / 5
# chunk 4 / 5
# chunk 4 / 5
# chunk 4 / 5
# chunk 4 / 5
# chunk 5 / 5
# reading unwrapPhase_bridging in [0, 1320, 1286, 1650] * 375 ...
# chunk 5 / 5
# reading unwrapPhase_bridging in [1286, 1320, 2572, 1650] * 375 ...
# chunk 5 / 5
# chunk 5 / 5
# reading unwrapPhase_bridging in [2572, 1320, 3858, 1650] * 375 ...
# reading unwrapPhase_bridging in [3858, 1320, 5142, 1650] * 375 ...
# 2024-01-29 22:31:39,974 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.98 GiB -- Worker memory limit: 2.68 GiB
# use input reference value
# 2024-01-29 22:31:40,176 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.93 GiB -- Worker memory limit: 2.68 GiB
# use input reference value
# 2024-01-29 22:31:40,376 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.90 GiB -- Worker memory limit: 2.68 GiB
# use input reference value
# 2024-01-29 22:31:40,578 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.02 GiB -- Worker memory limit: 2.68 GiB
# use input reference value
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# skip pixels with zero value in file: avgSpatialCoh.h5
# skip pixels with zero value in file: avgSpatialCoh.h5
# number of pixels to invert: 96596 out of 424380 (22.8%)
# estimating time-series via WLS pixel-by-pixel ...
# number of pixels to invert: 0 out of 423720 (0.0%)
# skip pixels with zero value in file: avgSpatialCoh.h5
# number of pixels to invert: 331150 out of 424380 (78.0%)
# estimating time-series via WLS pixel-by-pixel ...
# skip pixels with zero value in file: avgSpatialCoh.h5
# number of pixels to invert: 371593 out of 424380 (87.6%)
# estimating time-series via WLS pixel-by-pixel ...
#
# FUTURE #1 complete. Time used: 26 seconds
# [==================================================] 96596/96596 pixels   321s /  1074s
# converting LOS phase unit from radian to meter
#
# FUTURE #2 complete. Time used: 347 seconds
# [==================================================] 331150/331150 pixels 1141s /   112s
# converting LOS phase unit from radian to meter
# [======================= 91% =================>    ] 338000/371593 pixels 1142s /   112s
# FUTURE #3 complete. Time used: 1168 seconds
# [==================================================] 371593/371593 pixels 1221s /    24s
# converting LOS phase unit from radian to meter
#
# FUTURE #4 complete. Time used: 1262 seconds
# close dask client
# close dask cluster
# ------- finished parallel processing -------
#
#
# --------------------------------------------------
# open  HDF5 file timeseries.h5 in a mode
# writing dataset /timeseries                block: [0, 209, 1320, 1650, 0, 5142]
# close HDF5 file timeseries.h5.
# --------------------------------------------------
# open  HDF5 file temporalCoherence.h5 in a mode
# writing dataset /temporalCoherence         block: [1320, 1650, 0, 5142]
# close HDF5 file temporalCoherence.h5.
# --------------------------------------------------
# open  HDF5 file numInvIfgram.h5 in a mode
# writing dataset /mask                      block: [1320, 1650, 0, 5142]
# close HDF5 file numInvIfgram.h5.
# time used: 109 mins 46.8 secs.
#
#
# ------- processing patch 6 out of 6 --------------
# box width:  5142
# box length: 322
#
#
# ------- start parallel processing using Dask -------
# input Dask cluster type: local
# initiate Dask cluster
# split patch into 4 sub boxes in x direction for workers to process
# scale Dask cluster to 4 workers
# initiate Dask client
# submit a job to the worker for sub box 0: [0, 1650, 1286, 1972]
# submit a job to the worker for sub box 1: [1286, 1650, 2572, 1972]
# submit a job to the worker for sub box 2: [2572, 1650, 3858, 1972]
# submit a job to the worker for sub box 3: [3858, 1650, 5142, 1972]
# calculating weight from spatial coherence ...
# calculating weight from spatial coherence ...
# reading coherence in [3858, 1650, 5142, 1972] * 375 ...
# reading coherence in [0, 1650, 1286, 1972] * 375 ...
# calculating weight from spatial coherence ...
# calculating weight from spatial coherence ...
# reading coherence in [1286, 1650, 2572, 1972] * 375 ...
# reading coherence in [2572, 1650, 3858, 1972] * 375 ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight in chunks of 100000 pixels: 5 chunks in total ...
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=3
# chunk 1 / 5
# chunk 1 / 5
# chunk 1 / 5
# chunk 1 / 5
# chunk 2 / 5
# chunk 2 / 5
# chunk 2 / 5
# chunk 2 / 5
# chunk 3 / 5
# chunk 3 / 5
# chunk 3 / 5
# chunk 3 / 5
# chunk 4 / 5
# chunk 4 / 5
# chunk 4 / 5
# chunk 5 / 5
# chunk 5 / 5
# reading unwrapPhase_bridging in [3858, 1650, 5142, 1972] * 375 ...
# reading unwrapPhase_bridging in [0, 1650, 1286, 1972] * 375 ...
# chunk 4 / 5
# chunk 5 / 5
# reading unwrapPhase_bridging in [2572, 1650, 3858, 1972] * 375 ...
# chunk 5 / 5
# reading unwrapPhase_bridging in [1286, 1650, 2572, 1972] * 375 ...
# 2024-01-29 22:52:49,398 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.97 GiB -- Worker memory limit: 2.68 GiB
# use input reference value
# 2024-01-29 22:52:49,804 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.88 GiB -- Worker memory limit: 2.68 GiB
# 2024-01-29 22:52:49,804 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.87 GiB -- Worker memory limit: 2.68 GiB
# use input reference value
# use input reference value
# 2024-01-29 22:52:50,119 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.00 GiB -- Worker memory limit: 2.68 GiB
# use input reference value
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# skip pixels with zero value in file: avgSpatialCoh.h5
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# convert zero value in unwrapPhase_bridging to NaN (no-data value)
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# skip pixels with unwrapPhase_bridging = NaN in all interferograms
# number of pixels to invert: 179439 out of 414092 (43.3%)
# estimating time-series via WLS pixel-by-pixel ...
# skip pixels with zero value in file: avgSpatialCoh.h5
# skip pixels with zero value in file: avgSpatialCoh.h5
# skip pixels with zero value in file: avgSpatialCoh.h5
# number of pixels to invert: 0 out of 413448 (0.0%)
# number of pixels to invert: 0 out of 414092 (0.0%)
# number of pixels to invert: 26471 out of 414092 (6.4%)
# estimating time-series via WLS pixel-by-pixel ...
# [>                                                 ]
# FUTURE #1 complete. Time used: 25 seconds
#
# FUTURE #2 complete. Time used: 25 seconds
# [==================================================] 26471/26471 pixels   71s /     1ss
# converting LOS phase unit from radian to meter
# [=====>                  12%                       ] 22200/179439 pixels   72s /   528s
# FUTURE #3 complete. Time used: 96 seconds
# [==================================================] 179439/179439 pixels  487s /     9s
# converting LOS phase unit from radian to meter
#
# FUTURE #4 complete. Time used: 515 seconds
# close dask client
# close dask cluster
# ------- finished parallel processing -------
#
#
# --------------------------------------------------
# open  HDF5 file timeseries.h5 in a mode
# writing dataset /timeseries                block: [0, 209, 1650, 1972, 0, 5142]
# close HDF5 file timeseries.h5.
# --------------------------------------------------
# open  HDF5 file temporalCoherence.h5 in a mode
# writing dataset /temporalCoherence         block: [1650, 1972, 0, 5142]
# close HDF5 file temporalCoherence.h5.
# --------------------------------------------------
# open  HDF5 file numInvIfgram.h5 in a mode
# writing dataset /mask                      block: [1650, 1972, 0, 5142]
# close HDF5 file numInvIfgram.h5.
# time used: 118 mins 30.1 secs.
#
# --------------------------------------------------
# update values on the reference pixel: (992, 3640)
# set temporalCoherence on the reference pixel to 1.
# set  # of observations on the reference pixel as 375
# roll back to the original settings of ['OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS', 'MKL_NUM_THREADS', 'NUMEXPR_NUM_THREADS', 'VECLIB_MAXIMUM_THREADS']
# remove env variable OMP_NUM_THREADS
# remove env variable OPENBLAS_NUM_THREADS
# remove env variable MKL_NUM_THREADS
# remove env variable NUMEXPR_NUM_THREADS
# remove env variable VECLIB_MAXIMUM_THREADS
# time used: 118 mins 30.1 secs.
#
# Input data seems to be geocoded. Lookup file not needed.
#
# generate_mask.py /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/temporalCoherence.h5 -m 0.0 -o /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/maskTempCoh.h5
# update mode: ON
# run or skip: run
# input temporalCoherence file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/temporalCoherence.h5
# read /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/temporalCoherence.h5
# create initial mask with the same size as the input file and all = 1
# all pixels with nan value = 0
# exclude pixels with value < 0.0
# delete exsited file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/maskTempCoh.h5
# create HDF5 file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/maskTempCoh.h5 with w mode
# create dataset /mask of bool       in size of (1972, 5142)         with compression=None
# finished writing to /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/maskTempCoh.h5
# time used: 00 mins 0.5 secs.
# number of reliable pixels: 10140024
# Go back to directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 118 mins 37.1 secs

# %%
view.main('avgSpatialCoh.h5 --noverbose'.split())
view.main('temporalCoherence.h5 --noverbose'.split())
# Out:
# view.py avgSpatialCoh.h5 --noverbose
# view.py temporalCoherence.h5 --noverbose

# %%
view.main('timeseries.h5 -v -5 5 --noaxis'.split())
# equivalent command in terminal: view.py timeseries.h5 -v -5 5 --noaxis
# Out:
# run view.py in MintPy version 1.5.3, date 2023-11-23
# input file is timeseries file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries.h5 in float32 format
# file size in y/x: (1972, 5142)
# num of datasets in file timeseries.h5: 209
# datasets to exclude (0):
# []
# datasets to display (209):
# ['timeseries-20170123', 'timeseries-20170204', 'timeseries-20170216', 'timeseries-20170228', 'timeseries-20170312', 'timeseries-20170324', 'timeseries-20170405', 'timeseries-20170417', 'timeseries-20170429', 'timeseries-20170511', 'timeseries-20170523', 'timeseries-20170604', 'timeseries-20170628', 'timeseries-20170710', 'timeseries-20170722', 'timeseries-20170803', 'timeseries-20170815', 'timeseries-20170827', 'timeseries-20170908', 'timeseries-20170920', 'timeseries-20171002', 'timeseries-20171014', 'timeseries-20171026', 'timeseries-20171107', 'timeseries-20171119', 'timeseries-20171201', 'timeseries-20171213', 'timeseries-20171225', 'timeseries-20180106', 'timeseries-20180118', 'timeseries-20180130', 'timeseries-20180211', 'timeseries-20180223', 'timeseries-20180307', 'timeseries-20180319', 'timeseries-20180331', 'timeseries-20180412', 'timeseries-20180424', 'timeseries-20180506', 'timeseries-20180518', 'timeseries-20180530', 'timeseries-20180611', 'timeseries-20180623', 'timeseries-20180705', 'timeseries-20180717', 'timeseries-20180729', 'timeseries-20180810', 'timeseries-20180822', 'timeseries-20180903', 'timeseries-20180915', 'timeseries-20180927', 'timeseries-20181009', 'timeseries-20181021', 'timeseries-20181102', 'timeseries-20181114', 'timeseries-20181126', 'timeseries-20181208', 'timeseries-20181220', 'timeseries-20190101', 'timeseries-20190113', 'timeseries-20190125', 'timeseries-20190206', 'timeseries-20190218', 'timeseries-20190302', 'timeseries-20190314', 'timeseries-20190326', 'timeseries-20190407', 'timeseries-20190419', 'timeseries-20190501', 'timeseries-20190513', 'timeseries-20190606', 'timeseries-20190618', 'timeseries-20190630', 'timeseries-20190712', 'timeseries-20190724', 'timeseries-20190805', 'timeseries-20190817', 'timeseries-20190829', 'timeseries-20190910', 'timeseries-20190922', 'timeseries-20191004', 'timeseries-20191016', 'timeseries-20191028', 'timeseries-20191109', 'timeseries-20191121', 'timeseries-20191203', 'timeseries-20191215', 'timeseries-20191227', 'timeseries-20200108', 'timeseries-20200120', 'timeseries-20200201', 'timeseries-20200213', 'timeseries-20200225', 'timeseries-20200308', 'timeseries-20200320', 'timeseries-20200401', 'timeseries-20200413', 'timeseries-20200425', 'timeseries-20200507', 'timeseries-20200519', 'timeseries-20200531', 'timeseries-20200612', 'timeseries-20200624', 'timeseries-20200706', 'timeseries-20200718', 'timeseries-20200730', 'timeseries-20200811', 'timeseries-20200823', 'timeseries-20200904', 'timeseries-20200916', 'timeseries-20200928', 'timeseries-20201010', 'timeseries-20201022', 'timeseries-20201103', 'timeseries-20201115', 'timeseries-20201127', 'timeseries-20201209', 'timeseries-20201221', 'timeseries-20210102', 'timeseries-20210114', 'timeseries-20210126', 'timeseries-20210207', 'timeseries-20210219', 'timeseries-20210303', 'timeseries-20210315', 'timeseries-20210327', 'timeseries-20210408', 'timeseries-20210420', 'timeseries-20210502', 'timeseries-20210514', 'timeseries-20210526', 'timeseries-20210607', 'timeseries-20210619', 'timeseries-20210701', 'timeseries-20210713', 'timeseries-20210725', 'timeseries-20210806', 'timeseries-20210818', 'timeseries-20210830', 'timeseries-20210911', 'timeseries-20210923', 'timeseries-20211005', 'timeseries-20211017', 'timeseries-20211029', 'timeseries-20211110', 'timeseries-20211122', 'timeseries-20211204', 'timeseries-20211216', 'timeseries-20211228', 'timeseries-20220109', 'timeseries-20220121', 'timeseries-20220202', 'timeseries-20220214', 'timeseries-20220226', 'timeseries-20220310', 'timeseries-20220322', 'timeseries-20220403', 'timeseries-20220415', 'timeseries-20220427', 'timeseries-20220509', 'timeseries-20220521', 'timeseries-20220602', 'timeseries-20220614', 'timeseries-20220626', 'timeseries-20220708', 'timeseries-20220720', 'timeseries-20220801', 'timeseries-20220813', 'timeseries-20220825', 'timeseries-20220906', 'timeseries-20220918', 'timeseries-20220930', 'timeseries-20221012', 'timeseries-20221024 ...
# data   coverage in y/x: (0, 0, 5142, 1972)
# subset coverage in y/x: (0, 0, 5142, 1972)
# data   coverage in lat/lon: (416620.0, 3107120.0, 519460.0, 3067680.0)
# subset coverage in lat/lon: (416620.0, 3107120.0, 519460.0, 3067680.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries
# figure size : [15.00, 8.00]
# dataset number: 209
# row     number: 12
# column  number: 9
# figure  number: 2
# read mask from file: maskTempCoh.h5
# total number of pixels: 1.1E+09
# * multilook 6 by 6 with nearest interpolation for display to save memory
# ----------------------------------------
# Figure 1 - timeseries_1.png
# reading data as a 3D matrix ...
# reading 2D slices 108/108...
# data    range: [-471.43365, 338.6863] cm
# display range: [-5.0, 5.0] cm
# masking data
# plotting ...
# [==================================================] timeseries-20200823    4s /     0s
# data    range: [-471.43365, 338.6863] cm
# display range: [-5.0, 5.0] cm
# show colorbar
# ----------------------------------------
# Figure 2 - timeseries_2.png
# reading data as a 3D matrix ...
# reading 2D slices 101/101...
# data    range: [-947.36053, 543.58246] cm
# display range: [-5.0, 5.0] cm
# masking data
# plotting ...
# [==================================================] timeseries-20240123    2s /     0s
# data    range: [-947.36053, 543.58246] cm
# display range: [-5.0, 5.0] cm
# show colorbar
# ----------------------------------------
# all data range: [-947.3605346679688, 543.5824584960938] cm
# display  range: [-5.0, 5.0] cm
# showing ...

# %%
# !smallbaselineApp.py SenAT12.txt --dostep deramp
# Out:
# MintPy version 1.5.3, date 2023-11-23
# --RUN-at-2024-01-29 23:03:02.603524--
# Current directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# Run routine processing with smallbaselineApp.py on steps: ['deramp']
# Remaining steps: ['correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# read custom template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/SenAT12.txt
# update default template based on input custom template
# No new option value found, skip updating /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
# copy SenAT12.txt          to inputs   directory for backup.
# copy smallbaselineApp.cfg to inputs   directory for backup.
# copy SenAT12.txt          to pic      directory for backup.
# copy smallbaselineApp.cfg to pic      directory for backup.
# read default template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
#
#
# ******************** step - deramp ********************
# Remove for each acquisition a phase ramp: linear
#
# remove_ramp.py /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries.h5 -s linear -m maskTempCoh.h5 -o /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp.h5 --update
# --------------------------------------------------
# update mode: ON
# 1) output file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp.h5 already exists.
# 2) output file is NOT newer than input file: ['/mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries.h5', 'maskTempCoh.h5'].
# run or skip: run.
# remove linear ramp from file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries.h5
# read mask file: maskTempCoh.h5
# --------------------------------------------------
# grab metadata from ref_file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries.h5
# grab dataset structure from ref_file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries.h5
# create HDF5 file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp.h5 with w mode
# create dataset  : bperp      of float32                   in size of (209,)               with compression = None
# create dataset  : date       of |S8                       in size of (209,)               with compression = None
# create dataset  : timeseries of float32                   in size of (209, 1972, 5142)    with compression = None
# close  HDF5 file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp.h5
# estimating phase ramp one date at a time ...
# [==================================================] 209/209  355s /     7s
# finished writing to file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp.h5
# add/update the following metadata to file:
# add/update mintpy.deramp = linear
# add/update mintpy.deramp.maskFile = maskTempCoh.h5
# time used: 06 mins 3.1 secs.
# Go back to directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 06 mins 3.3 secs

# %%
# !smallbaselineApp.py SenAT12.txt --dostep correct_topography
# Out:
# MintPy version 1.5.3, date 2023-11-23
# --RUN-at-2024-01-29 23:09:07.080937--
# Current directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# Run routine processing with smallbaselineApp.py on steps: ['correct_topography']
# Remaining steps: ['residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# read custom template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/SenAT12.txt
# update default template based on input custom template
# No new option value found, skip updating /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
# copy SenAT12.txt          to inputs   directory for backup.
# copy smallbaselineApp.cfg to inputs   directory for backup.
# copy SenAT12.txt          to pic      directory for backup.
# copy smallbaselineApp.cfg to pic      directory for backup.
# read default template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
#
#
# ******************** step - correct_topography ********************
# Input data seems to be geocoded. Lookup file not needed.
#
# dem_error.py /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp.h5 -t /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg -o /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp_demErr.h5 --update -g /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/geometryGeo.h5
# read options from template file: smallbaselineApp.cfg
# --------------------------------------------------
# update mode: ON
# 1) output file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp_demErr.h5 already exists.
# 2) output file is NOT newer than input file: ['/mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp.h5', '/mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/inputs/geometryGeo.h5'].
# run or skip: run.
# save the original settings of ['OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS', 'MKL_NUM_THREADS', 'NUMEXPR_NUM_THREADS', 'VECLIB_MAXIMUM_THREADS']
# set OMP_NUM_THREADS = 1
# set OPENBLAS_NUM_THREADS = 1
# set MKL_NUM_THREADS = 1
# set NUMEXPR_NUM_THREADS = 1
# set VECLIB_MAXIMUM_THREADS = 1
# open timeseries file: timeseries_ramp.h5
# --------------------------------------------------------------------------------
# correct topographic phase residual (DEM error) (Fattahi & Amelung, 2013, IEEE-TGRS)
# ordinal least squares (OLS) inversion with L2-norm minimization on: phase
# temporal deformation model: polynomial order = 2
# --------------------------------------------------------------------------------
# add/update the following configuration metadata to file:
# ['polyOrder', 'phaseVelocity', 'stepFuncDate', 'excludeDate']
# --------------------------------------------------
# create HDF5 file: demErr.h5 with w mode
# create dataset  : dem of <class 'numpy.float32'>   in size of (1972, 5142)         with compression = None
# close  HDF5 file: demErr.h5
# --------------------------------------------------
# grab dataset structure from ref_file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp.h5
# create HDF5 file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp_demErr.h5 with w mode
# create dataset  : bperp      of float32                   in size of (209,)               with compression = None
# create dataset  : date       of |S8                       in size of (209,)               with compression = None
# create dataset  : timeseries of float32                   in size of (209, 1972, 5142)    with compression = None
# close  HDF5 file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp_demErr.h5
# --------------------------------------------------
# grab dataset structure from ref_file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp.h5
# create HDF5 file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseriesResidual.h5 with w mode
# create dataset  : bperp      of float32                   in size of (209,)               with compression = None
# create dataset  : date       of |S8                       in size of (209,)               with compression = None
# create dataset  : timeseries of float32                   in size of (209, 1972, 5142)    with compression = None
# close  HDF5 file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseriesResidual.h5
#
# ------- processing patch 1 out of 6 --------------
# box width:  5142
# box length: 329
#
#
# ------- start parallel processing using Dask -------
# input Dask cluster type: local
# initiate Dask cluster
# split patch into 4 sub boxes in x direction for workers to process
# scale Dask cluster to 4 workers
# initiate Dask client
# submit a job to the worker for sub box 0: [0, 0, 1286, 329]
# submit a job to the worker for sub box 1: [1286, 0, 2572, 329]
# submit a job to the worker for sub box 2: [2572, 0, 3858, 329]
# submit a job to the worker for sub box 3: [3858, 0, 5142, 329]
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# open geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 0 out of 423094 (0.0%)
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 0 out of 423094 (0.0%)
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 132760 out of 422436 (31.4%)
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 22219 out of 423094 (5.3%)
# estimating DEM error pixel-wisely ...
# [=================>      36%                       ] 8000/22219    1s /     2ss
# FUTURE #1 complete. Time used: 6 seconds
# [======================= 63% ===>                  ] 14000/22219    2s /     1ss
# FUTURE #2 complete. Time used: 7 seconds
# [==================================================] 22219/22219     3s /    16s
# [=========>              21%                       ] 28000/132760    4s /    16s
# FUTURE #3 complete. Time used: 9 seconds
# [==================================================] 132760/132760   15s /     0s
#
# FUTURE #4 complete. Time used: 22 seconds
# close dask client
# close dask cluster
# ------- finished parallel processing -------
#
#
# --------------------------------------------------
# open  HDF5 file demErr.h5 in a mode
# writing dataset /dem                       block: [0, 329, 0, 5142]
# close HDF5 file demErr.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp_demErr.h5 in a mode
# writing dataset /timeseries                block: [0, 209, 0, 329, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp_demErr.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseriesResidual.h5 in a mode
# writing dataset /timeseries                block: [0, 209, 0, 329, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseriesResidual.h5.
#
# ------- processing patch 2 out of 6 --------------
# box width:  5142
# box length: 329
#
#
# ------- start parallel processing using Dask -------
# input Dask cluster type: local
# initiate Dask cluster
# split patch into 4 sub boxes in x direction for workers to process
# scale Dask cluster to 4 workers
# initiate Dask client
# submit a job to the worker for sub box 0: [0, 329, 1286, 658]
# submit a job to the worker for sub box 1: [1286, 329, 2572, 658]
# submit a job to the worker for sub box 2: [2572, 329, 3858, 658]
# submit a job to the worker for sub box 3: [3858, 329, 5142, 658]
# open geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 0 out of 423094 (0.0%)
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 87958 out of 423094 (20.8%)
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 364002 out of 423094 (86.0%)
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 270049 out of 422436 (63.9%)
# estimating DEM error pixel-wisely ...
# [>                                                 ] 4000/87958    1s /    22s
# FUTURE #1 complete. Time used: 7 seconds
# [==================================================] 87958/87958    11s /    36s
# [==================>     38%                       ] 102000/270049   12s /    20s
# FUTURE #2 complete. Time used: 18 seconds
# [==================================================] 270049/270049   31s /    12s
# [======================= 74% ========>             ] 268000/364002   32s /    11s
# FUTURE #3 complete. Time used: 39 seconds
# [==================================================] 364002/364002   43s /     0s
#
# FUTURE #4 complete. Time used: 51 seconds
# close dask client
# close dask cluster
# ------- finished parallel processing -------
#
#
# --------------------------------------------------
# open  HDF5 file demErr.h5 in a mode
# writing dataset /dem                       block: [329, 658, 0, 5142]
# close HDF5 file demErr.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp_demErr.h5 in a mode
# writing dataset /timeseries                block: [0, 209, 329, 658, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp_demErr.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseriesResidual.h5 in a mode
# writing dataset /timeseries                block: [0, 209, 329, 658, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseriesResidual.h5.
#
# ------- processing patch 3 out of 6 --------------
# box width:  5142
# box length: 329
#
#
# ------- start parallel processing using Dask -------
# input Dask cluster type: local
# initiate Dask cluster
# split patch into 4 sub boxes in x direction for workers to process
# scale Dask cluster to 4 workers
# initiate Dask client
# submit a job to the worker for sub box 0: [0, 658, 1286, 987]
# submit a job to the worker for sub box 1: [1286, 658, 2572, 987]
# submit a job to the worker for sub box 2: [2572, 658, 3858, 987]
# submit a job to the worker for sub box 3: [3858, 658, 5142, 987]
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 180279 out of 423094 (42.6%)
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 297227 out of 422436 (70.4%)
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 423092 out of 423094 (100.0%)
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 413966 out of 423094 (97.8%)
# estimating DEM error pixel-wisely ...
# [==================================================] 180279/180279   23s /    16s
# [======================= 62% ==>                   ] 184000/297227   24s /    15s
# FUTURE #1 complete. Time used: 31 seconds
# [==================================================] 297227/297227   38s /    17s
# [======================= 75% =========>            ] 316000/423092   42s /    14s
# FUTURE #2 complete. Time used: 49 seconds
# [==================================================] 413966/413966   55s /     1s
# [==================================================] 423092/423092
#
# FUTURE #3 complete. Time used: 64 seconds
#
# FUTURE #4 complete. Time used: 64 seconds
# close dask client
# close dask cluster
# ------- finished parallel processing -------
#
#
# --------------------------------------------------
# open  HDF5 file demErr.h5 in a mode
# writing dataset /dem                       block: [658, 987, 0, 5142]
# close HDF5 file demErr.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp_demErr.h5 in a mode
# writing dataset /timeseries                block: [0, 209, 658, 987, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp_demErr.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseriesResidual.h5 in a mode
# writing dataset /timeseries                block: [0, 209, 658, 987, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseriesResidual.h5.
#
# ------- processing patch 4 out of 6 --------------
# box width:  5142
# box length: 329
#
#
# ------- start parallel processing using Dask -------
# input Dask cluster type: local
# initiate Dask cluster
# split patch into 4 sub boxes in x direction for workers to process
# scale Dask cluster to 4 workers
# initiate Dask client
# submit a job to the worker for sub box 0: [0, 987, 1286, 1316]
# submit a job to the worker for sub box 1: [1286, 987, 2572, 1316]
# submit a job to the worker for sub box 2: [2572, 987, 3858, 1316]
# submit a job to the worker for sub box 3: [3858, 987, 5142, 1316]
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# skip pixels with NaN  in ANY acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 331941 out of 423094 (78.5%)
# estimating DEM error pixel-wisely ...
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 423094 out of 423094 (100.0%)
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# estimating DEM error pixel-wisely ...
# number of pixels to invert: 414354 out of 423094 (97.9%)
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO temporal coherence
# [>                                                 ]skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 175385 out of 422436 (41.5%)
# estimating DEM error pixel-wisely ...
# [==================================================] 175385/175385   28s /    23s
# [=====================>  43%                       ] 180000/423094   28s /    38s
# FUTURE #1 complete. Time used: 35 seconds
# [==================================================] 331941/331941   49s /    15s
# [======================= 78% ==========>           ] 332000/423094   50s /    14s
# FUTURE #2 complete. Time used: 57 seconds
# [==================================================] 414354/414354   59s /     3s
# [======================= 96% ===================>  ] 406000/423094   61s /     2s
# FUTURE #3 complete. Time used: 68 seconds
# [==================================================] 423094/423094   62s /     1s
#
# FUTURE #4 complete. Time used: 71 seconds
# close dask client
# close dask cluster
# ------- finished parallel processing -------
#
#
# --------------------------------------------------
# open  HDF5 file demErr.h5 in a mode
# writing dataset /dem                       block: [987, 1316, 0, 5142]
# close HDF5 file demErr.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp_demErr.h5 in a mode
# writing dataset /timeseries                block: [0, 209, 987, 1316, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp_demErr.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseriesResidual.h5 in a mode
# writing dataset /timeseries                block: [0, 209, 987, 1316, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseriesResidual.h5.
#
# ------- processing patch 5 out of 6 --------------
# box width:  5142
# box length: 329
#
#
# ------- start parallel processing using Dask -------
# input Dask cluster type: local
# initiate Dask cluster
# split patch into 4 sub boxes in x direction for workers to process
# scale Dask cluster to 4 workers
# initiate Dask client
# submit a job to the worker for sub box 0: [0, 1316, 1286, 1645]
# submit a job to the worker for sub box 1: [1286, 1316, 2572, 1645]
# submit a job to the worker for sub box 2: [2572, 1316, 3858, 1645]
# submit a job to the worker for sub box 3: [3858, 1316, 5142, 1645]
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# open geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 327362 out of 423094 (77.4%)
# estimating DEM error pixel-wisely ...
# skip pixels with NaN  in ANY acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 365753 out of 423094 (86.4%)
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 0 out of 422436 (0.0%)
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 89652 out of 423094 (21.2%)
# estimating DEM error pixel-wisely ...
# [=>                       5%                       ] 16000/327362    6s /   117s
# FUTURE #1 complete. Time used: 12 seconds
# [==================================================] 89652/89652    19s /    45s
# [===============>        32%                       ] 106000/327362   20s /    43s
# FUTURE #2 complete. Time used: 26 seconds
# [==================================================] 327362/327362   45s /     5s
# [======================= 91% =================>    ] 332000/365753   46s /     4s
# FUTURE #3 complete. Time used: 55 seconds
# [==================================================] 365753/365753   49s /     1s
#
# FUTURE #4 complete. Time used: 60 seconds
# close dask client
# close dask cluster
# ------- finished parallel processing -------
#
#
# --------------------------------------------------
# open  HDF5 file demErr.h5 in a mode
# writing dataset /dem                       block: [1316, 1645, 0, 5142]
# close HDF5 file demErr.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp_demErr.h5 in a mode
# writing dataset /timeseries                block: [0, 209, 1316, 1645, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp_demErr.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseriesResidual.h5 in a mode
# writing dataset /timeseries                block: [0, 209, 1316, 1645, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseriesResidual.h5.
#
# ------- processing patch 6 out of 6 --------------
# box width:  5142
# box length: 327
#
#
# ------- start parallel processing using Dask -------
# input Dask cluster type: local
# initiate Dask cluster
# split patch into 4 sub boxes in x direction for workers to process
# scale Dask cluster to 4 workers
# initiate Dask client
# submit a job to the worker for sub box 0: [0, 1645, 1286, 1972]
# submit a job to the worker for sub box 1: [1286, 1645, 2572, 1972]
# submit a job to the worker for sub box 2: [2572, 1645, 3858, 1972]
# submit a job to the worker for sub box 3: [3858, 1645, 5142, 1972]
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# open geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# read mean bperp from timeseries file
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with ZERO in ALL acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# skip pixels with NaN  in ANY acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 167195 out of 420522 (39.8%)
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 0 out of 420522 (0.0%)
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 23408 out of 420522 (5.6%)
# estimating DEM error pixel-wisely ...
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 0 out of 419868 (0.0%)
# [======================= 77% =========>            ] 18000/23408    3s /     0ss
# FUTURE #1 complete. Time used: 9 seconds
# [==================================================] 23408/23408    3s /     0ss
# [=======>                17%                       ] 28000/167195    4s /    24s
# FUTURE #2 complete. Time used: 10 seconds
# [=========>              19%                       ] 32000/167195    5s /    23s
# FUTURE #3 complete. Time used: 11 seconds
# [==================================================] 167195/167195   20s /     0s
#
# FUTURE #4 complete. Time used: 27 seconds
# close dask client
# close dask cluster
# ------- finished parallel processing -------
#
#
# --------------------------------------------------
# open  HDF5 file demErr.h5 in a mode
# writing dataset /dem                       block: [1645, 1972, 0, 5142]
# close HDF5 file demErr.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp_demErr.h5 in a mode
# writing dataset /timeseries                block: [0, 209, 1645, 1972, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp_demErr.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseriesResidual.h5 in a mode
# writing dataset /timeseries                block: [0, 209, 1645, 1972, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseriesResidual.h5.
# roll back to the original settings of ['OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS', 'MKL_NUM_THREADS', 'NUMEXPR_NUM_THREADS', 'VECLIB_MAXIMUM_THREADS']
# remove env variable OMP_NUM_THREADS
# remove env variable OPENBLAS_NUM_THREADS
# remove env variable MKL_NUM_THREADS
# remove env variable NUMEXPR_NUM_THREADS
# remove env variable VECLIB_MAXIMUM_THREADS
# time used: 06 mins 8.1 secs.
# Go back to directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 06 mins 10.1 secs

# %%
# !smallbaselineApp.py SenAT12.txt --dostep residual_RMS
# Out:
# MintPy version 1.5.3, date 2023-11-23
# --RUN-at-2024-01-29 23:15:19.278277--
# Current directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# Run routine processing with smallbaselineApp.py on steps: ['residual_RMS']
# Remaining steps: ['reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# read custom template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/SenAT12.txt
# update default template based on input custom template
# No new option value found, skip updating /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
# copy SenAT12.txt          to inputs   directory for backup.
# copy smallbaselineApp.cfg to inputs   directory for backup.
# copy SenAT12.txt          to pic      directory for backup.
# copy smallbaselineApp.cfg to pic      directory for backup.
# read default template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
#
#
# ******************** step - residual_RMS ********************
#
# timeseries_rms.py timeseriesResidual.h5 -t /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
# read options from template file: smallbaselineApp.cfg
# remove quadratic ramp from file: timeseriesResidual.h5
# read mask file: maskTempCoh.h5
# --------------------------------------------------
# grab metadata from ref_file: timeseriesResidual.h5
# grab dataset structure from ref_file: timeseriesResidual.h5
# create HDF5 file: timeseriesResidual_ramp.h5 with w mode
# create dataset  : bperp      of float32                   in size of (209,)               with compression = None
# create dataset  : date       of |S8                       in size of (209,)               with compression = None
# create dataset  : timeseries of float32                   in size of (209, 1972, 5142)    with compression = None
# close  HDF5 file: timeseriesResidual_ramp.h5
# estimating phase ramp one date at a time ...
# [==================================================] 209/209  408s /     8s
# finished writing to file: timeseriesResidual_ramp.h5
# time used: 06 mins 57.5 secs.
#
# calculating residual RMS for each epoch from file: timeseriesResidual_ramp.h5
# read mask from file: maskTempCoh.h5
# reading timeseries data from file: timeseriesResidual_ramp.h5 ...
# [==================================================] 209/209  106s /     2s
# save timeseries RMS to text file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/rms_timeseriesResidual_ramp.txt
# read timeseries residual RMS from file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/rms_timeseriesResidual_ramp.txt
# --------------------------------------------------
# date with min RMS: 20230609 - 0.0372
# save date to file: reference_date.txt
# --------------------------------------------------
# date(s) with RMS > 3.0 * median RMS (0.2777)
# None.
# save figure to file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/rms_timeseriesResidual_ramp.pdf
# Go back to directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 08 mins 47.2 secs

# %%
# !smallbaselineApp.py SenAT12.txt --dostep reference_date
# Out:
# MintPy version 1.5.3, date 2023-11-23
# --RUN-at-2024-01-29 23:24:07.775159--
# Current directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# Run routine processing with smallbaselineApp.py on steps: ['reference_date']
# Remaining steps: ['velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# read custom template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/SenAT12.txt
# update default template based on input custom template
# No new option value found, skip updating /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
# copy SenAT12.txt          to inputs   directory for backup.
# copy smallbaselineApp.cfg to inputs   directory for backup.
# copy SenAT12.txt          to pic      directory for backup.
# copy smallbaselineApp.cfg to pic      directory for backup.
# read default template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
#
#
# ******************** step - reference_date ********************
# No reference date change.
# Go back to directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 0.1 secs

# %%
# !smallbaselineApp.py SenAT12.txt --dostep velocity
# Out:
# MintPy version 1.5.3, date 2023-11-23
# --RUN-at-2024-01-29 23:24:08.958127--
# Current directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# Run routine processing with smallbaselineApp.py on steps: ['velocity']
# Remaining steps: ['geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: SenAT12
# Go to work directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
# read custom template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/SenAT12.txt
# update default template based on input custom template
# No new option value found, skip updating /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
# copy SenAT12.txt          to inputs   directory for backup.
# copy smallbaselineApp.cfg to inputs   directory for backup.
# copy SenAT12.txt          to pic      directory for backup.
# copy smallbaselineApp.cfg to pic      directory for backup.
# read default template file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg
#
#
# ******************** step - velocity ********************
#
# timeseries2velocity.py /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp_demErr.h5 -t /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/smallbaselineApp.cfg -o /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5 --update
# read options from template file: smallbaselineApp.cfg
# update mode: ON
# 1) output file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5 already exists.
# 2) output file is NOT newer than input file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp_demErr.h5.
# run or skip: run.
# open timeseries file: timeseries_ramp_demErr.h5
# exclude date: []
# --------------------------------------------------
# dates from input file: 209
# ['20170123', '20170204', '20170216', '20170228', '20170312', '20170324', '20170405', '20170417', '20170429', '20170511', '20170523', '20170604', '20170628', '20170710', '20170722', '20170803', '20170815', '20170827', '20170908', '20170920', '20171002', '20171014', '20171026', '20171107', '20171119', '20171201', '20171213', '20171225', '20180106', '20180118', '20180130', '20180211', '20180223', '20180307', '20180319', '20180331', '20180412', '20180424', '20180506', '20180518', '20180530', '20180611', '20180623', '20180705', '20180717', '20180729', '20180810', '20180822', '20180903', '20180915', '20180927', '20181009', '20181021', '20181102', '20181114', '20181126', '20181208', '20181220', '20190101', '20190113', '20190125', '20190206', '20190218', '20190302', '20190314', '20190326', '20190407', '20190419', '20190501', '20190513', '20190606', '20190618', '20190630', '20190712', '20190724', '20190805', '20190817', '20190829', '20190910', '20190922', '20191004', '20191016', '20191028', '20191109', '20191121', '20191203', '20191215', '20191227', '20200108', '20200120', '20200201', '20200213', '20200225', '20200308', '20200320', '20200401', '20200413', '20200425', '20200507', '20200519', '20200531', '20200612', '20200624', '20200706', '20200718', '20200730', '20200811', '20200823', '20200904', '20200916', '20200928', '20201010', '20201022', '20201103', '20201115', '20201127', '20201209', '20201221', '20210102', '20210114', '20210126', '20210207', '20210219', '20210303', '20210315', '20210327', '20210408', '20210420', '20210502', '20210514', '20210526', '20210607', '20210619', '20210701', '20210713', '20210725', '20210806', '20210818', '20210830', '20210911', '20210923', '20211005', '20211017', '20211029', '20211110', '20211122', '20211204', '20211216', '20211228', '20220109', '20220121', '20220202', '20220214', '20220226', '20220310', '20220322', '20220403', '20220415', '20220427', '20220509', '20220521', '20220602', '20220614', '20220626', '20220708', '20220720', '20220801', '20220813', '20220825', '20220906', '20220918', '20220930', '20221012', '20221024', '20221105', '20221117', '20221129', '20221211', '20221223', '20230104', '20230116', '20230209', '20230221', '20230317', '20230410', '20230422', '20230504', '20230516', '20230528', '20230609', '20230621', '20230703', '20230715', '20230727', '20230808', '20230820', '20230901', '20230913', '20230925', '20231007', '20231019', '20231031', '20231112', '20231124', '20231206', '20231218', '20231230', '20240111', '20240123']
# --------------------------------------------------
# using all dates to calculate the time function
# --------------------------------------------------
# estimate deformation model with the following assumed time functions:
#     polynomial : 1
#     periodic   : []
#     stepDate   : []
#     polyline   : []
#     exp        : {}
#     log        : {}
# add/update the following configuration metadata:
# ['startDate', 'endDate', 'excludeDate', 'polynomial', 'periodic', 'stepDate', 'exp', 'log', 'uncertaintyQuantification', 'timeSeriesCovFile', 'bootstrapCount']
# --------------------------------------------------
# create HDF5 file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5 with w mode
# create dataset  : intercept    of <class 'numpy.float32'>   in size of (1972, 5142)         with compression = None
# create dataset  : interceptStd of <class 'numpy.float32'>   in size of (1972, 5142)         with compression = None
# create dataset  : velocity     of <class 'numpy.float32'>   in size of (1972, 5142)         with compression = None
# create dataset  : velocityStd  of <class 'numpy.float32'>   in size of (1972, 5142)         with compression = None
# create dataset  : residue      of <class 'numpy.float32'>   in size of (1972, 5142)         with compression = None
# add /intercept    attribute: UNIT = m
# add /interceptStd attribute: UNIT = m
# add /velocity     attribute: UNIT = m/year
# add /velocityStd  attribute: UNIT = m/year
# add /residue      attribute: UNIT = m
# close  HDF5 file: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5
# split along y dimension (1972) into 3 boxes
#     with each box up to 658 in y dimension
#
# ------- processing patch 1 out of 3 --------------
# box width:  5142
# box length: 658
# reading data from file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp_demErr.h5 ...
# skip pixels with zero/nan value in all acquisitions
# number of pixels to invert: 876988 out of 3383436 (25.9%)
# estimating time functions via linalg.lstsq ...
# estimating time functions STD from time-series fitting residual ...
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5 in a mode
# writing dataset /intercept                 block: [0, 658, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5 in a mode
# writing dataset /interceptStd              block: [0, 658, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5 in a mode
# writing dataset /velocity                  block: [0, 658, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5 in a mode
# writing dataset /velocityStd               block: [0, 658, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5 in a mode
# writing dataset /residue                   block: [0, 658, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5.
#
# ------- processing patch 2 out of 3 --------------
# box width:  5142
# box length: 658
# reading data from file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp_demErr.h5 ...
# skip pixels with zero/nan value in all acquisitions
# number of pixels to invert: 2659339 out of 3383436 (78.6%)
# estimating time functions via linalg.lstsq ...
# estimating time functions STD from time-series fitting residual ...
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5 in a mode
# writing dataset /intercept                 block: [658, 1316, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5 in a mode
# writing dataset /interceptStd              block: [658, 1316, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5 in a mode
# writing dataset /velocity                  block: [658, 1316, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5 in a mode
# writing dataset /velocityStd               block: [658, 1316, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5 in a mode
# writing dataset /residue                   block: [658, 1316, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5.
#
# ------- processing patch 3 out of 3 --------------
# box width:  5142
# box length: 656
# reading data from file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/timeseries_ramp_demErr.h5 ...
# skip pixels with zero/nan value in all acquisitions
# number of pixels to invert: 973370 out of 3373152 (28.9%)
# estimating time functions via linalg.lstsq ...
# estimating time functions STD from time-series fitting residual ...
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5 in a mode
# writing dataset /intercept                 block: [1316, 1972, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5 in a mode
# writing dataset /interceptStd              block: [1316, 1972, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5 in a mode
# writing dataset /velocity                  block: [1316, 1972, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5 in a mode
# writing dataset /velocityStd               block: [1316, 1972, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5 in a mode
# writing dataset /residue                   block: [1316, 1972, 0, 5142]
# close HDF5 file /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams/velocity.h5.
# time used: 00 mins 57.0 secs.
# Go back to directory: /mnt/c/Users/qbren/Desktop/taco/projects/fusits/nbs/imja/hyp3-isce2/mintpy_igrams
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 57.6 secs

# %%
view.main('velocity.h5 --noverbose --vlim -0.1 0.1 -c RdBu_r'.split())
# Out:
# view.py velocity.h5 --noverbose --vlim -0.1 0.1 -c RdBu_r
